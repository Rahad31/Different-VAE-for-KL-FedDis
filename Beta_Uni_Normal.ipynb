# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahad31/Different-VAE-for-KL-FedDis/blob/main/Beta_Uni_Normal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Beta=0.1

# %%
import numpy as np
from scipy.stats import truncnorm
import torch
import torchvision
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import Subset, DataLoader
from torchvision.datasets import CIFAR10
from typing import Dict, Tuple
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import random

# Define VAE model
class VAE(nn.Module):
    def __init__(self, x_dim, h_dim, z_dim):
        super(VAE, self).__init__()
        self.x_dim = x_dim
        self.h_dim = h_dim
        self.z_dim = z_dim

        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 32, 4, stride=2, padding=1),  # 16x16
            nn.ReLU(),
            nn.Conv2d(32, 64, 4, stride=2, padding=1),  # 8x8
            nn.ReLU(),
            nn.Conv2d(64, 128, 4, stride=2, padding=1),  # 4x4
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(2048, 256),
            nn.ReLU(),
            nn.Linear(256, 2*z_dim)
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(z_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 2048),
            nn.ReLU(),
            nn.Unflatten(1, (128, 4, 4)),
            nn.ConvTranspose2d(128, 64, 4, stride=2, padding=1),  # 8x8
            nn.ReLU(),
            nn.ConvTranspose2d(64, 32, 4, stride=2, padding=1),  # 16x16
            nn.ReLU(),
            nn.ConvTranspose2d(32, 3, 4, stride=2, padding=1),  # 32x32
            nn.Sigmoid()
        )

    def encode(self, x):
        h = self.encoder(x)
        mu, logvar = h[:, :self.z_dim], h[:, self.z_dim:]
        return mu, logvar

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z):
        return self.decoder(z)

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar


# Define VAE training procedure
def vae_train(vae: VAE, trainloader: DataLoader, epochs: int, beta: float =0.1):
    optimizer = torch.optim.Adam(vae.parameters(), lr=1e-3)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)

    for epoch in range(epochs):
        vae.train()
        for i, data in enumerate(trainloader, 0):
            inputs, _ = data
            optimizer.zero_grad()
            recon_x, mu, logvar = vae(inputs)
            loss = vae_loss(recon_x, inputs, mu, logvar , beta=beta)
            loss.backward()
            optimizer.step()

        scheduler.step()


# Define classification model
class Net(nn.Module):
    def __init__(self) -> None:
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.pool(nn.functional.relu(self.conv1(x)))
        x = self.pool(nn.functional.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = nn.functional.relu(self.fc1(x))
        x = nn.functional.relu(self.fc2(x))
        x = self.fc3(x)
        return x


# Load CIFAR10 dataset
transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]
)

full_dataset = CIFAR10(root="./data", train=True, download=True, transform=transform)
test_set = CIFAR10(root="./data", train=False, download=True, transform=transform)

# Separate dataset by class
class_indices = {i: [] for i in range(10)}  # CIFAR-10 has 10 classes
for idx, (_, label) in enumerate(full_dataset):
    class_indices[label].append(idx)

# Define target count per class, summing to 60,000 with random distribution
class_counts = np.random.multinomial(60000, [0.1] * 10)  # Adjust probabilities if you want specific class biases
print("Random Images per Class:", class_counts)

# Sample indices based on the specified class counts
indices = []
for class_id, count in enumerate(class_counts):
    # Ensure count does not exceed available images
    count = min(count, len(class_indices[class_id]))
    selected_indices = random.sample(class_indices[class_id], count)
    indices.extend(selected_indices)

# Create a custom CIFAR-10 dataset with the sampled indices
custom_dataset = Subset(full_dataset, indices)
# Split dataset into training and validation sets
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_set, val_set = torch.utils.data.random_split(full_dataset, [train_size, val_size])

# Create training and validation loaders
trainloader = DataLoader(train_set, batch_size=128, shuffle=True, num_workers=2)
valloader = DataLoader(val_set, batch_size=128, shuffle=False, num_workers=2)
testloader = DataLoader(test_set, batch_size=128, shuffle=False, num_workers=2)



# Define VAE loss function
def vae_loss(recon_x, x, mu, logvar, beta=0.1):
    BCE = nn.functional.mse_loss(recon_x, x, reduction='sum')
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return BCE + beta * KLD

# Define training procedure for classification model
def train(net: nn.Module, trainloader: DataLoader, valloader: DataLoader, epochs: int) -> None:
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)

    best_acc = 0.0

    for epoch in range(epochs):
        # Training loop
        net.train()
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            inputs, labels = data
            optimizer.zero_grad()
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        scheduler.step()

        # Validation loop
        net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data in valloader:
                images, labels = data
                outputs = net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_acc = 100 * correct / total
        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(net.state_dict(), 'best_model.pth')

        print(f"Epoch [{epoch+1}/{epochs}], Training Loss: {running_loss / (i+1):.3f}, Validation Accuracy: {val_acc:.2f}%")

# Define evaluation procedure
def evaluate(net: nn.Module, testloader: DataLoader) -> Tuple[float, np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
    net.eval()
    correct = 0
    total = 0
    all_labels = []
    all_predictions = []
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    accuracy = 100 * correct / total

    # Calculate confusion matrix
    cm = confusion_matrix(all_labels, all_predictions)
    print(f"Confusion Matrix:\n{cm}")

    # Calculate TP, FP, TN, FN for each class
    tp = np.diag(cm)
    fp = cm.sum(axis=0) - tp
    fn = cm.sum(axis=1) - tp
    tn = cm.sum() - (fp + fn + tp)

    # Calculate precision, recall, and F1 score for each class
    precision = precision_score(all_labels, all_predictions, average=None)
    recall = recall_score(all_labels, all_predictions, average=None)
    f1 = f1_score(all_labels, all_predictions, average=None)

    return accuracy, tp, fp, tn, fn, precision, recall, f1

# Initialize clients
def initialize_clients(trainset, transform, batch_size, num_clients):
    clients = {}
    for i in range(num_clients):
        client_trainset = torch.utils.data.Subset(trainset, range(i * len(trainset) // num_clients, (i + 1) * len(trainset) // num_clients))
        client_trainloader = torch.utils.data.DataLoader(client_trainset, batch_size=batch_size, shuffle=True)
        clients[f"client_{i}"] = client_trainloader
    return clients

def get_distribution_info(vae: VAE) -> Dict:
    # Implement the logic to extract distribution information from the VAE
    # This can involve computing statistics, parameters, or any other relevant information
    # that can be used to generate augmented data

    # Example implementation:
    distribution_info = {
        "uniform": {
            "mean": vae.encoder[-1].bias.data.cpu().numpy(),
            "std": torch.exp(0.5 * vae.encoder[-1].weight.data).cpu().numpy()
        },
        "normal": {
            "mean": vae.encoder[-1].bias.data.cpu().numpy(),
            "std": torch.exp(0.5 * vae.encoder[-1].weight.data).cpu().numpy()
        }
    }

    return distribution_info

def send_distribution_info(distribution_info: Dict) -> None:
    # Implement the logic to send the distribution information to the global server
    # This can involve using a network protocol, a message queue, or any other communication mechanism
    # to send the information

    # Example implementation:
    # Send the distribution information to the global server using a network protocol
    # For example, you can use the `socket` module to send the information over a network
    # or use a message queue like `RabbitMQ` to send the information
    pass

def generate_augmented_data(vae: VAE, distribution_info_uniform: Dict, distribution_info_normal: Dict) -> torch.Tensor:
    # Generate augmented data using both uniform and truncated uniform distributions

    mean = distribution_info_uniform["mean"].mean().item()  # Convert numpy array to float
    std = distribution_info_uniform["std"].mean().item()  # Convert numpy array to float


    mean_normal = distribution_info_normal["mean"]
    std_normal = distribution_info_normal["std"]

    augmented_data_normal = torch.randn(64, vae.z_dim) * std_normal + mean_normal

     # Generate augmented data using Uniform distribution
    augmented_data_uniform = torch.FloatTensor(64, vae.z_dim).uniform_(mean - std, mean + std)


    # Calculate the average of augmented data from both distributions
    augmented_data_average = (augmented_data_uniform + augmented_data_normal ) / 2

    return augmented_data_average

def federated_train(net: nn.Module, vae: VAE, trainloaders: Dict[str, DataLoader], trainloader: DataLoader, valloader: DataLoader, epochs: int) -> None:
    for epoch in range(epochs):
        for client_id, client_trainloader in trainloaders.items():
            # Train VAE on client data
            vae_train(vae, client_trainloader, epochs=10, beta=0.1)

            # Share distribution information with global server
            distribution_info = get_distribution_info(vae)
            send_distribution_info(distribution_info)

            # Receive distribution information from other clients
            other_distribution_info = receive_distribution_info()

            # Generate augmented data using received distribution information
            augmented_data = generate_augmented_data(vae, other_distribution_info["uniform"], other_distribution_info["normal"])

            # Train classification model using local, augmented, and validation data
            train(net, client_trainloader, valloader, epochs=10)

            # Send model updates to global server
            send_model_update(client_id, net.state_dict())

# Define logic to receive distribution information from global server
def receive_distribution_info() -> Dict:
    # Receive distribution information logic
    distribution_info = {
        "uniform": {
            "mean": np.zeros(20),  # Adjust the size based on your latent space dimension
            "std": np.ones(20)
        },
        "normal": {
            "mean": np.zeros(20),  # Adjust the size based on your latent space dimension
            "std": np.ones(20)
        }
    }
    return distribution_info

def send_model_update(client_id: str, model_update: Dict) -> None:
    # Implement the logic to send the model update to the global server
    # This can involve using a network protocol, a message queue, or any other communication mechanism
    # to send the model update

    # Example implementation:
    # Send the model update to the global server using a network protocol
    # For example, you can use the `socket` module to send the information over a network
    # or use a message queue like `RabbitMQ` to send the information
    pass

# Define global server procedure
def global_server() -> None:
    net = Net()
    x_dim = 3 * 32 * 32  # CIFAR-10 input size
    h_dim = 400
    z_dim = 20
    vae = VAE(x_dim, h_dim, z_dim)  # Initialize VAE object with required arguments

    # Initialize clients
    num_clients = 5  # Define the number of clients
    clients = initialize_clients(train_set, transform, batch_size=128, num_clients=num_clients)

    # Train model using FedDIS
    federated_train(net, vae, clients, trainloader, valloader, epochs=10)

    # Evaluate final model
    test_accuracy, tp, fp, tn, fn, precision, recall, f1 = evaluate(net, testloader)
    print(f"Test Accuracy: {test_accuracy:.2f}%")

    print("True Positives (TP):", tp)
    print("False Positives (FP):", fp)
    print("True Negatives (TN):", tn)
    print("False Negatives (FN):", fn)
    print(":", fn+tn+tp+fp)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)

if __name__ == "__main__":
    global_server()
# Out:
# 100%|██████████| 170M/170M [00:01<00:00, 97.4MB/s]
# Random Images per Class: [6005 5991 5981 5935 6115 6021 6039 5981 5977 5955]
# /tmp/ipython-input-1-2097540308.py:280: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   augmented_data_normal = torch.randn(64, vae.z_dim) * std_normal + mean_normal
# Epoch [1/10], Training Loss: 2.304, Validation Accuracy: 11.00%
# Epoch [2/10], Training Loss: 2.303, Validation Accuracy: 11.60%
# Epoch [3/10], Training Loss: 2.302, Validation Accuracy: 12.75%
# Epoch [4/10], Training Loss: 2.301, Validation Accuracy: 12.63%
# Epoch [5/10], Training Loss: 2.300, Validation Accuracy: 12.77%
# Epoch [6/10], Training Loss: 2.299, Validation Accuracy: 12.77%
# Epoch [7/10], Training Loss: 2.298, Validation Accuracy: 12.93%
# Epoch [8/10], Training Loss: 2.297, Validation Accuracy: 13.36%
# Epoch [9/10], Training Loss: 2.295, Validation Accuracy: 13.44%
# Epoch [10/10], Training Loss: 2.292, Validation Accuracy: 13.21%
# Epoch [1/10], Training Loss: 2.290, Validation Accuracy: 12.74%
# Epoch [2/10], Training Loss: 2.286, Validation Accuracy: 12.47%
# Epoch [3/10], Training Loss: 2.279, Validation Accuracy: 12.35%
# Epoch [4/10], Training Loss: 2.268, Validation Accuracy: 12.53%
# Epoch [5/10], Training Loss: 2.256, Validation Accuracy: 13.47%
# Epoch [6/10], Training Loss: 2.243, Validation Accuracy: 16.25%
# Epoch [7/10], Training Loss: 2.229, Validation Accuracy: 17.22%
# Epoch [8/10], Training Loss: 2.214, Validation Accuracy: 18.18%
# Epoch [9/10], Training Loss: 2.198, Validation Accuracy: 19.17%
# Epoch [10/10], Training Loss: 2.181, Validation Accuracy: 19.64%
# Epoch [1/10], Training Loss: 2.164, Validation Accuracy: 21.04%
# Epoch [2/10], Training Loss: 2.144, Validation Accuracy: 22.91%
# Epoch [3/10], Training Loss: 2.120, Validation Accuracy: 23.23%
# Epoch [4/10], Training Loss: 2.094, Validation Accuracy: 23.93%
# Epoch [5/10], Training Loss: 2.066, Validation Accuracy: 24.31%
# Epoch [6/10], Training Loss: 2.037, Validation Accuracy: 25.59%
# Epoch [7/10], Training Loss: 2.011, Validation Accuracy: 26.37%
# Epoch [8/10], Training Loss: 1.988, Validation Accuracy: 26.74%
# Epoch [9/10], Training Loss: 1.967, Validation Accuracy: 27.41%
# Epoch [10/10], Training Loss: 1.948, Validation Accuracy: 28.14%
# Epoch [1/10], Training Loss: 1.927, Validation Accuracy: 28.98%
# Epoch [2/10], Training Loss: 1.911, Validation Accuracy: 29.82%
# Epoch [3/10], Training Loss: 1.890, Validation Accuracy: 29.93%
# Epoch [4/10], Training Loss: 1.873, Validation Accuracy: 31.62%
# Epoch [5/10], Training Loss: 1.855, Validation Accuracy: 32.05%
# Epoch [6/10], Training Loss: 1.837, Validation Accuracy: 31.96%
# Epoch [7/10], Training Loss: 1.819, Validation Accuracy: 34.01%
# Epoch [8/10], Training Loss: 1.800, Validation Accuracy: 34.19%
# Epoch [9/10], Training Loss: 1.784, Validation Accuracy: 34.13%
# Epoch [10/10], Training Loss: 1.768, Validation Accuracy: 35.10%
# Epoch [1/10], Training Loss: 1.784, Validation Accuracy: 35.79%
# Epoch [2/10], Training Loss: 1.764, Validation Accuracy: 35.92%
# Epoch [3/10], Training Loss: 1.744, Validation Accuracy: 36.46%
# Epoch [4/10], Training Loss: 1.734, Validation Accuracy: 36.71%
# Epoch [5/10], Training Loss: 1.714, Validation Accuracy: 36.37%
# Epoch [6/10], Training Loss: 1.703, Validation Accuracy: 36.91%
# Epoch [7/10], Training Loss: 1.688, Validation Accuracy: 37.56%
# Epoch [8/10], Training Loss: 1.675, Validation Accuracy: 37.58%
# Epoch [9/10], Training Loss: 1.667, Validation Accuracy: 37.79%
# Epoch [10/10], Training Loss: 1.658, Validation Accuracy: 37.48%
# Epoch [1/10], Training Loss: 1.658, Validation Accuracy: 38.56%
# Epoch [2/10], Training Loss: 1.646, Validation Accuracy: 37.98%
# Epoch [3/10], Training Loss: 1.633, Validation Accuracy: 39.10%
# Epoch [4/10], Training Loss: 1.624, Validation Accuracy: 39.24%
# Epoch [5/10], Training Loss: 1.625, Validation Accuracy: 39.65%
# Epoch [6/10], Training Loss: 1.602, Validation Accuracy: 39.11%
# Epoch [7/10], Training Loss: 1.587, Validation Accuracy: 40.10%
# Epoch [8/10], Training Loss: 1.580, Validation Accuracy: 40.58%
# Epoch [9/10], Training Loss: 1.571, Validation Accuracy: 40.59%
# Epoch [10/10], Training Loss: 1.563, Validation Accuracy: 40.82%
# Epoch [1/10], Training Loss: 1.592, Validation Accuracy: 40.58%
# Epoch [2/10], Training Loss: 1.574, Validation Accuracy: 41.26%
# Epoch [3/10], Training Loss: 1.564, Validation Accuracy: 40.99%
# Epoch [4/10], Training Loss: 1.557, Validation Accuracy: 41.48%
# Epoch [5/10], Training Loss: 1.546, Validation Accuracy: 42.04%
# Epoch [6/10], Training Loss: 1.541, Validation Accuracy: 41.99%
# Epoch [7/10], Training Loss: 1.532, Validation Accuracy: 41.57%
# Epoch [8/10], Training Loss: 1.526, Validation Accuracy: 42.51%
# Epoch [9/10], Training Loss: 1.512, Validation Accuracy: 42.47%
# Epoch [10/10], Training Loss: 1.505, Validation Accuracy: 42.52%
# Epoch [1/10], Training Loss: 1.535, Validation Accuracy: 43.17%
# Epoch [2/10], Training Loss: 1.524, Validation Accuracy: 43.78%
# Epoch [3/10], Training Loss: 1.514, Validation Accuracy: 43.15%
# Epoch [4/10], Training Loss: 1.504, Validation Accuracy: 43.50%
# Epoch [5/10], Training Loss: 1.492, Validation Accuracy: 43.92%
# Epoch [6/10], Training Loss: 1.484, Validation Accuracy: 44.75%
# Epoch [7/10], Training Loss: 1.478, Validation Accuracy: 44.05%
# Epoch [8/10], Training Loss: 1.472, Validation Accuracy: 44.32%
# Epoch [9/10], Training Loss: 1.464, Validation Accuracy: 44.57%
# Epoch [10/10], Training Loss: 1.452, Validation Accuracy: 45.03%
# Epoch [1/10], Training Loss: 1.501, Validation Accuracy: 45.76%
# Epoch [2/10], Training Loss: 1.486, Validation Accuracy: 45.17%
# Epoch [3/10], Training Loss: 1.471, Validation Accuracy: 45.70%
# Epoch [4/10], Training Loss: 1.466, Validation Accuracy: 45.16%
# Epoch [5/10], Training Loss: 1.450, Validation Accuracy: 46.07%
# Epoch [6/10], Training Loss: 1.442, Validation Accuracy: 45.72%
# Epoch [7/10], Training Loss: 1.438, Validation Accuracy: 45.76%
# Epoch [8/10], Training Loss: 1.428, Validation Accuracy: 46.77%
# Epoch [9/10], Training Loss: 1.422, Validation Accuracy: 45.99%
# Epoch [10/10], Training Loss: 1.412, Validation Accuracy: 46.30%
# Epoch [1/10], Training Loss: 1.438, Validation Accuracy: 46.61%
# Epoch [2/10], Training Loss: 1.424, Validation Accuracy: 46.77%
# Epoch [3/10], Training Loss: 1.411, Validation Accuracy: 46.65%
# Epoch [4/10], Training Loss: 1.410, Validation Accuracy: 47.00%
# Epoch [5/10], Training Loss: 1.401, Validation Accuracy: 47.62%
# Epoch [6/10], Training Loss: 1.390, Validation Accuracy: 46.89%
# Epoch [7/10], Training Loss: 1.383, Validation Accuracy: 47.81%
# Epoch [8/10], Training Loss: 1.370, Validation Accuracy: 48.10%
# Epoch [9/10], Training Loss: 1.358, Validation Accuracy: 48.46%
# Epoch [10/10], Training Loss: 1.355, Validation Accuracy: 48.76%
# Epoch [1/10], Training Loss: 1.384, Validation Accuracy: 48.98%
# Epoch [2/10], Training Loss: 1.378, Validation Accuracy: 47.88%
# Epoch [3/10], Training Loss: 1.361, Validation Accuracy: 47.53%
# Epoch [4/10], Training Loss: 1.352, Validation Accuracy: 49.01%
# Epoch [5/10], Training Loss: 1.339, Validation Accuracy: 49.08%
# Epoch [6/10], Training Loss: 1.343, Validation Accuracy: 49.17%
# Epoch [7/10], Training Loss: 1.321, Validation Accuracy: 49.80%
# Epoch [8/10], Training Loss: 1.317, Validation Accuracy: 48.88%
# Epoch [9/10], Training Loss: 1.308, Validation Accuracy: 49.50%
# Epoch [10/10], Training Loss: 1.298, Validation Accuracy: 49.95%
# Epoch [1/10], Training Loss: 1.364, Validation Accuracy: 49.88%
# Epoch [2/10], Training Loss: 1.334, Validation Accuracy: 50.25%
# Epoch [3/10], Training Loss: 1.329, Validation Accuracy: 49.02%
# Epoch [4/10], Training Loss: 1.319, Validation Accuracy: 49.67%
# Epoch [5/10], Training Loss: 1.307, Validation Accuracy: 50.38%
# Epoch [6/10], Training Loss: 1.289, Validation Accuracy: 50.33%
# Epoch [7/10], Training Loss: 1.285, Validation Accuracy: 51.01%
# Epoch [8/10], Training Loss: 1.281, Validation Accuracy: 51.25%
# Epoch [9/10], Training Loss: 1.265, Validation Accuracy: 51.08%
# Epoch [10/10], Training Loss: 1.259, Validation Accuracy: 51.05%
# Epoch [1/10], Training Loss: 1.334, Validation Accuracy: 51.01%
# Epoch [2/10], Training Loss: 1.310, Validation Accuracy: 51.83%
# Epoch [3/10], Training Loss: 1.293, Validation Accuracy: 50.46%
# Epoch [4/10], Training Loss: 1.293, Validation Accuracy: 51.47%
# Epoch [5/10], Training Loss: 1.280, Validation Accuracy: 51.29%
# Epoch [6/10], Training Loss: 1.267, Validation Accuracy: 51.76%
# Epoch [7/10], Training Loss: 1.260, Validation Accuracy: 52.02%
# Epoch [8/10], Training Loss: 1.246, Validation Accuracy: 52.34%
# Epoch [9/10], Training Loss: 1.237, Validation Accuracy: 51.45%
# Epoch [10/10], Training Loss: 1.226, Validation Accuracy: 51.46%
# Epoch [1/10], Training Loss: 1.317, Validation Accuracy: 51.79%
# Epoch [2/10], Training Loss: 1.286, Validation Accuracy: 52.93%
# Epoch [3/10], Training Loss: 1.270, Validation Accuracy: 52.64%
# Epoch [4/10], Training Loss: 1.256, Validation Accuracy: 52.14%
# Epoch [5/10], Training Loss: 1.242, Validation Accuracy: 53.15%
# Epoch [6/10], Training Loss: 1.235, Validation Accuracy: 52.59%
# Epoch [7/10], Training Loss: 1.228, Validation Accuracy: 53.47%
# Epoch [8/10], Training Loss: 1.215, Validation Accuracy: 52.63%
# Epoch [9/10], Training Loss: 1.214, Validation Accuracy: 53.03%
# Epoch [10/10], Training Loss: 1.201, Validation Accuracy: 53.10%
# Epoch [1/10], Training Loss: 1.264, Validation Accuracy: 52.30%
# Epoch [2/10], Training Loss: 1.250, Validation Accuracy: 54.28%
# Epoch [3/10], Training Loss: 1.239, Validation Accuracy: 53.50%
# Epoch [4/10], Training Loss: 1.217, Validation Accuracy: 53.33%
# Epoch [5/10], Training Loss: 1.204, Validation Accuracy: 53.85%
# Epoch [6/10], Training Loss: 1.200, Validation Accuracy: 53.74%
# Epoch [7/10], Training Loss: 1.182, Validation Accuracy: 54.02%
# Epoch [8/10], Training Loss: 1.176, Validation Accuracy: 53.28%
# Epoch [9/10], Training Loss: 1.168, Validation Accuracy: 54.26%
# Epoch [10/10], Training Loss: 1.157, Validation Accuracy: 53.12%
# Epoch [1/10], Training Loss: 1.251, Validation Accuracy: 54.29%
# Epoch [2/10], Training Loss: 1.212, Validation Accuracy: 55.09%
# Epoch [3/10], Training Loss: 1.194, Validation Accuracy: 54.92%
# Epoch [4/10], Training Loss: 1.177, Validation Accuracy: 54.98%
# Epoch [5/10], Training Loss: 1.170, Validation Accuracy: 55.14%
# Epoch [6/10], Training Loss: 1.161, Validation Accuracy: 54.68%
# Epoch [7/10], Training Loss: 1.153, Validation Accuracy: 53.56%
# Epoch [8/10], Training Loss: 1.150, Validation Accuracy: 54.93%
# Epoch [9/10], Training Loss: 1.127, Validation Accuracy: 54.64%
# Epoch [10/10], Training Loss: 1.121, Validation Accuracy: 54.68%
# Epoch [1/10], Training Loss: 1.217, Validation Accuracy: 54.74%
# Epoch [2/10], Training Loss: 1.182, Validation Accuracy: 54.33%
# Epoch [3/10], Training Loss: 1.167, Validation Accuracy: 55.34%
# Epoch [4/10], Training Loss: 1.149, Validation Accuracy: 54.96%
# Epoch [5/10], Training Loss: 1.140, Validation Accuracy: 55.34%
# Epoch [6/10], Training Loss: 1.125, Validation Accuracy: 54.88%
# Epoch [7/10], Training Loss: 1.119, Validation Accuracy: 55.46%
# Epoch [8/10], Training Loss: 1.107, Validation Accuracy: 54.72%
# Epoch [9/10], Training Loss: 1.099, Validation Accuracy: 55.24%
# Epoch [10/10], Training Loss: 1.086, Validation Accuracy: 55.93%
# Epoch [1/10], Training Loss: 1.206, Validation Accuracy: 55.46%
# Epoch [2/10], Training Loss: 1.181, Validation Accuracy: 55.17%
# Epoch [3/10], Training Loss: 1.166, Validation Accuracy: 55.57%
# Epoch [4/10], Training Loss: 1.145, Validation Accuracy: 54.98%
# Epoch [5/10], Training Loss: 1.127, Validation Accuracy: 55.15%
# Epoch [6/10], Training Loss: 1.115, Validation Accuracy: 55.41%
# Epoch [7/10], Training Loss: 1.110, Validation Accuracy: 55.48%
# Epoch [8/10], Training Loss: 1.091, Validation Accuracy: 55.73%
# Epoch [9/10], Training Loss: 1.082, Validation Accuracy: 55.38%
# Epoch [10/10], Training Loss: 1.078, Validation Accuracy: 56.03%
# Epoch [1/10], Training Loss: 1.187, Validation Accuracy: 55.62%
# Epoch [2/10], Training Loss: 1.160, Validation Accuracy: 56.06%
# Epoch [3/10], Training Loss: 1.137, Validation Accuracy: 56.29%
# Epoch [4/10], Training Loss: 1.131, Validation Accuracy: 55.71%
# Epoch [5/10], Training Loss: 1.111, Validation Accuracy: 55.30%
# Epoch [6/10], Training Loss: 1.096, Validation Accuracy: 56.38%
# Epoch [7/10], Training Loss: 1.086, Validation Accuracy: 56.07%
# Epoch [8/10], Training Loss: 1.076, Validation Accuracy: 55.49%
# Epoch [9/10], Training Loss: 1.063, Validation Accuracy: 55.95%
# Epoch [10/10], Training Loss: 1.050, Validation Accuracy: 56.15%
# Epoch [1/10], Training Loss: 1.160, Validation Accuracy: 57.28%
# Epoch [2/10], Training Loss: 1.134, Validation Accuracy: 56.97%
# Epoch [3/10], Training Loss: 1.117, Validation Accuracy: 56.71%
# Epoch [4/10], Training Loss: 1.102, Validation Accuracy: 56.41%
# Epoch [5/10], Training Loss: 1.080, Validation Accuracy: 56.57%
# Epoch [6/10], Training Loss: 1.070, Validation Accuracy: 56.83%
# Epoch [7/10], Training Loss: 1.061, Validation Accuracy: 56.95%
# Epoch [8/10], Training Loss: 1.046, Validation Accuracy: 56.50%
# Epoch [9/10], Training Loss: 1.030, Validation Accuracy: 57.18%
# Epoch [10/10], Training Loss: 1.016, Validation Accuracy: 56.29%
# Epoch [1/10], Training Loss: 1.156, Validation Accuracy: 57.09%
# Epoch [2/10], Training Loss: 1.115, Validation Accuracy: 57.51%
# Epoch [3/10], Training Loss: 1.087, Validation Accuracy: 56.46%
# Epoch [4/10], Training Loss: 1.068, Validation Accuracy: 57.14%
# Epoch [5/10], Training Loss: 1.058, Validation Accuracy: 56.92%
# Epoch [6/10], Training Loss: 1.038, Validation Accuracy: 56.85%
# Epoch [7/10], Training Loss: 1.029, Validation Accuracy: 57.13%
# Epoch [8/10], Training Loss: 1.018, Validation Accuracy: 57.16%
# Epoch [9/10], Training Loss: 1.008, Validation Accuracy: 56.70%
# Epoch [10/10], Training Loss: 0.998, Validation Accuracy: 56.51%
# Epoch [1/10], Training Loss: 1.124, Validation Accuracy: 57.42%
# Epoch [2/10], Training Loss: 1.095, Validation Accuracy: 57.40%
# Epoch [3/10], Training Loss: 1.066, Validation Accuracy: 57.71%
# Epoch [4/10], Training Loss: 1.048, Validation Accuracy: 57.01%
# Epoch [5/10], Training Loss: 1.023, Validation Accuracy: 57.25%
# Epoch [6/10], Training Loss: 1.023, Validation Accuracy: 57.61%
# Epoch [7/10], Training Loss: 1.002, Validation Accuracy: 56.95%
# Epoch [8/10], Training Loss: 0.990, Validation Accuracy: 56.37%
# Epoch [9/10], Training Loss: 0.989, Validation Accuracy: 56.81%
# Epoch [10/10], Training Loss: 0.965, Validation Accuracy: 57.71%
# Epoch [1/10], Training Loss: 1.123, Validation Accuracy: 57.21%
# Epoch [2/10], Training Loss: 1.075, Validation Accuracy: 57.67%
# Epoch [3/10], Training Loss: 1.062, Validation Accuracy: 57.56%
# Epoch [4/10], Training Loss: 1.037, Validation Accuracy: 58.14%
# Epoch [5/10], Training Loss: 1.017, Validation Accuracy: 56.95%
# Epoch [6/10], Training Loss: 1.016, Validation Accuracy: 57.01%
# Epoch [7/10], Training Loss: 0.987, Validation Accuracy: 57.22%
# Epoch [8/10], Training Loss: 0.973, Validation Accuracy: 57.52%
# Epoch [9/10], Training Loss: 0.966, Validation Accuracy: 57.40%
# Epoch [10/10], Training Loss: 0.951, Validation Accuracy: 57.42%
# Epoch [1/10], Training Loss: 1.116, Validation Accuracy: 58.02%
# Epoch [2/10], Training Loss: 1.068, Validation Accuracy: 58.29%
# Epoch [3/10], Training Loss: 1.046, Validation Accuracy: 57.65%
# Epoch [4/10], Training Loss: 1.020, Validation Accuracy: 57.56%
# Epoch [5/10], Training Loss: 1.003, Validation Accuracy: 57.30%
# Epoch [6/10], Training Loss: 0.985, Validation Accuracy: 57.48%
# Epoch [7/10], Training Loss: 0.977, Validation Accuracy: 57.88%
# Epoch [8/10], Training Loss: 0.962, Validation Accuracy: 57.79%
# Epoch [9/10], Training Loss: 0.943, Validation Accuracy: 57.76%
# Epoch [10/10], Training Loss: 0.938, Validation Accuracy: 57.77%
# Epoch [1/10], Training Loss: 1.092, Validation Accuracy: 58.22%
# Epoch [2/10], Training Loss: 1.048, Validation Accuracy: 58.34%
# Epoch [3/10], Training Loss: 1.021, Validation Accuracy: 57.06%
# Epoch [4/10], Training Loss: 1.004, Validation Accuracy: 58.44%
# Epoch [5/10], Training Loss: 0.977, Validation Accuracy: 57.93%
# Epoch [6/10], Training Loss: 0.968, Validation Accuracy: 58.12%
# Epoch [7/10], Training Loss: 0.956, Validation Accuracy: 58.36%
# Epoch [8/10], Training Loss: 0.941, Validation Accuracy: 57.40%
# Epoch [9/10], Training Loss: 0.926, Validation Accuracy: 58.45%
# Epoch [10/10], Training Loss: 0.915, Validation Accuracy: 58.49%
# Epoch [1/10], Training Loss: 1.087, Validation Accuracy: 58.58%
# Epoch [2/10], Training Loss: 1.032, Validation Accuracy: 58.87%
# Epoch [3/10], Training Loss: 1.012, Validation Accuracy: 58.22%
# Epoch [4/10], Training Loss: 0.982, Validation Accuracy: 57.97%
# Epoch [5/10], Training Loss: 0.964, Validation Accuracy: 58.31%
# Epoch [6/10], Training Loss: 0.954, Validation Accuracy: 58.28%
# Epoch [7/10], Training Loss: 0.926, Validation Accuracy: 58.64%
# Epoch [8/10], Training Loss: 0.915, Validation Accuracy: 58.98%
# Epoch [9/10], Training Loss: 0.893, Validation Accuracy: 58.29%
# Epoch [10/10], Training Loss: 0.887, Validation Accuracy: 58.55%
# Epoch [1/10], Training Loss: 1.058, Validation Accuracy: 58.94%
# Epoch [2/10], Training Loss: 1.011, Validation Accuracy: 58.38%
# Epoch [3/10], Training Loss: 0.980, Validation Accuracy: 58.22%
# Epoch [4/10], Training Loss: 0.960, Validation Accuracy: 58.31%
# Epoch [5/10], Training Loss: 0.943, Validation Accuracy: 58.91%
# Epoch [6/10], Training Loss: 0.916, Validation Accuracy: 58.62%
# Epoch [7/10], Training Loss: 0.899, Validation Accuracy: 58.94%
# Epoch [8/10], Training Loss: 0.889, Validation Accuracy: 59.10%
# Epoch [9/10], Training Loss: 0.877, Validation Accuracy: 58.91%
# Epoch [10/10], Training Loss: 0.857, Validation Accuracy: 59.21%
# Epoch [1/10], Training Loss: 1.053, Validation Accuracy: 58.01%
# Epoch [2/10], Training Loss: 1.010, Validation Accuracy: 59.01%
# Epoch [3/10], Training Loss: 0.968, Validation Accuracy: 58.12%
# Epoch [4/10], Training Loss: 0.947, Validation Accuracy: 58.57%
# Epoch [5/10], Training Loss: 0.920, Validation Accuracy: 59.43%
# Epoch [6/10], Training Loss: 0.897, Validation Accuracy: 58.42%
# Epoch [7/10], Training Loss: 0.885, Validation Accuracy: 58.88%
# Epoch [8/10], Training Loss: 0.874, Validation Accuracy: 57.95%
# Epoch [9/10], Training Loss: 0.863, Validation Accuracy: 58.38%
# Epoch [10/10], Training Loss: 0.836, Validation Accuracy: 58.77%
# Epoch [1/10], Training Loss: 1.047, Validation Accuracy: 59.02%
# Epoch [2/10], Training Loss: 0.991, Validation Accuracy: 59.27%
# Epoch [3/10], Training Loss: 0.958, Validation Accuracy: 58.38%
# Epoch [4/10], Training Loss: 0.929, Validation Accuracy: 59.14%
# Epoch [5/10], Training Loss: 0.902, Validation Accuracy: 59.01%
# Epoch [6/10], Training Loss: 0.887, Validation Accuracy: 59.11%
# Epoch [7/10], Training Loss: 0.875, Validation Accuracy: 58.64%
# Epoch [8/10], Training Loss: 0.861, Validation Accuracy: 57.61%
# Epoch [9/10], Training Loss: 0.851, Validation Accuracy: 58.61%
# Epoch [10/10], Training Loss: 0.825, Validation Accuracy: 58.87%
# Epoch [1/10], Training Loss: 1.030, Validation Accuracy: 58.85%
# Epoch [2/10], Training Loss: 0.987, Validation Accuracy: 58.47%
# Epoch [3/10], Training Loss: 0.957, Validation Accuracy: 58.94%
# Epoch [4/10], Training Loss: 0.921, Validation Accuracy: 59.13%
# Epoch [5/10], Training Loss: 0.895, Validation Accuracy: 59.15%
# Epoch [6/10], Training Loss: 0.877, Validation Accuracy: 59.84%
# Epoch [7/10], Training Loss: 0.861, Validation Accuracy: 59.27%
# Epoch [8/10], Training Loss: 0.842, Validation Accuracy: 59.08%
# Epoch [9/10], Training Loss: 0.826, Validation Accuracy: 58.96%
# Epoch [10/10], Training Loss: 0.825, Validation Accuracy: 57.73%
# Epoch [1/10], Training Loss: 1.029, Validation Accuracy: 58.79%
# Epoch [2/10], Training Loss: 0.964, Validation Accuracy: 58.58%
# Epoch [3/10], Training Loss: 0.930, Validation Accuracy: 59.10%
# Epoch [4/10], Training Loss: 0.899, Validation Accuracy: 59.77%
# Epoch [5/10], Training Loss: 0.867, Validation Accuracy: 59.11%
# Epoch [6/10], Training Loss: 0.850, Validation Accuracy: 59.50%
# Epoch [7/10], Training Loss: 0.827, Validation Accuracy: 59.30%
# Epoch [8/10], Training Loss: 0.815, Validation Accuracy: 58.86%
# Epoch [9/10], Training Loss: 0.806, Validation Accuracy: 58.61%
# Epoch [10/10], Training Loss: 0.780, Validation Accuracy: 58.97%
# Epoch [1/10], Training Loss: 0.994, Validation Accuracy: 59.13%
# Epoch [2/10], Training Loss: 0.933, Validation Accuracy: 59.24%
# Epoch [3/10], Training Loss: 0.901, Validation Accuracy: 59.42%
# Epoch [4/10], Training Loss: 0.868, Validation Accuracy: 59.45%
# Epoch [5/10], Training Loss: 0.846, Validation Accuracy: 59.07%
# Epoch [6/10], Training Loss: 0.820, Validation Accuracy: 59.67%
# Epoch [7/10], Training Loss: 0.814, Validation Accuracy: 58.95%
# Epoch [8/10], Training Loss: 0.786, Validation Accuracy: 59.59%
# Epoch [9/10], Training Loss: 0.769, Validation Accuracy: 59.04%
# Epoch [10/10], Training Loss: 0.753, Validation Accuracy: 59.34%
# Epoch [1/10], Training Loss: 1.009, Validation Accuracy: 59.36%
# Epoch [2/10], Training Loss: 0.928, Validation Accuracy: 59.81%
# Epoch [3/10], Training Loss: 0.891, Validation Accuracy: 59.67%
# Epoch [4/10], Training Loss: 0.863, Validation Accuracy: 59.69%
# Epoch [5/10], Training Loss: 0.834, Validation Accuracy: 59.71%
# Epoch [6/10], Training Loss: 0.802, Validation Accuracy: 59.07%
# Epoch [7/10], Training Loss: 0.790, Validation Accuracy: 59.67%
# Epoch [8/10], Training Loss: 0.769, Validation Accuracy: 59.21%
# Epoch [9/10], Training Loss: 0.754, Validation Accuracy: 59.29%
# Epoch [10/10], Training Loss: 0.734, Validation Accuracy: 59.24%
# Epoch [1/10], Training Loss: 0.999, Validation Accuracy: 59.21%
# Epoch [2/10], Training Loss: 0.927, Validation Accuracy: 59.35%
# Epoch [3/10], Training Loss: 0.878, Validation Accuracy: 59.34%
# Epoch [4/10], Training Loss: 0.853, Validation Accuracy: 58.78%
# Epoch [5/10], Training Loss: 0.832, Validation Accuracy: 59.79%
# Epoch [6/10], Training Loss: 0.802, Validation Accuracy: 59.34%
# Epoch [7/10], Training Loss: 0.784, Validation Accuracy: 59.45%
# Epoch [8/10], Training Loss: 0.763, Validation Accuracy: 59.16%
# Epoch [9/10], Training Loss: 0.738, Validation Accuracy: 59.29%
# Epoch [10/10], Training Loss: 0.734, Validation Accuracy: 58.86%
# Epoch [1/10], Training Loss: 0.986, Validation Accuracy: 59.61%
# Epoch [2/10], Training Loss: 0.912, Validation Accuracy: 59.48%
# Epoch [3/10], Training Loss: 0.873, Validation Accuracy: 59.60%
# Epoch [4/10], Training Loss: 0.839, Validation Accuracy: 59.96%
# Epoch [5/10], Training Loss: 0.820, Validation Accuracy: 59.31%
# Epoch [6/10], Training Loss: 0.791, Validation Accuracy: 59.66%
# Epoch [7/10], Training Loss: 0.770, Validation Accuracy: 59.39%
# Epoch [8/10], Training Loss: 0.757, Validation Accuracy: 59.16%
# Epoch [9/10], Training Loss: 0.742, Validation Accuracy: 59.32%
# Epoch [10/10], Training Loss: 0.713, Validation Accuracy: 59.08%
# Epoch [1/10], Training Loss: 0.975, Validation Accuracy: 59.61%
# Epoch [2/10], Training Loss: 0.898, Validation Accuracy: 59.79%
# Epoch [3/10], Training Loss: 0.853, Validation Accuracy: 59.77%
# Epoch [4/10], Training Loss: 0.810, Validation Accuracy: 59.20%
# Epoch [5/10], Training Loss: 0.784, Validation Accuracy: 59.70%
# Epoch [6/10], Training Loss: 0.761, Validation Accuracy: 60.02%
# Epoch [7/10], Training Loss: 0.737, Validation Accuracy: 59.32%
# Epoch [8/10], Training Loss: 0.721, Validation Accuracy: 59.82%
# Epoch [9/10], Training Loss: 0.693, Validation Accuracy: 59.05%
# Epoch [10/10], Training Loss: 0.687, Validation Accuracy: 59.90%
# Epoch [1/10], Training Loss: 0.942, Validation Accuracy: 59.42%
# Epoch [2/10], Training Loss: 0.860, Validation Accuracy: 59.83%
# Epoch [3/10], Training Loss: 0.814, Validation Accuracy: 59.64%
# Epoch [4/10], Training Loss: 0.788, Validation Accuracy: 59.07%
# Epoch [5/10], Training Loss: 0.765, Validation Accuracy: 60.07%
# Epoch [6/10], Training Loss: 0.731, Validation Accuracy: 59.81%
# Epoch [7/10], Training Loss: 0.712, Validation Accuracy: 60.17%
# Epoch [8/10], Training Loss: 0.690, Validation Accuracy: 59.72%
# Epoch [9/10], Training Loss: 0.669, Validation Accuracy: 59.41%
# Epoch [10/10], Training Loss: 0.651, Validation Accuracy: 59.58%
# Epoch [1/10], Training Loss: 0.944, Validation Accuracy: 60.15%
# Epoch [2/10], Training Loss: 0.861, Validation Accuracy: 59.83%
# Epoch [3/10], Training Loss: 0.805, Validation Accuracy: 59.33%
# Epoch [4/10], Training Loss: 0.775, Validation Accuracy: 58.88%
# Epoch [5/10], Training Loss: 0.747, Validation Accuracy: 60.12%
# Epoch [6/10], Training Loss: 0.714, Validation Accuracy: 59.53%
# Epoch [7/10], Training Loss: 0.699, Validation Accuracy: 59.66%
# Epoch [8/10], Training Loss: 0.675, Validation Accuracy: 59.47%
# Epoch [9/10], Training Loss: 0.658, Validation Accuracy: 59.80%
# Epoch [10/10], Training Loss: 0.632, Validation Accuracy: 58.87%
# Epoch [1/10], Training Loss: 0.957, Validation Accuracy: 59.36%
# Epoch [2/10], Training Loss: 0.869, Validation Accuracy: 59.97%
# Epoch [3/10], Training Loss: 0.806, Validation Accuracy: 58.75%
# Epoch [4/10], Training Loss: 0.773, Validation Accuracy: 59.28%
# Epoch [5/10], Training Loss: 0.741, Validation Accuracy: 59.39%
# Epoch [6/10], Training Loss: 0.714, Validation Accuracy: 59.46%
# Epoch [7/10], Training Loss: 0.687, Validation Accuracy: 59.30%
# Epoch [8/10], Training Loss: 0.664, Validation Accuracy: 59.23%
# Epoch [9/10], Training Loss: 0.641, Validation Accuracy: 59.26%
# Epoch [10/10], Training Loss: 0.624, Validation Accuracy: 58.51%
# Epoch [1/10], Training Loss: 0.961, Validation Accuracy: 58.45%
# Epoch [2/10], Training Loss: 0.857, Validation Accuracy: 59.73%
# Epoch [3/10], Training Loss: 0.795, Validation Accuracy: 59.88%
# Epoch [4/10], Training Loss: 0.761, Validation Accuracy: 58.89%
# Epoch [5/10], Training Loss: 0.727, Validation Accuracy: 59.08%
# Epoch [6/10], Training Loss: 0.702, Validation Accuracy: 59.10%
# Epoch [7/10], Training Loss: 0.671, Validation Accuracy: 58.85%
# Epoch [8/10], Training Loss: 0.650, Validation Accuracy: 59.00%
# Epoch [9/10], Training Loss: 0.634, Validation Accuracy: 59.36%
# Epoch [10/10], Training Loss: 0.618, Validation Accuracy: 59.21%
# Epoch [1/10], Training Loss: 0.927, Validation Accuracy: 59.36%
# Epoch [2/10], Training Loss: 0.828, Validation Accuracy: 59.64%
# Epoch [3/10], Training Loss: 0.770, Validation Accuracy: 59.67%
# Epoch [4/10], Training Loss: 0.725, Validation Accuracy: 59.55%
# Epoch [5/10], Training Loss: 0.698, Validation Accuracy: 59.87%
# Epoch [6/10], Training Loss: 0.674, Validation Accuracy: 60.03%
# Epoch [7/10], Training Loss: 0.640, Validation Accuracy: 59.04%
# Epoch [8/10], Training Loss: 0.629, Validation Accuracy: 59.09%
# Epoch [9/10], Training Loss: 0.605, Validation Accuracy: 59.30%
# Epoch [10/10], Training Loss: 0.586, Validation Accuracy: 59.18%
# Epoch [1/10], Training Loss: 0.893, Validation Accuracy: 59.44%
# Epoch [2/10], Training Loss: 0.802, Validation Accuracy: 58.82%
# Epoch [3/10], Training Loss: 0.754, Validation Accuracy: 59.74%
# Epoch [4/10], Training Loss: 0.700, Validation Accuracy: 59.74%
# Epoch [5/10], Training Loss: 0.675, Validation Accuracy: 59.97%
# Epoch [6/10], Training Loss: 0.644, Validation Accuracy: 59.31%
# Epoch [7/10], Training Loss: 0.620, Validation Accuracy: 59.94%
# Epoch [8/10], Training Loss: 0.611, Validation Accuracy: 59.56%
# Epoch [9/10], Training Loss: 0.584, Validation Accuracy: 59.60%
# Epoch [10/10], Training Loss: 0.555, Validation Accuracy: 59.66%
# Epoch [1/10], Training Loss: 0.902, Validation Accuracy: 59.28%
# Epoch [2/10], Training Loss: 0.790, Validation Accuracy: 59.65%
# Epoch [3/10], Training Loss: 0.736, Validation Accuracy: 59.47%
# Epoch [4/10], Training Loss: 0.692, Validation Accuracy: 59.59%
# Epoch [5/10], Training Loss: 0.667, Validation Accuracy: 60.01%
# Epoch [6/10], Training Loss: 0.633, Validation Accuracy: 59.94%
# Epoch [7/10], Training Loss: 0.605, Validation Accuracy: 59.07%
# Epoch [8/10], Training Loss: 0.583, Validation Accuracy: 59.43%
# Epoch [9/10], Training Loss: 0.558, Validation Accuracy: 59.03%
# Epoch [10/10], Training Loss: 0.534, Validation Accuracy: 58.99%
# Epoch [1/10], Training Loss: 0.918, Validation Accuracy: 59.04%
# Epoch [2/10], Training Loss: 0.798, Validation Accuracy: 59.25%
# Epoch [3/10], Training Loss: 0.728, Validation Accuracy: 59.45%
# Epoch [4/10], Training Loss: 0.683, Validation Accuracy: 59.77%
# Epoch [5/10], Training Loss: 0.654, Validation Accuracy: 58.75%
# Epoch [6/10], Training Loss: 0.617, Validation Accuracy: 57.98%
# Epoch [7/10], Training Loss: 0.601, Validation Accuracy: 59.62%
# Epoch [8/10], Training Loss: 0.574, Validation Accuracy: 58.88%
# Epoch [9/10], Training Loss: 0.557, Validation Accuracy: 59.14%
# Epoch [10/10], Training Loss: 0.529, Validation Accuracy: 58.58%
# Epoch [1/10], Training Loss: 0.896, Validation Accuracy: 59.39%
# Epoch [2/10], Training Loss: 0.785, Validation Accuracy: 58.92%
# Epoch [3/10], Training Loss: 0.722, Validation Accuracy: 59.44%
# Epoch [4/10], Training Loss: 0.674, Validation Accuracy: 59.50%
# Epoch [5/10], Training Loss: 0.635, Validation Accuracy: 59.26%
# Epoch [6/10], Training Loss: 0.604, Validation Accuracy: 59.51%
# Epoch [7/10], Training Loss: 0.581, Validation Accuracy: 59.23%
# Epoch [8/10], Training Loss: 0.554, Validation Accuracy: 59.44%
# Epoch [9/10], Training Loss: 0.531, Validation Accuracy: 59.17%
# Epoch [10/10], Training Loss: 0.518, Validation Accuracy: 58.89%
# Epoch [1/10], Training Loss: 0.882, Validation Accuracy: 58.93%
# Epoch [2/10], Training Loss: 0.758, Validation Accuracy: 59.11%
# Epoch [3/10], Training Loss: 0.689, Validation Accuracy: 59.25%
# Epoch [4/10], Training Loss: 0.643, Validation Accuracy: 59.25%
# Epoch [5/10], Training Loss: 0.613, Validation Accuracy: 59.23%
# Epoch [6/10], Training Loss: 0.584, Validation Accuracy: 60.10%
# Epoch [7/10], Training Loss: 0.548, Validation Accuracy: 59.11%
# Epoch [8/10], Training Loss: 0.528, Validation Accuracy: 59.24%
# Epoch [9/10], Training Loss: 0.505, Validation Accuracy: 59.35%
# Epoch [10/10], Training Loss: 0.492, Validation Accuracy: 59.14%
# Epoch [1/10], Training Loss: 0.857, Validation Accuracy: 59.48%
# Epoch [2/10], Training Loss: 0.726, Validation Accuracy: 60.04%
# Epoch [3/10], Training Loss: 0.668, Validation Accuracy: 59.95%
# Epoch [4/10], Training Loss: 0.624, Validation Accuracy: 59.17%
# Epoch [5/10], Training Loss: 0.591, Validation Accuracy: 59.59%
# Epoch [6/10], Training Loss: 0.552, Validation Accuracy: 59.58%
# Epoch [7/10], Training Loss: 0.529, Validation Accuracy: 58.97%
# Epoch [8/10], Training Loss: 0.503, Validation Accuracy: 59.57%
# Epoch [9/10], Training Loss: 0.488, Validation Accuracy: 58.94%
# Epoch [10/10], Training Loss: 0.473, Validation Accuracy: 58.92%
# Epoch [1/10], Training Loss: 0.871, Validation Accuracy: 58.69%
# Epoch [2/10], Training Loss: 0.727, Validation Accuracy: 58.73%
# Epoch [3/10], Training Loss: 0.660, Validation Accuracy: 59.74%
# Epoch [4/10], Training Loss: 0.609, Validation Accuracy: 59.23%
# Epoch [5/10], Training Loss: 0.574, Validation Accuracy: 59.52%
# Epoch [6/10], Training Loss: 0.543, Validation Accuracy: 59.62%
# Epoch [7/10], Training Loss: 0.518, Validation Accuracy: 59.80%
# Epoch [8/10], Training Loss: 0.477, Validation Accuracy: 58.82%
# Epoch [9/10], Training Loss: 0.465, Validation Accuracy: 58.97%
# Epoch [10/10], Training Loss: 0.439, Validation Accuracy: 59.10%
# Epoch [1/10], Training Loss: 0.873, Validation Accuracy: 58.31%
# Epoch [2/10], Training Loss: 0.738, Validation Accuracy: 58.66%
# Epoch [3/10], Training Loss: 0.660, Validation Accuracy: 58.96%
# Epoch [4/10], Training Loss: 0.600, Validation Accuracy: 59.24%
# Epoch [5/10], Training Loss: 0.569, Validation Accuracy: 58.83%
# Epoch [6/10], Training Loss: 0.533, Validation Accuracy: 59.20%
# Epoch [7/10], Training Loss: 0.500, Validation Accuracy: 58.68%
# Epoch [8/10], Training Loss: 0.489, Validation Accuracy: 59.29%
# Epoch [9/10], Training Loss: 0.457, Validation Accuracy: 58.63%
# Epoch [10/10], Training Loss: 0.436, Validation Accuracy: 58.58%
# Epoch [1/10], Training Loss: 0.855, Validation Accuracy: 59.30%
# Epoch [2/10], Training Loss: 0.710, Validation Accuracy: 59.16%
# Epoch [3/10], Training Loss: 0.633, Validation Accuracy: 59.25%
# Epoch [4/10], Training Loss: 0.595, Validation Accuracy: 59.21%
# Epoch [5/10], Training Loss: 0.551, Validation Accuracy: 59.63%
# Epoch [6/10], Training Loss: 0.511, Validation Accuracy: 59.17%
# Epoch [7/10], Training Loss: 0.482, Validation Accuracy: 58.76%
# Epoch [8/10], Training Loss: 0.469, Validation Accuracy: 59.33%
# Epoch [9/10], Training Loss: 0.437, Validation Accuracy: 58.32%
# Epoch [10/10], Training Loss: 0.411, Validation Accuracy: 58.72%
# Confusion Matrix:
# [[637  36 110  16  24   9   9  23  76  60]
#  [ 20 720  20  13   7   8   9   9  34 160]
#  [ 50  15 566  60  89  84  60  45  13  18]
#  [ 26  27 108 323  76 234  70  79  18  39]
#  [ 37  11 183  38 475  59  60 109  10  18]
#  [ 15  11  84 136  70 529  34  97   9  15]
#  [ 10  19  95  72  62  40 648  21   8  25]
#  [ 14  13  60  38  81 104   8 644   6  32]
#  [103  59  32  25  15  13   7   7 676  63]
#  [ 39 161  27  27  10  18  15  29  34 640]]
# Test Accuracy: 58.58%
# True Positives (TP): [637 720 566 323 475 529 648 644 676 640]
# False Positives (FP): [314 352 719 425 434 569 272 419 208 430]
# True Negatives (TN): [8686 8648 8281 8575 8566 8431 8728 8581 8792 8570]
# False Negatives (FN): [363 280 434 677 525 471 352 356 324 360]
# : [10000 10000 10000 10000 10000 10000 10000 10000 10000 10000]
# Precision: [0.66982124 0.67164179 0.44046693 0.43181818 0.52255226 0.48178506
#  0.70434783 0.60583255 0.76470588 0.59813084]
# Recall: [0.637 0.72  0.566 0.323 0.475 0.529 0.648 0.644 0.676 0.64 ]
# F1 Score: [0.65299846 0.69498069 0.49540481 0.36956522 0.49764274 0.5042898
#  0.675      0.62433349 0.71762208 0.61835749]

# %% [markdown]
# Beta=0.5

# %%
import numpy as np
from scipy.stats import truncnorm
import torch
import torchvision
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import Subset, DataLoader
from torchvision.datasets import CIFAR10
from typing import Dict, Tuple
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import random

# Define VAE model
class VAE(nn.Module):
    def __init__(self, x_dim, h_dim, z_dim):
        super(VAE, self).__init__()
        self.x_dim = x_dim
        self.h_dim = h_dim
        self.z_dim = z_dim

        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 32, 4, stride=2, padding=1),  # 16x16
            nn.ReLU(),
            nn.Conv2d(32, 64, 4, stride=2, padding=1),  # 8x8
            nn.ReLU(),
            nn.Conv2d(64, 128, 4, stride=2, padding=1),  # 4x4
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(2048, 256),
            nn.ReLU(),
            nn.Linear(256, 2*z_dim)
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(z_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 2048),
            nn.ReLU(),
            nn.Unflatten(1, (128, 4, 4)),
            nn.ConvTranspose2d(128, 64, 4, stride=2, padding=1),  # 8x8
            nn.ReLU(),
            nn.ConvTranspose2d(64, 32, 4, stride=2, padding=1),  # 16x16
            nn.ReLU(),
            nn.ConvTranspose2d(32, 3, 4, stride=2, padding=1),  # 32x32
            nn.Sigmoid()
        )

    def encode(self, x):
        h = self.encoder(x)
        mu, logvar = h[:, :self.z_dim], h[:, self.z_dim:]
        return mu, logvar

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z):
        return self.decoder(z)

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar


# Define VAE training procedure
def vae_train(vae: VAE, trainloader: DataLoader, epochs: int, beta: float =0.5):
    optimizer = torch.optim.Adam(vae.parameters(), lr=1e-3)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)

    for epoch in range(epochs):
        vae.train()
        for i, data in enumerate(trainloader, 0):
            inputs, _ = data
            optimizer.zero_grad()
            recon_x, mu, logvar = vae(inputs)
            loss = vae_loss(recon_x, inputs, mu, logvar , beta=beta)
            loss.backward()
            optimizer.step()

        scheduler.step()


# Define classification model
class Net(nn.Module):
    def __init__(self) -> None:
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.pool(nn.functional.relu(self.conv1(x)))
        x = self.pool(nn.functional.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = nn.functional.relu(self.fc1(x))
        x = nn.functional.relu(self.fc2(x))
        x = self.fc3(x)
        return x


# Load CIFAR10 dataset
transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]
)

full_dataset = CIFAR10(root="./data", train=True, download=True, transform=transform)
test_set = CIFAR10(root="./data", train=False, download=True, transform=transform)

# Separate dataset by class
class_indices = {i: [] for i in range(10)}  # CIFAR-10 has 10 classes
for idx, (_, label) in enumerate(full_dataset):
    class_indices[label].append(idx)

# Define target count per class, summing to 60,000 with random distribution
class_counts = np.random.multinomial(60000, [0.1] * 10)  # Adjust probabilities if you want specific class biases
print("Random Images per Class:", class_counts)

# Sample indices based on the specified class counts
indices = []
for class_id, count in enumerate(class_counts):
    # Ensure count does not exceed available images
    count = min(count, len(class_indices[class_id]))
    selected_indices = random.sample(class_indices[class_id], count)
    indices.extend(selected_indices)

# Create a custom CIFAR-10 dataset with the sampled indices
custom_dataset = Subset(full_dataset, indices)
# Split dataset into training and validation sets
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_set, val_set = torch.utils.data.random_split(full_dataset, [train_size, val_size])

# Create training and validation loaders
trainloader = DataLoader(train_set, batch_size=128, shuffle=True, num_workers=2)
valloader = DataLoader(val_set, batch_size=128, shuffle=False, num_workers=2)
testloader = DataLoader(test_set, batch_size=128, shuffle=False, num_workers=2)



# Define VAE loss function
def vae_loss(recon_x, x, mu, logvar, beta=0.5):
    BCE = nn.functional.mse_loss(recon_x, x, reduction='sum')
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return BCE + beta * KLD

# Define training procedure for classification model
def train(net: nn.Module, trainloader: DataLoader, valloader: DataLoader, epochs: int) -> None:
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)

    best_acc = 0.0

    for epoch in range(epochs):
        # Training loop
        net.train()
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            inputs, labels = data
            optimizer.zero_grad()
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        scheduler.step()

        # Validation loop
        net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data in valloader:
                images, labels = data
                outputs = net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_acc = 100 * correct / total
        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(net.state_dict(), 'best_model.pth')

        print(f"Epoch [{epoch+1}/{epochs}], Training Loss: {running_loss / (i+1):.3f}, Validation Accuracy: {val_acc:.2f}%")

# Define evaluation procedure
def evaluate(net: nn.Module, testloader: DataLoader) -> Tuple[float, np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
    net.eval()
    correct = 0
    total = 0
    all_labels = []
    all_predictions = []
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    accuracy = 100 * correct / total

    # Calculate confusion matrix
    cm = confusion_matrix(all_labels, all_predictions)
    print(f"Confusion Matrix:\n{cm}")

    # Calculate TP, FP, TN, FN for each class
    tp = np.diag(cm)
    fp = cm.sum(axis=0) - tp
    fn = cm.sum(axis=1) - tp
    tn = cm.sum() - (fp + fn + tp)

    # Calculate precision, recall, and F1 score for each class
    precision = precision_score(all_labels, all_predictions, average=None)
    recall = recall_score(all_labels, all_predictions, average=None)
    f1 = f1_score(all_labels, all_predictions, average=None)

    return accuracy, tp, fp, tn, fn, precision, recall, f1

# Initialize clients
def initialize_clients(trainset, transform, batch_size, num_clients):
    clients = {}
    for i in range(num_clients):
        client_trainset = torch.utils.data.Subset(trainset, range(i * len(trainset) // num_clients, (i + 1) * len(trainset) // num_clients))
        client_trainloader = torch.utils.data.DataLoader(client_trainset, batch_size=batch_size, shuffle=True)
        clients[f"client_{i}"] = client_trainloader
    return clients

def get_distribution_info(vae: VAE) -> Dict:
    # Implement the logic to extract distribution information from the VAE
    # This can involve computing statistics, parameters, or any other relevant information
    # that can be used to generate augmented data

    # Example implementation:
    distribution_info = {
        "uniform": {
            "mean": vae.encoder[-1].bias.data.cpu().numpy(),
            "std": torch.exp(0.5 * vae.encoder[-1].weight.data).cpu().numpy()
        },
        "normal": {
            "mean": vae.encoder[-1].bias.data.cpu().numpy(),
            "std": torch.exp(0.5 * vae.encoder[-1].weight.data).cpu().numpy()
        }
    }

    return distribution_info

def send_distribution_info(distribution_info: Dict) -> None:
    # Implement the logic to send the distribution information to the global server
    # This can involve using a network protocol, a message queue, or any other communication mechanism
    # to send the information

    # Example implementation:
    # Send the distribution information to the global server using a network protocol
    # For example, you can use the `socket` module to send the information over a network
    # or use a message queue like `RabbitMQ` to send the information
    pass

def generate_augmented_data(vae: VAE, distribution_info_uniform: Dict, distribution_info_normal: Dict) -> torch.Tensor:
    # Generate augmented data using both uniform and truncated uniform distributions

    mean = distribution_info_uniform["mean"].mean().item()  # Convert numpy array to float
    std = distribution_info_uniform["std"].mean().item()  # Convert numpy array to float


    mean_normal = distribution_info_normal["mean"]
    std_normal = distribution_info_normal["std"]

    augmented_data_normal = torch.randn(64, vae.z_dim) * std_normal + mean_normal

     # Generate augmented data using Uniform distribution
    augmented_data_uniform = torch.FloatTensor(64, vae.z_dim).uniform_(mean - std, mean + std)


    # Calculate the average of augmented data from both distributions
    augmented_data_average = (augmented_data_uniform + augmented_data_normal ) / 2

    return augmented_data_average

def federated_train(net: nn.Module, vae: VAE, trainloaders: Dict[str, DataLoader], trainloader: DataLoader, valloader: DataLoader, epochs: int) -> None:
    for epoch in range(epochs):
        for client_id, client_trainloader in trainloaders.items():
            # Train VAE on client data
            vae_train(vae, client_trainloader, epochs=10, beta=0.5)

            # Share distribution information with global server
            distribution_info = get_distribution_info(vae)
            send_distribution_info(distribution_info)

            # Receive distribution information from other clients
            other_distribution_info = receive_distribution_info()

            # Generate augmented data using received distribution information
            augmented_data = generate_augmented_data(vae, other_distribution_info["uniform"], other_distribution_info["normal"])

            # Train classification model using local, augmented, and validation data
            train(net, client_trainloader, valloader, epochs=10)

            # Send model updates to global server
            send_model_update(client_id, net.state_dict())

# Define logic to receive distribution information from global server
def receive_distribution_info() -> Dict:
    # Receive distribution information logic
    distribution_info = {
        "uniform": {
            "mean": np.zeros(20),  # Adjust the size based on your latent space dimension
            "std": np.ones(20)
        },
        "normal": {
            "mean": np.zeros(20),  # Adjust the size based on your latent space dimension
            "std": np.ones(20)
        }
    }
    return distribution_info

def send_model_update(client_id: str, model_update: Dict) -> None:
    # Implement the logic to send the model update to the global server
    # This can involve using a network protocol, a message queue, or any other communication mechanism
    # to send the model update

    # Example implementation:
    # Send the model update to the global server using a network protocol
    # For example, you can use the `socket` module to send the information over a network
    # or use a message queue like `RabbitMQ` to send the information
    pass

# Define global server procedure
def global_server() -> None:
    net = Net()
    x_dim = 3 * 32 * 32  # CIFAR-10 input size
    h_dim = 400
    z_dim = 20
    vae = VAE(x_dim, h_dim, z_dim)  # Initialize VAE object with required arguments

    # Initialize clients
    num_clients = 5  # Define the number of clients
    clients = initialize_clients(train_set, transform, batch_size=128, num_clients=num_clients)

    # Train model using FedDIS
    federated_train(net, vae, clients, trainloader, valloader, epochs=10)

    # Evaluate final model
    test_accuracy, tp, fp, tn, fn, precision, recall, f1 = evaluate(net, testloader)
    print(f"Test Accuracy: {test_accuracy:.2f}%")

    print("True Positives (TP):", tp)
    print("False Positives (FP):", fp)
    print("True Negatives (TN):", tn)
    print("False Negatives (FN):", fn)
    print(":", fn+tn+tp+fp)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)

if __name__ == "__main__":
    global_server()
# Out:
# 100%|██████████| 170M/170M [00:03<00:00, 49.4MB/s]
# Random Images per Class: [6005 6011 5989 5957 6090 5899 5775 6141 6052 6081]
# /tmp/ipython-input-1-3287870634.py:280: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   augmented_data_normal = torch.randn(64, vae.z_dim) * std_normal + mean_normal
# Epoch [1/10], Training Loss: 2.304, Validation Accuracy: 10.05%
# Epoch [2/10], Training Loss: 2.303, Validation Accuracy: 10.30%
# Epoch [3/10], Training Loss: 2.302, Validation Accuracy: 10.48%
# Epoch [4/10], Training Loss: 2.301, Validation Accuracy: 11.04%
# Epoch [5/10], Training Loss: 2.300, Validation Accuracy: 11.52%
# Epoch [6/10], Training Loss: 2.299, Validation Accuracy: 12.15%
# Epoch [7/10], Training Loss: 2.297, Validation Accuracy: 12.27%
# Epoch [8/10], Training Loss: 2.296, Validation Accuracy: 12.58%
# Epoch [9/10], Training Loss: 2.294, Validation Accuracy: 13.41%
# Epoch [10/10], Training Loss: 2.292, Validation Accuracy: 13.73%
# Epoch [1/10], Training Loss: 2.290, Validation Accuracy: 14.22%
# Epoch [2/10], Training Loss: 2.286, Validation Accuracy: 15.33%
# Epoch [3/10], Training Loss: 2.280, Validation Accuracy: 17.26%
# Epoch [4/10], Training Loss: 2.272, Validation Accuracy: 18.16%
# Epoch [5/10], Training Loss: 2.259, Validation Accuracy: 19.71%
# Epoch [6/10], Training Loss: 2.239, Validation Accuracy: 21.32%
# Epoch [7/10], Training Loss: 2.206, Validation Accuracy: 21.90%
# Epoch [8/10], Training Loss: 2.163, Validation Accuracy: 22.28%
# Epoch [9/10], Training Loss: 2.122, Validation Accuracy: 23.17%
# Epoch [10/10], Training Loss: 2.097, Validation Accuracy: 23.79%
# Epoch [1/10], Training Loss: 2.081, Validation Accuracy: 25.30%
# Epoch [2/10], Training Loss: 2.064, Validation Accuracy: 25.65%
# Epoch [3/10], Training Loss: 2.048, Validation Accuracy: 26.55%
# Epoch [4/10], Training Loss: 2.032, Validation Accuracy: 27.48%
# Epoch [5/10], Training Loss: 2.017, Validation Accuracy: 28.04%
# Epoch [6/10], Training Loss: 2.001, Validation Accuracy: 28.67%
# Epoch [7/10], Training Loss: 1.987, Validation Accuracy: 28.71%
# Epoch [8/10], Training Loss: 1.970, Validation Accuracy: 29.48%
# Epoch [9/10], Training Loss: 1.953, Validation Accuracy: 29.58%
# Epoch [10/10], Training Loss: 1.936, Validation Accuracy: 30.67%
# Epoch [1/10], Training Loss: 1.933, Validation Accuracy: 30.66%
# Epoch [2/10], Training Loss: 1.907, Validation Accuracy: 31.39%
# Epoch [3/10], Training Loss: 1.883, Validation Accuracy: 31.88%
# Epoch [4/10], Training Loss: 1.856, Validation Accuracy: 32.36%
# Epoch [5/10], Training Loss: 1.840, Validation Accuracy: 31.80%
# Epoch [6/10], Training Loss: 1.821, Validation Accuracy: 33.79%
# Epoch [7/10], Training Loss: 1.798, Validation Accuracy: 33.18%
# Epoch [8/10], Training Loss: 1.779, Validation Accuracy: 34.43%
# Epoch [9/10], Training Loss: 1.755, Validation Accuracy: 35.23%
# Epoch [10/10], Training Loss: 1.739, Validation Accuracy: 36.22%
# Epoch [1/10], Training Loss: 1.771, Validation Accuracy: 36.45%
# Epoch [2/10], Training Loss: 1.751, Validation Accuracy: 37.11%
# Epoch [3/10], Training Loss: 1.728, Validation Accuracy: 37.79%
# Epoch [4/10], Training Loss: 1.710, Validation Accuracy: 38.58%
# Epoch [5/10], Training Loss: 1.692, Validation Accuracy: 39.16%
# Epoch [6/10], Training Loss: 1.677, Validation Accuracy: 38.82%
# Epoch [7/10], Training Loss: 1.651, Validation Accuracy: 38.94%
# Epoch [8/10], Training Loss: 1.643, Validation Accuracy: 40.10%
# Epoch [9/10], Training Loss: 1.622, Validation Accuracy: 39.73%
# Epoch [10/10], Training Loss: 1.614, Validation Accuracy: 40.75%
# Epoch [1/10], Training Loss: 1.627, Validation Accuracy: 41.68%
# Epoch [2/10], Training Loss: 1.609, Validation Accuracy: 41.67%
# Epoch [3/10], Training Loss: 1.598, Validation Accuracy: 41.82%
# Epoch [4/10], Training Loss: 1.580, Validation Accuracy: 42.35%
# Epoch [5/10], Training Loss: 1.565, Validation Accuracy: 41.53%
# Epoch [6/10], Training Loss: 1.551, Validation Accuracy: 43.13%
# Epoch [7/10], Training Loss: 1.542, Validation Accuracy: 42.82%
# Epoch [8/10], Training Loss: 1.535, Validation Accuracy: 43.46%
# Epoch [9/10], Training Loss: 1.522, Validation Accuracy: 43.55%
# Epoch [10/10], Training Loss: 1.512, Validation Accuracy: 43.87%
# Epoch [1/10], Training Loss: 1.546, Validation Accuracy: 43.89%
# Epoch [2/10], Training Loss: 1.531, Validation Accuracy: 43.87%
# Epoch [3/10], Training Loss: 1.516, Validation Accuracy: 43.97%
# Epoch [4/10], Training Loss: 1.505, Validation Accuracy: 45.04%
# Epoch [5/10], Training Loss: 1.490, Validation Accuracy: 45.63%
# Epoch [6/10], Training Loss: 1.482, Validation Accuracy: 45.19%
# Epoch [7/10], Training Loss: 1.473, Validation Accuracy: 45.47%
# Epoch [8/10], Training Loss: 1.460, Validation Accuracy: 45.83%
# Epoch [9/10], Training Loss: 1.456, Validation Accuracy: 45.58%
# Epoch [10/10], Training Loss: 1.449, Validation Accuracy: 45.99%
# Epoch [1/10], Training Loss: 1.481, Validation Accuracy: 46.22%
# Epoch [2/10], Training Loss: 1.465, Validation Accuracy: 47.02%
# Epoch [3/10], Training Loss: 1.445, Validation Accuracy: 46.24%
# Epoch [4/10], Training Loss: 1.435, Validation Accuracy: 46.92%
# Epoch [5/10], Training Loss: 1.429, Validation Accuracy: 46.84%
# Epoch [6/10], Training Loss: 1.411, Validation Accuracy: 46.69%
# Epoch [7/10], Training Loss: 1.402, Validation Accuracy: 47.27%
# Epoch [8/10], Training Loss: 1.397, Validation Accuracy: 46.92%
# Epoch [9/10], Training Loss: 1.389, Validation Accuracy: 46.67%
# Epoch [10/10], Training Loss: 1.376, Validation Accuracy: 47.50%
# Epoch [1/10], Training Loss: 1.429, Validation Accuracy: 47.64%
# Epoch [2/10], Training Loss: 1.418, Validation Accuracy: 47.04%
# Epoch [3/10], Training Loss: 1.397, Validation Accuracy: 48.52%
# Epoch [4/10], Training Loss: 1.387, Validation Accuracy: 48.16%
# Epoch [5/10], Training Loss: 1.378, Validation Accuracy: 48.20%
# Epoch [6/10], Training Loss: 1.361, Validation Accuracy: 48.81%
# Epoch [7/10], Training Loss: 1.349, Validation Accuracy: 48.81%
# Epoch [8/10], Training Loss: 1.348, Validation Accuracy: 48.46%
# Epoch [9/10], Training Loss: 1.334, Validation Accuracy: 48.69%
# Epoch [10/10], Training Loss: 1.324, Validation Accuracy: 49.91%
# Epoch [1/10], Training Loss: 1.418, Validation Accuracy: 49.68%
# Epoch [2/10], Training Loss: 1.401, Validation Accuracy: 49.37%
# Epoch [3/10], Training Loss: 1.382, Validation Accuracy: 48.77%
# Epoch [4/10], Training Loss: 1.368, Validation Accuracy: 49.44%
# Epoch [5/10], Training Loss: 1.348, Validation Accuracy: 49.51%
# Epoch [6/10], Training Loss: 1.343, Validation Accuracy: 49.07%
# Epoch [7/10], Training Loss: 1.337, Validation Accuracy: 49.46%
# Epoch [8/10], Training Loss: 1.324, Validation Accuracy: 50.35%
# Epoch [9/10], Training Loss: 1.317, Validation Accuracy: 49.55%
# Epoch [10/10], Training Loss: 1.310, Validation Accuracy: 49.76%
# Epoch [1/10], Training Loss: 1.387, Validation Accuracy: 49.41%
# Epoch [2/10], Training Loss: 1.360, Validation Accuracy: 50.24%
# Epoch [3/10], Training Loss: 1.338, Validation Accuracy: 50.60%
# Epoch [4/10], Training Loss: 1.334, Validation Accuracy: 50.70%
# Epoch [5/10], Training Loss: 1.320, Validation Accuracy: 50.01%
# Epoch [6/10], Training Loss: 1.303, Validation Accuracy: 50.28%
# Epoch [7/10], Training Loss: 1.294, Validation Accuracy: 49.88%
# Epoch [8/10], Training Loss: 1.297, Validation Accuracy: 50.39%
# Epoch [9/10], Training Loss: 1.278, Validation Accuracy: 50.16%
# Epoch [10/10], Training Loss: 1.263, Validation Accuracy: 50.86%
# Epoch [1/10], Training Loss: 1.352, Validation Accuracy: 50.82%
# Epoch [2/10], Training Loss: 1.326, Validation Accuracy: 50.72%
# Epoch [3/10], Training Loss: 1.306, Validation Accuracy: 50.52%
# Epoch [4/10], Training Loss: 1.301, Validation Accuracy: 51.60%
# Epoch [5/10], Training Loss: 1.284, Validation Accuracy: 51.06%
# Epoch [6/10], Training Loss: 1.270, Validation Accuracy: 51.96%
# Epoch [7/10], Training Loss: 1.270, Validation Accuracy: 51.36%
# Epoch [8/10], Training Loss: 1.253, Validation Accuracy: 50.72%
# Epoch [9/10], Training Loss: 1.244, Validation Accuracy: 51.75%
# Epoch [10/10], Training Loss: 1.247, Validation Accuracy: 50.89%
# Epoch [1/10], Training Loss: 1.319, Validation Accuracy: 52.20%
# Epoch [2/10], Training Loss: 1.287, Validation Accuracy: 51.61%
# Epoch [3/10], Training Loss: 1.268, Validation Accuracy: 51.49%
# Epoch [4/10], Training Loss: 1.248, Validation Accuracy: 52.14%
# Epoch [5/10], Training Loss: 1.245, Validation Accuracy: 51.99%
# Epoch [6/10], Training Loss: 1.226, Validation Accuracy: 51.84%
# Epoch [7/10], Training Loss: 1.220, Validation Accuracy: 51.32%
# Epoch [8/10], Training Loss: 1.205, Validation Accuracy: 51.48%
# Epoch [9/10], Training Loss: 1.192, Validation Accuracy: 52.19%
# Epoch [10/10], Training Loss: 1.190, Validation Accuracy: 51.85%
# Epoch [1/10], Training Loss: 1.291, Validation Accuracy: 52.25%
# Epoch [2/10], Training Loss: 1.259, Validation Accuracy: 52.34%
# Epoch [3/10], Training Loss: 1.240, Validation Accuracy: 52.92%
# Epoch [4/10], Training Loss: 1.227, Validation Accuracy: 52.58%
# Epoch [5/10], Training Loss: 1.206, Validation Accuracy: 53.43%
# Epoch [6/10], Training Loss: 1.194, Validation Accuracy: 53.05%
# Epoch [7/10], Training Loss: 1.188, Validation Accuracy: 52.10%
# Epoch [8/10], Training Loss: 1.173, Validation Accuracy: 52.40%
# Epoch [9/10], Training Loss: 1.165, Validation Accuracy: 51.69%
# Epoch [10/10], Training Loss: 1.150, Validation Accuracy: 53.43%
# Epoch [1/10], Training Loss: 1.290, Validation Accuracy: 53.34%
# Epoch [2/10], Training Loss: 1.250, Validation Accuracy: 53.20%
# Epoch [3/10], Training Loss: 1.234, Validation Accuracy: 52.61%
# Epoch [4/10], Training Loss: 1.215, Validation Accuracy: 53.42%
# Epoch [5/10], Training Loss: 1.204, Validation Accuracy: 53.27%
# Epoch [6/10], Training Loss: 1.184, Validation Accuracy: 53.00%
# Epoch [7/10], Training Loss: 1.168, Validation Accuracy: 53.38%
# Epoch [8/10], Training Loss: 1.153, Validation Accuracy: 53.90%
# Epoch [9/10], Training Loss: 1.146, Validation Accuracy: 53.71%
# Epoch [10/10], Training Loss: 1.128, Validation Accuracy: 53.09%
# Epoch [1/10], Training Loss: 1.266, Validation Accuracy: 53.55%
# Epoch [2/10], Training Loss: 1.242, Validation Accuracy: 53.93%
# Epoch [3/10], Training Loss: 1.205, Validation Accuracy: 53.81%
# Epoch [4/10], Training Loss: 1.193, Validation Accuracy: 54.20%
# Epoch [5/10], Training Loss: 1.176, Validation Accuracy: 54.04%
# Epoch [6/10], Training Loss: 1.160, Validation Accuracy: 53.37%
# Epoch [7/10], Training Loss: 1.150, Validation Accuracy: 53.53%
# Epoch [8/10], Training Loss: 1.131, Validation Accuracy: 53.73%
# Epoch [9/10], Training Loss: 1.125, Validation Accuracy: 53.83%
# Epoch [10/10], Training Loss: 1.109, Validation Accuracy: 53.76%
# Epoch [1/10], Training Loss: 1.252, Validation Accuracy: 54.04%
# Epoch [2/10], Training Loss: 1.212, Validation Accuracy: 52.55%
# Epoch [3/10], Training Loss: 1.196, Validation Accuracy: 54.57%
# Epoch [4/10], Training Loss: 1.169, Validation Accuracy: 53.61%
# Epoch [5/10], Training Loss: 1.153, Validation Accuracy: 54.75%
# Epoch [6/10], Training Loss: 1.138, Validation Accuracy: 54.64%
# Epoch [7/10], Training Loss: 1.122, Validation Accuracy: 54.42%
# Epoch [8/10], Training Loss: 1.106, Validation Accuracy: 54.75%
# Epoch [9/10], Training Loss: 1.097, Validation Accuracy: 54.69%
# Epoch [10/10], Training Loss: 1.089, Validation Accuracy: 54.52%
# Epoch [1/10], Training Loss: 1.214, Validation Accuracy: 54.14%
# Epoch [2/10], Training Loss: 1.171, Validation Accuracy: 55.19%
# Epoch [3/10], Training Loss: 1.148, Validation Accuracy: 54.87%
# Epoch [4/10], Training Loss: 1.119, Validation Accuracy: 54.78%
# Epoch [5/10], Training Loss: 1.105, Validation Accuracy: 55.00%
# Epoch [6/10], Training Loss: 1.097, Validation Accuracy: 54.58%
# Epoch [7/10], Training Loss: 1.082, Validation Accuracy: 54.32%
# Epoch [8/10], Training Loss: 1.067, Validation Accuracy: 54.80%
# Epoch [9/10], Training Loss: 1.049, Validation Accuracy: 54.64%
# Epoch [10/10], Training Loss: 1.045, Validation Accuracy: 54.75%
# Epoch [1/10], Training Loss: 1.192, Validation Accuracy: 54.07%
# Epoch [2/10], Training Loss: 1.149, Validation Accuracy: 55.71%
# Epoch [3/10], Training Loss: 1.115, Validation Accuracy: 55.36%
# Epoch [4/10], Training Loss: 1.109, Validation Accuracy: 55.14%
# Epoch [5/10], Training Loss: 1.076, Validation Accuracy: 55.37%
# Epoch [6/10], Training Loss: 1.069, Validation Accuracy: 55.33%
# Epoch [7/10], Training Loss: 1.049, Validation Accuracy: 55.13%
# Epoch [8/10], Training Loss: 1.028, Validation Accuracy: 54.37%
# Epoch [9/10], Training Loss: 1.028, Validation Accuracy: 55.44%
# Epoch [10/10], Training Loss: 1.009, Validation Accuracy: 54.63%
# Epoch [1/10], Training Loss: 1.195, Validation Accuracy: 55.84%
# Epoch [2/10], Training Loss: 1.140, Validation Accuracy: 56.20%
# Epoch [3/10], Training Loss: 1.103, Validation Accuracy: 55.91%
# Epoch [4/10], Training Loss: 1.089, Validation Accuracy: 55.71%
# Epoch [5/10], Training Loss: 1.060, Validation Accuracy: 55.47%
# Epoch [6/10], Training Loss: 1.045, Validation Accuracy: 55.55%
# Epoch [7/10], Training Loss: 1.031, Validation Accuracy: 55.16%
# Epoch [8/10], Training Loss: 1.020, Validation Accuracy: 55.83%
# Epoch [9/10], Training Loss: 1.007, Validation Accuracy: 55.56%
# Epoch [10/10], Training Loss: 0.988, Validation Accuracy: 55.43%
# Epoch [1/10], Training Loss: 1.184, Validation Accuracy: 54.29%
# Epoch [2/10], Training Loss: 1.136, Validation Accuracy: 55.80%
# Epoch [3/10], Training Loss: 1.096, Validation Accuracy: 55.84%
# Epoch [4/10], Training Loss: 1.077, Validation Accuracy: 55.77%
# Epoch [5/10], Training Loss: 1.061, Validation Accuracy: 56.20%
# Epoch [6/10], Training Loss: 1.038, Validation Accuracy: 55.49%
# Epoch [7/10], Training Loss: 1.026, Validation Accuracy: 55.80%
# Epoch [8/10], Training Loss: 1.010, Validation Accuracy: 54.75%
# Epoch [9/10], Training Loss: 0.996, Validation Accuracy: 55.50%
# Epoch [10/10], Training Loss: 0.975, Validation Accuracy: 56.19%
# Epoch [1/10], Training Loss: 1.160, Validation Accuracy: 55.93%
# Epoch [2/10], Training Loss: 1.112, Validation Accuracy: 56.49%
# Epoch [3/10], Training Loss: 1.074, Validation Accuracy: 56.53%
# Epoch [4/10], Training Loss: 1.053, Validation Accuracy: 57.02%
# Epoch [5/10], Training Loss: 1.031, Validation Accuracy: 56.48%
# Epoch [6/10], Training Loss: 1.017, Validation Accuracy: 57.25%
# Epoch [7/10], Training Loss: 0.993, Validation Accuracy: 57.03%
# Epoch [8/10], Training Loss: 0.985, Validation Accuracy: 56.64%
# Epoch [9/10], Training Loss: 0.970, Validation Accuracy: 56.83%
# Epoch [10/10], Training Loss: 0.955, Validation Accuracy: 56.35%
# Epoch [1/10], Training Loss: 1.132, Validation Accuracy: 57.01%
# Epoch [2/10], Training Loss: 1.068, Validation Accuracy: 57.28%
# Epoch [3/10], Training Loss: 1.042, Validation Accuracy: 56.82%
# Epoch [4/10], Training Loss: 1.019, Validation Accuracy: 56.80%
# Epoch [5/10], Training Loss: 0.992, Validation Accuracy: 56.11%
# Epoch [6/10], Training Loss: 0.980, Validation Accuracy: 56.53%
# Epoch [7/10], Training Loss: 0.959, Validation Accuracy: 57.28%
# Epoch [8/10], Training Loss: 0.936, Validation Accuracy: 56.82%
# Epoch [9/10], Training Loss: 0.921, Validation Accuracy: 56.05%
# Epoch [10/10], Training Loss: 0.910, Validation Accuracy: 56.45%
# Epoch [1/10], Training Loss: 1.110, Validation Accuracy: 57.60%
# Epoch [2/10], Training Loss: 1.056, Validation Accuracy: 56.96%
# Epoch [3/10], Training Loss: 1.025, Validation Accuracy: 56.64%
# Epoch [4/10], Training Loss: 0.997, Validation Accuracy: 57.11%
# Epoch [5/10], Training Loss: 0.959, Validation Accuracy: 56.55%
# Epoch [6/10], Training Loss: 0.956, Validation Accuracy: 56.04%
# Epoch [7/10], Training Loss: 0.935, Validation Accuracy: 56.67%
# Epoch [8/10], Training Loss: 0.918, Validation Accuracy: 57.01%
# Epoch [9/10], Training Loss: 0.885, Validation Accuracy: 56.33%
# Epoch [10/10], Training Loss: 0.872, Validation Accuracy: 56.64%
# Epoch [1/10], Training Loss: 1.101, Validation Accuracy: 57.31%
# Epoch [2/10], Training Loss: 1.052, Validation Accuracy: 57.29%
# Epoch [3/10], Training Loss: 1.002, Validation Accuracy: 57.50%
# Epoch [4/10], Training Loss: 0.969, Validation Accuracy: 56.70%
# Epoch [5/10], Training Loss: 0.952, Validation Accuracy: 56.98%
# Epoch [6/10], Training Loss: 0.923, Validation Accuracy: 56.41%
# Epoch [7/10], Training Loss: 0.906, Validation Accuracy: 56.64%
# Epoch [8/10], Training Loss: 0.893, Validation Accuracy: 56.20%
# Epoch [9/10], Training Loss: 0.878, Validation Accuracy: 56.42%
# Epoch [10/10], Training Loss: 0.859, Validation Accuracy: 56.74%
# Epoch [1/10], Training Loss: 1.110, Validation Accuracy: 57.51%
# Epoch [2/10], Training Loss: 1.039, Validation Accuracy: 56.67%
# Epoch [3/10], Training Loss: 1.003, Validation Accuracy: 57.74%
# Epoch [4/10], Training Loss: 0.974, Validation Accuracy: 57.24%
# Epoch [5/10], Training Loss: 0.950, Validation Accuracy: 57.65%
# Epoch [6/10], Training Loss: 0.932, Validation Accuracy: 56.46%
# Epoch [7/10], Training Loss: 0.916, Validation Accuracy: 57.64%
# Epoch [8/10], Training Loss: 0.894, Validation Accuracy: 56.75%
# Epoch [9/10], Training Loss: 0.878, Validation Accuracy: 56.81%
# Epoch [10/10], Training Loss: 0.859, Validation Accuracy: 56.91%
# Epoch [1/10], Training Loss: 1.094, Validation Accuracy: 56.70%
# Epoch [2/10], Training Loss: 1.013, Validation Accuracy: 57.45%
# Epoch [3/10], Training Loss: 0.979, Validation Accuracy: 57.41%
# Epoch [4/10], Training Loss: 0.947, Validation Accuracy: 57.59%
# Epoch [5/10], Training Loss: 0.916, Validation Accuracy: 57.40%
# Epoch [6/10], Training Loss: 0.896, Validation Accuracy: 57.77%
# Epoch [7/10], Training Loss: 0.880, Validation Accuracy: 57.40%
# Epoch [8/10], Training Loss: 0.859, Validation Accuracy: 57.59%
# Epoch [9/10], Training Loss: 0.846, Validation Accuracy: 57.07%
# Epoch [10/10], Training Loss: 0.834, Validation Accuracy: 56.97%
# Epoch [1/10], Training Loss: 1.069, Validation Accuracy: 57.67%
# Epoch [2/10], Training Loss: 0.987, Validation Accuracy: 58.17%
# Epoch [3/10], Training Loss: 0.950, Validation Accuracy: 58.02%
# Epoch [4/10], Training Loss: 0.919, Validation Accuracy: 57.33%
# Epoch [5/10], Training Loss: 0.890, Validation Accuracy: 57.04%
# Epoch [6/10], Training Loss: 0.858, Validation Accuracy: 57.73%
# Epoch [7/10], Training Loss: 0.843, Validation Accuracy: 57.00%
# Epoch [8/10], Training Loss: 0.826, Validation Accuracy: 57.26%
# Epoch [9/10], Training Loss: 0.802, Validation Accuracy: 56.96%
# Epoch [10/10], Training Loss: 0.789, Validation Accuracy: 57.25%
# Epoch [1/10], Training Loss: 1.055, Validation Accuracy: 58.10%
# Epoch [2/10], Training Loss: 0.966, Validation Accuracy: 57.38%
# Epoch [3/10], Training Loss: 0.918, Validation Accuracy: 57.99%
# Epoch [4/10], Training Loss: 0.892, Validation Accuracy: 57.13%
# Epoch [5/10], Training Loss: 0.871, Validation Accuracy: 57.83%
# Epoch [6/10], Training Loss: 0.837, Validation Accuracy: 57.73%
# Epoch [7/10], Training Loss: 0.822, Validation Accuracy: 57.91%
# Epoch [8/10], Training Loss: 0.803, Validation Accuracy: 57.49%
# Epoch [9/10], Training Loss: 0.781, Validation Accuracy: 56.71%
# Epoch [10/10], Training Loss: 0.759, Validation Accuracy: 57.58%
# Epoch [1/10], Training Loss: 1.046, Validation Accuracy: 57.35%
# Epoch [2/10], Training Loss: 0.955, Validation Accuracy: 57.44%
# Epoch [3/10], Training Loss: 0.908, Validation Accuracy: 57.99%
# Epoch [4/10], Training Loss: 0.873, Validation Accuracy: 57.96%
# Epoch [5/10], Training Loss: 0.838, Validation Accuracy: 57.42%
# Epoch [6/10], Training Loss: 0.829, Validation Accuracy: 57.40%
# Epoch [7/10], Training Loss: 0.799, Validation Accuracy: 56.87%
# Epoch [8/10], Training Loss: 0.779, Validation Accuracy: 57.99%
# Epoch [9/10], Training Loss: 0.762, Validation Accuracy: 57.23%
# Epoch [10/10], Training Loss: 0.736, Validation Accuracy: 57.05%
# Epoch [1/10], Training Loss: 1.068, Validation Accuracy: 57.67%
# Epoch [2/10], Training Loss: 0.967, Validation Accuracy: 57.74%
# Epoch [3/10], Training Loss: 0.926, Validation Accuracy: 58.11%
# Epoch [4/10], Training Loss: 0.888, Validation Accuracy: 57.35%
# Epoch [5/10], Training Loss: 0.862, Validation Accuracy: 58.14%
# Epoch [6/10], Training Loss: 0.835, Validation Accuracy: 57.65%
# Epoch [7/10], Training Loss: 0.809, Validation Accuracy: 58.19%
# Epoch [8/10], Training Loss: 0.785, Validation Accuracy: 57.80%
# Epoch [9/10], Training Loss: 0.766, Validation Accuracy: 57.60%
# Epoch [10/10], Training Loss: 0.753, Validation Accuracy: 57.52%
# Epoch [1/10], Training Loss: 1.019, Validation Accuracy: 57.98%
# Epoch [2/10], Training Loss: 0.927, Validation Accuracy: 58.68%
# Epoch [3/10], Training Loss: 0.876, Validation Accuracy: 58.52%
# Epoch [4/10], Training Loss: 0.841, Validation Accuracy: 58.46%
# Epoch [5/10], Training Loss: 0.810, Validation Accuracy: 57.78%
# Epoch [6/10], Training Loss: 0.789, Validation Accuracy: 57.67%
# Epoch [7/10], Training Loss: 0.768, Validation Accuracy: 58.01%
# Epoch [8/10], Training Loss: 0.747, Validation Accuracy: 58.13%
# Epoch [9/10], Training Loss: 0.720, Validation Accuracy: 57.63%
# Epoch [10/10], Training Loss: 0.704, Validation Accuracy: 57.99%
# Epoch [1/10], Training Loss: 1.003, Validation Accuracy: 57.62%
# Epoch [2/10], Training Loss: 0.905, Validation Accuracy: 57.64%
# Epoch [3/10], Training Loss: 0.852, Validation Accuracy: 57.68%
# Epoch [4/10], Training Loss: 0.822, Validation Accuracy: 58.38%
# Epoch [5/10], Training Loss: 0.790, Validation Accuracy: 58.26%
# Epoch [6/10], Training Loss: 0.761, Validation Accuracy: 58.14%
# Epoch [7/10], Training Loss: 0.744, Validation Accuracy: 57.54%
# Epoch [8/10], Training Loss: 0.710, Validation Accuracy: 57.77%
# Epoch [9/10], Training Loss: 0.694, Validation Accuracy: 57.79%
# Epoch [10/10], Training Loss: 0.670, Validation Accuracy: 57.47%
# Epoch [1/10], Training Loss: 1.006, Validation Accuracy: 56.98%
# Epoch [2/10], Training Loss: 0.897, Validation Accuracy: 57.90%
# Epoch [3/10], Training Loss: 0.842, Validation Accuracy: 58.18%
# Epoch [4/10], Training Loss: 0.807, Validation Accuracy: 57.55%
# Epoch [5/10], Training Loss: 0.767, Validation Accuracy: 58.34%
# Epoch [6/10], Training Loss: 0.741, Validation Accuracy: 57.92%
# Epoch [7/10], Training Loss: 0.722, Validation Accuracy: 57.93%
# Epoch [8/10], Training Loss: 0.687, Validation Accuracy: 57.43%
# Epoch [9/10], Training Loss: 0.665, Validation Accuracy: 57.54%
# Epoch [10/10], Training Loss: 0.643, Validation Accuracy: 57.51%
# Epoch [1/10], Training Loss: 0.985, Validation Accuracy: 56.99%
# Epoch [2/10], Training Loss: 0.883, Validation Accuracy: 58.02%
# Epoch [3/10], Training Loss: 0.828, Validation Accuracy: 57.79%
# Epoch [4/10], Training Loss: 0.786, Validation Accuracy: 58.08%
# Epoch [5/10], Training Loss: 0.754, Validation Accuracy: 58.42%
# Epoch [6/10], Training Loss: 0.721, Validation Accuracy: 57.58%
# Epoch [7/10], Training Loss: 0.688, Validation Accuracy: 58.12%
# Epoch [8/10], Training Loss: 0.666, Validation Accuracy: 57.24%
# Epoch [9/10], Training Loss: 0.651, Validation Accuracy: 57.88%
# Epoch [10/10], Training Loss: 0.638, Validation Accuracy: 57.36%
# Epoch [1/10], Training Loss: 1.014, Validation Accuracy: 57.84%
# Epoch [2/10], Training Loss: 0.902, Validation Accuracy: 57.63%
# Epoch [3/10], Training Loss: 0.833, Validation Accuracy: 57.93%
# Epoch [4/10], Training Loss: 0.794, Validation Accuracy: 58.22%
# Epoch [5/10], Training Loss: 0.762, Validation Accuracy: 57.93%
# Epoch [6/10], Training Loss: 0.722, Validation Accuracy: 57.36%
# Epoch [7/10], Training Loss: 0.704, Validation Accuracy: 58.21%
# Epoch [8/10], Training Loss: 0.680, Validation Accuracy: 57.89%
# Epoch [9/10], Training Loss: 0.661, Validation Accuracy: 58.16%
# Epoch [10/10], Training Loss: 0.639, Validation Accuracy: 57.60%
# Epoch [1/10], Training Loss: 0.971, Validation Accuracy: 57.86%
# Epoch [2/10], Training Loss: 0.852, Validation Accuracy: 58.09%
# Epoch [3/10], Training Loss: 0.797, Validation Accuracy: 57.97%
# Epoch [4/10], Training Loss: 0.759, Validation Accuracy: 58.11%
# Epoch [5/10], Training Loss: 0.719, Validation Accuracy: 58.24%
# Epoch [6/10], Training Loss: 0.687, Validation Accuracy: 57.93%
# Epoch [7/10], Training Loss: 0.660, Validation Accuracy: 58.37%
# Epoch [8/10], Training Loss: 0.634, Validation Accuracy: 57.74%
# Epoch [9/10], Training Loss: 0.611, Validation Accuracy: 57.60%
# Epoch [10/10], Training Loss: 0.591, Validation Accuracy: 57.32%
# Epoch [1/10], Training Loss: 0.973, Validation Accuracy: 57.77%
# Epoch [2/10], Training Loss: 0.843, Validation Accuracy: 57.05%
# Epoch [3/10], Training Loss: 0.781, Validation Accuracy: 57.92%
# Epoch [4/10], Training Loss: 0.736, Validation Accuracy: 57.85%
# Epoch [5/10], Training Loss: 0.696, Validation Accuracy: 57.85%
# Epoch [6/10], Training Loss: 0.659, Validation Accuracy: 57.98%
# Epoch [7/10], Training Loss: 0.635, Validation Accuracy: 57.60%
# Epoch [8/10], Training Loss: 0.620, Validation Accuracy: 57.77%
# Epoch [9/10], Training Loss: 0.586, Validation Accuracy: 57.82%
# Epoch [10/10], Training Loss: 0.573, Validation Accuracy: 57.83%
# Epoch [1/10], Training Loss: 0.958, Validation Accuracy: 58.39%
# Epoch [2/10], Training Loss: 0.822, Validation Accuracy: 57.71%
# Epoch [3/10], Training Loss: 0.756, Validation Accuracy: 58.04%
# Epoch [4/10], Training Loss: 0.720, Validation Accuracy: 58.22%
# Epoch [5/10], Training Loss: 0.677, Validation Accuracy: 58.37%
# Epoch [6/10], Training Loss: 0.638, Validation Accuracy: 58.12%
# Epoch [7/10], Training Loss: 0.614, Validation Accuracy: 57.79%
# Epoch [8/10], Training Loss: 0.587, Validation Accuracy: 58.22%
# Epoch [9/10], Training Loss: 0.554, Validation Accuracy: 58.54%
# Epoch [10/10], Training Loss: 0.543, Validation Accuracy: 57.82%
# Epoch [1/10], Training Loss: 0.945, Validation Accuracy: 58.02%
# Epoch [2/10], Training Loss: 0.809, Validation Accuracy: 57.89%
# Epoch [3/10], Training Loss: 0.744, Validation Accuracy: 57.38%
# Epoch [4/10], Training Loss: 0.683, Validation Accuracy: 58.14%
# Epoch [5/10], Training Loss: 0.652, Validation Accuracy: 57.99%
# Epoch [6/10], Training Loss: 0.614, Validation Accuracy: 58.08%
# Epoch [7/10], Training Loss: 0.593, Validation Accuracy: 57.86%
# Epoch [8/10], Training Loss: 0.568, Validation Accuracy: 58.16%
# Epoch [9/10], Training Loss: 0.541, Validation Accuracy: 57.72%
# Epoch [10/10], Training Loss: 0.524, Validation Accuracy: 57.78%
# Epoch [1/10], Training Loss: 0.978, Validation Accuracy: 57.46%
# Epoch [2/10], Training Loss: 0.818, Validation Accuracy: 57.34%
# Epoch [3/10], Training Loss: 0.755, Validation Accuracy: 57.87%
# Epoch [4/10], Training Loss: 0.704, Validation Accuracy: 58.46%
# Epoch [5/10], Training Loss: 0.661, Validation Accuracy: 57.99%
# Epoch [6/10], Training Loss: 0.635, Validation Accuracy: 57.49%
# Epoch [7/10], Training Loss: 0.611, Validation Accuracy: 57.86%
# Epoch [8/10], Training Loss: 0.580, Validation Accuracy: 58.05%
# Epoch [9/10], Training Loss: 0.547, Validation Accuracy: 58.07%
# Epoch [10/10], Training Loss: 0.524, Validation Accuracy: 58.15%
# Epoch [1/10], Training Loss: 0.926, Validation Accuracy: 57.18%
# Epoch [2/10], Training Loss: 0.791, Validation Accuracy: 58.50%
# Epoch [3/10], Training Loss: 0.703, Validation Accuracy: 57.69%
# Epoch [4/10], Training Loss: 0.667, Validation Accuracy: 57.81%
# Epoch [5/10], Training Loss: 0.619, Validation Accuracy: 57.97%
# Epoch [6/10], Training Loss: 0.594, Validation Accuracy: 57.54%
# Epoch [7/10], Training Loss: 0.562, Validation Accuracy: 57.96%
# Epoch [8/10], Training Loss: 0.538, Validation Accuracy: 57.35%
# Epoch [9/10], Training Loss: 0.508, Validation Accuracy: 57.63%
# Epoch [10/10], Training Loss: 0.482, Validation Accuracy: 57.26%
# Epoch [1/10], Training Loss: 0.931, Validation Accuracy: 57.53%
# Epoch [2/10], Training Loss: 0.766, Validation Accuracy: 57.52%
# Epoch [3/10], Training Loss: 0.695, Validation Accuracy: 57.99%
# Epoch [4/10], Training Loss: 0.639, Validation Accuracy: 58.07%
# Epoch [5/10], Training Loss: 0.592, Validation Accuracy: 58.13%
# Epoch [6/10], Training Loss: 0.567, Validation Accuracy: 58.26%
# Epoch [7/10], Training Loss: 0.538, Validation Accuracy: 57.90%
# Epoch [8/10], Training Loss: 0.506, Validation Accuracy: 57.71%
# Epoch [9/10], Training Loss: 0.478, Validation Accuracy: 58.00%
# Epoch [10/10], Training Loss: 0.470, Validation Accuracy: 57.55%
# Epoch [1/10], Training Loss: 0.907, Validation Accuracy: 58.24%
# Epoch [2/10], Training Loss: 0.765, Validation Accuracy: 57.71%
# Epoch [3/10], Training Loss: 0.666, Validation Accuracy: 58.85%
# Epoch [4/10], Training Loss: 0.619, Validation Accuracy: 58.16%
# Epoch [5/10], Training Loss: 0.577, Validation Accuracy: 57.92%
# Epoch [6/10], Training Loss: 0.544, Validation Accuracy: 58.14%
# Epoch [7/10], Training Loss: 0.509, Validation Accuracy: 57.87%
# Epoch [8/10], Training Loss: 0.485, Validation Accuracy: 57.23%
# Epoch [9/10], Training Loss: 0.454, Validation Accuracy: 58.40%
# Epoch [10/10], Training Loss: 0.438, Validation Accuracy: 57.29%
# Epoch [1/10], Training Loss: 0.915, Validation Accuracy: 56.73%
# Epoch [2/10], Training Loss: 0.752, Validation Accuracy: 58.18%
# Epoch [3/10], Training Loss: 0.674, Validation Accuracy: 57.53%
# Epoch [4/10], Training Loss: 0.610, Validation Accuracy: 57.45%
# Epoch [5/10], Training Loss: 0.554, Validation Accuracy: 58.16%
# Epoch [6/10], Training Loss: 0.523, Validation Accuracy: 58.22%
# Epoch [7/10], Training Loss: 0.494, Validation Accuracy: 57.95%
# Epoch [8/10], Training Loss: 0.469, Validation Accuracy: 57.32%
# Epoch [9/10], Training Loss: 0.457, Validation Accuracy: 58.16%
# Epoch [10/10], Training Loss: 0.424, Validation Accuracy: 57.78%
# Epoch [1/10], Training Loss: 0.932, Validation Accuracy: 57.02%
# Epoch [2/10], Training Loss: 0.751, Validation Accuracy: 57.37%
# Epoch [3/10], Training Loss: 0.675, Validation Accuracy: 57.75%
# Epoch [4/10], Training Loss: 0.615, Validation Accuracy: 58.02%
# Epoch [5/10], Training Loss: 0.569, Validation Accuracy: 58.36%
# Epoch [6/10], Training Loss: 0.534, Validation Accuracy: 57.56%
# Epoch [7/10], Training Loss: 0.501, Validation Accuracy: 57.17%
# Epoch [8/10], Training Loss: 0.475, Validation Accuracy: 58.17%
# Epoch [9/10], Training Loss: 0.449, Validation Accuracy: 57.84%
# Epoch [10/10], Training Loss: 0.422, Validation Accuracy: 57.64%
# Epoch [1/10], Training Loss: 0.890, Validation Accuracy: 57.50%
# Epoch [2/10], Training Loss: 0.724, Validation Accuracy: 57.61%
# Epoch [3/10], Training Loss: 0.626, Validation Accuracy: 57.85%
# Epoch [4/10], Training Loss: 0.570, Validation Accuracy: 57.44%
# Epoch [5/10], Training Loss: 0.534, Validation Accuracy: 57.84%
# Epoch [6/10], Training Loss: 0.493, Validation Accuracy: 57.65%
# Epoch [7/10], Training Loss: 0.463, Validation Accuracy: 57.65%
# Epoch [8/10], Training Loss: 0.437, Validation Accuracy: 57.18%
# Epoch [9/10], Training Loss: 0.410, Validation Accuracy: 57.40%
# Epoch [10/10], Training Loss: 0.393, Validation Accuracy: 56.99%
# Epoch [1/10], Training Loss: 0.921, Validation Accuracy: 56.28%
# Epoch [2/10], Training Loss: 0.714, Validation Accuracy: 56.92%
# Epoch [3/10], Training Loss: 0.617, Validation Accuracy: 56.93%
# Epoch [4/10], Training Loss: 0.562, Validation Accuracy: 57.88%
# Epoch [5/10], Training Loss: 0.508, Validation Accuracy: 57.99%
# Epoch [6/10], Training Loss: 0.474, Validation Accuracy: 57.54%
# Epoch [7/10], Training Loss: 0.444, Validation Accuracy: 57.61%
# Epoch [8/10], Training Loss: 0.412, Validation Accuracy: 57.65%
# Epoch [9/10], Training Loss: 0.390, Validation Accuracy: 57.26%
# Epoch [10/10], Training Loss: 0.362, Validation Accuracy: 56.88%
# Epoch [1/10], Training Loss: 0.899, Validation Accuracy: 57.72%
# Epoch [2/10], Training Loss: 0.691, Validation Accuracy: 57.80%
# Epoch [3/10], Training Loss: 0.599, Validation Accuracy: 57.73%
# Epoch [4/10], Training Loss: 0.531, Validation Accuracy: 58.69%
# Epoch [5/10], Training Loss: 0.490, Validation Accuracy: 57.71%
# Epoch [6/10], Training Loss: 0.445, Validation Accuracy: 58.05%
# Epoch [7/10], Training Loss: 0.417, Validation Accuracy: 57.79%
# Epoch [8/10], Training Loss: 0.386, Validation Accuracy: 57.49%
# Epoch [9/10], Training Loss: 0.368, Validation Accuracy: 57.89%
# Epoch [10/10], Training Loss: 0.345, Validation Accuracy: 57.78%
# Epoch [1/10], Training Loss: 0.883, Validation Accuracy: 55.65%
# Epoch [2/10], Training Loss: 0.674, Validation Accuracy: 57.48%
# Epoch [3/10], Training Loss: 0.578, Validation Accuracy: 57.60%
# Epoch [4/10], Training Loss: 0.519, Validation Accuracy: 57.82%
# Epoch [5/10], Training Loss: 0.466, Validation Accuracy: 57.62%
# Epoch [6/10], Training Loss: 0.430, Validation Accuracy: 57.94%
# Epoch [7/10], Training Loss: 0.413, Validation Accuracy: 57.90%
# Epoch [8/10], Training Loss: 0.373, Validation Accuracy: 57.46%
# Epoch [9/10], Training Loss: 0.354, Validation Accuracy: 57.07%
# Epoch [10/10], Training Loss: 0.339, Validation Accuracy: 57.08%
# Confusion Matrix:
# [[647  27  63  21  16  10  23   8 136  49]
#  [ 33 642  16  20   6  12  16  15  57 183]
#  [ 84   8 489  87  75  52 112  44  33  16]
#  [ 30  12  92 414  57 153 114  52  36  40]
#  [ 47   8 135  99 433  44 103  84  26  21]
#  [ 17   6  94 221  70 425  66  57  27  17]
#  [ 15  10  78  85  58  33 681   9  20  11]
#  [ 30  10  55  74  52  76  28 615  10  50]
#  [ 80  49  25  23   8   8  14   6 742  45]
#  [ 51 100  26  33  13  14  23  27  54 659]]
# Test Accuracy: 57.47%
# True Positives (TP): [647 642 489 414 433 425 681 615 742 659]
# False Positives (FP): [387 230 584 663 355 402 499 302 399 432]
# True Negatives (TN): [8613 8770 8416 8337 8645 8598 8501 8698 8601 8568]
# False Negatives (FN): [353 358 511 586 567 575 319 385 258 341]
# : [10000 10000 10000 10000 10000 10000 10000 10000 10000 10000]
# Precision: [0.62572534 0.73623853 0.45573159 0.38440111 0.54949239 0.51390568
#  0.57711864 0.67066521 0.65030675 0.604033  ]
# Recall: [0.647 0.642 0.489 0.414 0.433 0.425 0.681 0.615 0.742 0.659]
# F1 Score: [0.63618486 0.68589744 0.47178003 0.3986519  0.48434004 0.46524357
#  0.62477064 0.64162754 0.69313405 0.63032042]
