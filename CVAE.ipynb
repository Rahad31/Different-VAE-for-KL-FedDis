# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahad31/Different-VAE-for-KL-FedDis/blob/main/CVAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.stats import truncnorm
import torch
import torchvision
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import Subset, DataLoader
from torchvision.datasets import CIFAR10
from typing import Dict, Tuple
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import random

# Define Conditional VAE (CVAE) model
class CVAE(nn.Module):
    def __init__(self, x_dim, h_dim, z_dim, num_classes=10):
        super(CVAE, self).__init__()
        self.x_dim = x_dim
        self.h_dim = h_dim
        self.z_dim = z_dim
        self.num_classes = num_classes

        self.label_emb = nn.Embedding(num_classes, 32)

        self.encoder_conv = nn.Sequential(
            nn.Conv2d(3 + 1, 32, 4, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(32, 64, 4, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 128, 4, stride=2, padding=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(2048, 256),
            nn.ReLU(),
            nn.Linear(256, 2 * z_dim)
        )

        self.decoder_fc = nn.Sequential(
            nn.Linear(z_dim + 32, 256),
            nn.ReLU(),
            nn.Linear(256, 2048),
            nn.ReLU()
        )
        self.decoder_deconv = nn.Sequential(
            nn.Unflatten(1, (128, 4, 4)),
            nn.ConvTranspose2d(128, 64, 4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(64, 32, 4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(32, 3, 4, stride=2, padding=1),
            nn.Sigmoid()
        )

    def encode(self, x, y):
        y = self.label_emb(y).unsqueeze(2).unsqueeze(3).expand(-1, -1, 32, 32)
        y = y[:, 0:1]
        x_cat = torch.cat([x, y], dim=1)
        h = self.encoder_conv(x_cat)
        mu, logvar = h[:, :self.z_dim], h[:, self.z_dim:]
        return mu, logvar

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z, y):
        y = self.label_emb(y)
        z_cat = torch.cat([z, y], dim=1)
        h = self.decoder_fc(z_cat)
        x_hat = self.decoder_deconv(h)
        return x_hat

    def forward(self, x, y):
        mu, logvar = self.encode(x, y)
        z = self.reparameterize(mu, logvar)
        x_hat = self.decode(z, y)
        return x_hat, mu, logvar

# VAE loss function
def vae_loss(recon_x, x, mu, logvar, beta=1):
    BCE = nn.functional.mse_loss(recon_x, x, reduction='sum')
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return BCE + beta * KLD

# VAE training

def vae_train(vae: CVAE, trainloader: DataLoader, epochs: int, beta: float = 1):
    optimizer = torch.optim.Adam(vae.parameters(), lr=1e-3)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)

    for epoch in range(epochs):
        vae.train()
        for inputs, labels in trainloader:
            optimizer.zero_grad()
            recon_x, mu, logvar = vae(inputs, labels)
            loss = vae_loss(recon_x, inputs, mu, logvar, beta)
            loss.backward()
            optimizer.step()
        scheduler.step()

# Define classification model
class Net(nn.Module):
    def __init__(self) -> None:
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.pool(nn.functional.relu(self.conv1(x)))
        x = self.pool(nn.functional.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = nn.functional.relu(self.fc1(x))
        x = nn.functional.relu(self.fc2(x))
        x = self.fc3(x)
        return x


# Load CIFAR10 dataset
transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]
)

full_dataset = CIFAR10(root="./data", train=True, download=True, transform=transform)
test_set = CIFAR10(root="./data", train=False, download=True, transform=transform)

# Separate dataset by class
class_indices = {i: [] for i in range(10)}  # CIFAR-10 has 10 classes
for idx, (_, label) in enumerate(full_dataset):
    class_indices[label].append(idx)

# Define target count per class, summing to 60,000 with random distribution
class_counts = np.random.multinomial(60000, [0.1] * 10)  # Adjust probabilities if you want specific class biases
print("Random Images per Class:", class_counts)

# Sample indices based on the specified class counts
indices = []
for class_id, count in enumerate(class_counts):
    # Ensure count does not exceed available images
    count = min(count, len(class_indices[class_id]))
    selected_indices = random.sample(class_indices[class_id], count)
    indices.extend(selected_indices)

# Create a custom CIFAR-10 dataset with the sampled indices
custom_dataset = Subset(full_dataset, indices)
# Split dataset into training and validation sets
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_set, val_set = torch.utils.data.random_split(full_dataset, [train_size, val_size])

# Create training and validation loaders
trainloader = DataLoader(train_set, batch_size=128, shuffle=True, num_workers=2)
valloader = DataLoader(val_set, batch_size=128, shuffle=False, num_workers=2)
testloader = DataLoader(test_set, batch_size=128, shuffle=False, num_workers=2)



# Define VAE loss function
def vae_loss(recon_x, x, mu, logvar, beta=1):
    BCE = nn.functional.mse_loss(recon_x, x, reduction='sum')
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return BCE + beta * KLD

# Define training procedure for classification model
def train(net: nn.Module, trainloader: DataLoader, valloader: DataLoader, epochs: int) -> None:
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)

    best_acc = 0.0

    for epoch in range(epochs):
        # Training loop
        net.train()
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            inputs, labels = data
            optimizer.zero_grad()
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        scheduler.step()

        # Validation loop
        net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data in valloader:
                images, labels = data
                outputs = net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_acc = 100 * correct / total
        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(net.state_dict(), 'best_model.pth')

        print(f"Epoch [{epoch+1}/{epochs}], Training Loss: {running_loss / (i+1):.3f}, Validation Accuracy: {val_acc:.2f}%")

# Define evaluation procedure
def evaluate(net: nn.Module, testloader: DataLoader) -> Tuple[float, np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
    net.eval()
    correct = 0
    total = 0
    all_labels = []
    all_predictions = []
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    accuracy = 100 * correct / total

    # Calculate confusion matrix
    cm = confusion_matrix(all_labels, all_predictions)
    print(f"Confusion Matrix:\n{cm}")

    # Calculate TP, FP, TN, FN for each class
    tp = np.diag(cm)
    fp = cm.sum(axis=0) - tp
    fn = cm.sum(axis=1) - tp
    tn = cm.sum() - (fp + fn + tp)

    # Calculate precision, recall, and F1 score for each class
    precision = precision_score(all_labels, all_predictions, average=None)
    recall = recall_score(all_labels, all_predictions, average=None)
    f1 = f1_score(all_labels, all_predictions, average=None)

    return accuracy, tp, fp, tn, fn, precision, recall, f1

# Initialize clients
def initialize_clients(trainset, transform, batch_size, num_clients):
    clients = {}
    for i in range(num_clients):
        client_trainset = torch.utils.data.Subset(trainset, range(i * len(trainset) // num_clients, (i + 1) * len(trainset) // num_clients))
        client_trainloader = torch.utils.data.DataLoader(client_trainset, batch_size=batch_size, shuffle=True)
        clients[f"client_{i}"] = client_trainloader
    return clients

def get_distribution_info(vae: CVAE) -> Dict:
    # Implement the logic to extract distribution information from the VAE
    # This can involve computing statistics, parameters, or any other relevant information
    # that can be used to generate augmented data

    # Example implementation:
    distribution_info = {

        "normal": {
            "mean": vae.encoder_conv[-1].bias.data.cpu().numpy(),
            "std": torch.exp(0.5 * vae.encoder_conv[-1].weight.data[:, :vae.z_dim]).cpu().numpy()
        }
    }

    return distribution_info

def send_distribution_info(distribution_info: Dict) -> None:
    # Implement the logic to send the distribution information to the global server
    # This can involve using a network protocol, a message queue, or any other communication mechanism
    # to send the information

    # Example implementation:
    # Send the distribution information to the global server using a network protocol
    # For example, you can use the `socket` module to send the information over a network
    # or use a message queue like `RabbitMQ` to send the information
    pass

def generate_augmented_data(vae: CVAE, distribution_info_normal: Dict) -> torch.Tensor:
    # Generate augmented data using both uniform and truncated uniform distributions



    mean_normal = distribution_info_normal["mean"]
    std_normal = distribution_info_normal["std"]

    augmented_data_normal = torch.randn(64, vae.z_dim) * std_normal + mean_normal





    # Calculate the average of augmented data from both distributions
    augmented_data_average =  augmented_data_normal

    return augmented_data_average

def federated_train(net: nn.Module, vae: CVAE, trainloaders: Dict[str, DataLoader], trainloader: DataLoader, valloader: DataLoader, epochs: int) -> None:
    for epoch in range(epochs):
        for client_id, client_trainloader in trainloaders.items():
            # Train VAE on client data
            vae_train(vae, client_trainloader, epochs=10, beta=1)

            # Share distribution information with global server
            distribution_info = get_distribution_info(vae)
            send_distribution_info(distribution_info)

            # Receive distribution information from other clients
            other_distribution_info = receive_distribution_info()

            # Generate augmented data using received distribution information
            augmented_data = generate_augmented_data(vae, other_distribution_info["normal"])

            # Train classification model using local, augmented, and validation data
            train(net, client_trainloader, valloader, epochs=10)

            # Send model updates to global server
            send_model_update(client_id, net.state_dict())

# Define logic to receive distribution information from global server
def receive_distribution_info() -> Dict:
    # Receive distribution information logic
    distribution_info = {

        "normal": {
            "mean": np.zeros(20),  # Adjust the size based on your latent space dimension
            "std": np.ones(20)
        }
    }
    return distribution_info

def send_model_update(client_id: str, model_update: Dict) -> None:
    # Implement the logic to send the model update to the global server
    # This can involve using a network protocol, a message queue, or any other communication mechanism
    # to send the model update

    # Example implementation:
    # Send the model update to the global server using a network protocol
    # For example, you can use the `socket` module to send the information over a network
    # or use a message queue like `RabbitMQ` to send the information
    pass

# Define global server procedure
def global_server() -> None:
    net = Net()
    x_dim = 3 * 32 * 32  # CIFAR-10 input size
    h_dim = 400
    z_dim = 20
    vae = CVAE(x_dim, h_dim, z_dim)  # Initialize VAE object with required arguments

    # Initialize clients
    num_clients = 5  # Define the number of clients
    clients = initialize_clients(train_set, transform, batch_size=128, num_clients=num_clients)

    # Train model using FedDIS
    federated_train(net, vae, clients, trainloader, valloader, epochs=10)

    # Evaluate final model
    test_accuracy, tp, fp, tn, fn, precision, recall, f1 = evaluate(net, testloader)
    print(f"Test Accuracy: {test_accuracy:.2f}%")

    print("True Positives (TP):", tp)
    print("False Positives (FP):", fp)
    print("True Negatives (TN):", tn)
    print("False Negatives (FN):", fn)
    print(":", fn+tn+tp+fp)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)

if __name__ == "__main__":
    global_server()
# Out:
# Random Images per Class: [5970 5927 6135 5944 5922 6076 6051 5937 6021 6017]
# /tmp/ipython-input-2-993906647.py:289: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   augmented_data_normal = torch.randn(64, vae.z_dim) * std_normal + mean_normal
# Epoch [1/10], Training Loss: 2.303, Validation Accuracy: 9.85%
# Epoch [2/10], Training Loss: 2.303, Validation Accuracy: 10.00%
# Epoch [3/10], Training Loss: 2.302, Validation Accuracy: 10.29%
# Epoch [4/10], Training Loss: 2.301, Validation Accuracy: 10.79%
# Epoch [5/10], Training Loss: 2.300, Validation Accuracy: 11.44%
# Epoch [6/10], Training Loss: 2.299, Validation Accuracy: 12.12%
# Epoch [7/10], Training Loss: 2.297, Validation Accuracy: 13.16%
# Epoch [8/10], Training Loss: 2.296, Validation Accuracy: 13.47%
# Epoch [9/10], Training Loss: 2.293, Validation Accuracy: 13.59%
# Epoch [10/10], Training Loss: 2.289, Validation Accuracy: 13.81%
# Epoch [1/10], Training Loss: 2.286, Validation Accuracy: 14.89%
# Epoch [2/10], Training Loss: 2.279, Validation Accuracy: 15.27%
# Epoch [3/10], Training Loss: 2.268, Validation Accuracy: 15.10%
# Epoch [4/10], Training Loss: 2.254, Validation Accuracy: 15.63%
# Epoch [5/10], Training Loss: 2.239, Validation Accuracy: 16.86%
# Epoch [6/10], Training Loss: 2.224, Validation Accuracy: 19.33%
# Epoch [7/10], Training Loss: 2.207, Validation Accuracy: 20.09%
# Epoch [8/10], Training Loss: 2.193, Validation Accuracy: 21.45%
# Epoch [9/10], Training Loss: 2.179, Validation Accuracy: 21.74%
# Epoch [10/10], Training Loss: 2.168, Validation Accuracy: 22.03%
# Epoch [1/10], Training Loss: 2.158, Validation Accuracy: 22.15%
# Epoch [2/10], Training Loss: 2.146, Validation Accuracy: 22.93%
# Epoch [3/10], Training Loss: 2.136, Validation Accuracy: 23.49%
# Epoch [4/10], Training Loss: 2.124, Validation Accuracy: 24.05%
# Epoch [5/10], Training Loss: 2.111, Validation Accuracy: 24.18%
# Epoch [6/10], Training Loss: 2.099, Validation Accuracy: 24.92%
# Epoch [7/10], Training Loss: 2.085, Validation Accuracy: 25.25%
# Epoch [8/10], Training Loss: 2.071, Validation Accuracy: 25.70%
# Epoch [9/10], Training Loss: 2.056, Validation Accuracy: 25.77%
# Epoch [10/10], Training Loss: 2.041, Validation Accuracy: 26.64%
# Epoch [1/10], Training Loss: 2.039, Validation Accuracy: 27.29%
# Epoch [2/10], Training Loss: 2.017, Validation Accuracy: 28.41%
# Epoch [3/10], Training Loss: 1.995, Validation Accuracy: 28.45%
# Epoch [4/10], Training Loss: 1.974, Validation Accuracy: 28.61%
# Epoch [5/10], Training Loss: 1.959, Validation Accuracy: 29.20%
# Epoch [6/10], Training Loss: 1.945, Validation Accuracy: 29.42%
# Epoch [7/10], Training Loss: 1.934, Validation Accuracy: 29.88%
# Epoch [8/10], Training Loss: 1.922, Validation Accuracy: 29.89%
# Epoch [9/10], Training Loss: 1.909, Validation Accuracy: 30.31%
# Epoch [10/10], Training Loss: 1.899, Validation Accuracy: 30.29%
# Epoch [1/10], Training Loss: 1.892, Validation Accuracy: 31.25%
# Epoch [2/10], Training Loss: 1.872, Validation Accuracy: 31.37%
# Epoch [3/10], Training Loss: 1.862, Validation Accuracy: 31.76%
# Epoch [4/10], Training Loss: 1.845, Validation Accuracy: 32.18%
# Epoch [5/10], Training Loss: 1.830, Validation Accuracy: 32.63%
# Epoch [6/10], Training Loss: 1.815, Validation Accuracy: 33.01%
# Epoch [7/10], Training Loss: 1.805, Validation Accuracy: 33.34%
# Epoch [8/10], Training Loss: 1.794, Validation Accuracy: 34.30%
# Epoch [9/10], Training Loss: 1.776, Validation Accuracy: 34.75%
# Epoch [10/10], Training Loss: 1.760, Validation Accuracy: 35.34%
# Epoch [1/10], Training Loss: 1.755, Validation Accuracy: 35.62%
# Epoch [2/10], Training Loss: 1.738, Validation Accuracy: 36.60%
# Epoch [3/10], Training Loss: 1.722, Validation Accuracy: 36.86%
# Epoch [4/10], Training Loss: 1.713, Validation Accuracy: 37.16%
# Epoch [5/10], Training Loss: 1.701, Validation Accuracy: 37.46%
# Epoch [6/10], Training Loss: 1.685, Validation Accuracy: 37.80%
# Epoch [7/10], Training Loss: 1.675, Validation Accuracy: 37.53%
# Epoch [8/10], Training Loss: 1.662, Validation Accuracy: 38.68%
# Epoch [9/10], Training Loss: 1.650, Validation Accuracy: 39.07%
# Epoch [10/10], Training Loss: 1.646, Validation Accuracy: 39.90%
# Epoch [1/10], Training Loss: 1.694, Validation Accuracy: 40.08%
# Epoch [2/10], Training Loss: 1.682, Validation Accuracy: 39.90%
# Epoch [3/10], Training Loss: 1.677, Validation Accuracy: 40.35%
# Epoch [4/10], Training Loss: 1.659, Validation Accuracy: 40.49%
# Epoch [5/10], Training Loss: 1.647, Validation Accuracy: 41.42%
# Epoch [6/10], Training Loss: 1.639, Validation Accuracy: 40.95%
# Epoch [7/10], Training Loss: 1.627, Validation Accuracy: 41.38%
# Epoch [8/10], Training Loss: 1.622, Validation Accuracy: 40.85%
# Epoch [9/10], Training Loss: 1.611, Validation Accuracy: 41.19%
# Epoch [10/10], Training Loss: 1.598, Validation Accuracy: 41.79%
# Epoch [1/10], Training Loss: 1.613, Validation Accuracy: 41.02%
# Epoch [2/10], Training Loss: 1.597, Validation Accuracy: 43.33%
# Epoch [3/10], Training Loss: 1.581, Validation Accuracy: 43.16%
# Epoch [4/10], Training Loss: 1.572, Validation Accuracy: 43.49%
# Epoch [5/10], Training Loss: 1.556, Validation Accuracy: 43.81%
# Epoch [6/10], Training Loss: 1.545, Validation Accuracy: 43.22%
# Epoch [7/10], Training Loss: 1.536, Validation Accuracy: 44.24%
# Epoch [8/10], Training Loss: 1.527, Validation Accuracy: 44.96%
# Epoch [9/10], Training Loss: 1.516, Validation Accuracy: 44.98%
# Epoch [10/10], Training Loss: 1.503, Validation Accuracy: 45.39%
# Epoch [1/10], Training Loss: 1.551, Validation Accuracy: 44.49%
# Epoch [2/10], Training Loss: 1.532, Validation Accuracy: 45.31%
# Epoch [3/10], Training Loss: 1.522, Validation Accuracy: 45.71%
# Epoch [4/10], Training Loss: 1.503, Validation Accuracy: 45.90%
# Epoch [5/10], Training Loss: 1.494, Validation Accuracy: 46.44%
# Epoch [6/10], Training Loss: 1.491, Validation Accuracy: 45.94%
# Epoch [7/10], Training Loss: 1.472, Validation Accuracy: 46.63%
# Epoch [8/10], Training Loss: 1.465, Validation Accuracy: 47.18%
# Epoch [9/10], Training Loss: 1.446, Validation Accuracy: 47.51%
# Epoch [10/10], Training Loss: 1.436, Validation Accuracy: 47.64%
# Epoch [1/10], Training Loss: 1.460, Validation Accuracy: 47.57%
# Epoch [2/10], Training Loss: 1.442, Validation Accuracy: 47.94%
# Epoch [3/10], Training Loss: 1.428, Validation Accuracy: 47.12%
# Epoch [4/10], Training Loss: 1.415, Validation Accuracy: 47.96%
# Epoch [5/10], Training Loss: 1.411, Validation Accuracy: 48.19%
# Epoch [6/10], Training Loss: 1.397, Validation Accuracy: 49.03%
# Epoch [7/10], Training Loss: 1.383, Validation Accuracy: 47.76%
# Epoch [8/10], Training Loss: 1.378, Validation Accuracy: 48.96%
# Epoch [9/10], Training Loss: 1.366, Validation Accuracy: 49.67%
# Epoch [10/10], Training Loss: 1.357, Validation Accuracy: 49.16%
# Epoch [1/10], Training Loss: 1.405, Validation Accuracy: 49.82%
# Epoch [2/10], Training Loss: 1.385, Validation Accuracy: 49.97%
# Epoch [3/10], Training Loss: 1.372, Validation Accuracy: 49.77%
# Epoch [4/10], Training Loss: 1.367, Validation Accuracy: 49.36%
# Epoch [5/10], Training Loss: 1.350, Validation Accuracy: 49.53%
# Epoch [6/10], Training Loss: 1.338, Validation Accuracy: 49.79%
# Epoch [7/10], Training Loss: 1.336, Validation Accuracy: 50.02%
# Epoch [8/10], Training Loss: 1.318, Validation Accuracy: 49.71%
# Epoch [9/10], Training Loss: 1.316, Validation Accuracy: 50.23%
# Epoch [10/10], Training Loss: 1.307, Validation Accuracy: 50.81%
# Epoch [1/10], Training Loss: 1.407, Validation Accuracy: 51.14%
# Epoch [2/10], Training Loss: 1.388, Validation Accuracy: 50.02%
# Epoch [3/10], Training Loss: 1.366, Validation Accuracy: 51.78%
# Epoch [4/10], Training Loss: 1.359, Validation Accuracy: 51.35%
# Epoch [5/10], Training Loss: 1.351, Validation Accuracy: 51.61%
# Epoch [6/10], Training Loss: 1.336, Validation Accuracy: 51.88%
# Epoch [7/10], Training Loss: 1.331, Validation Accuracy: 52.20%
# Epoch [8/10], Training Loss: 1.315, Validation Accuracy: 51.93%
# Epoch [9/10], Training Loss: 1.317, Validation Accuracy: 51.99%
# Epoch [10/10], Training Loss: 1.303, Validation Accuracy: 52.19%
# Epoch [1/10], Training Loss: 1.346, Validation Accuracy: 52.08%
# Epoch [2/10], Training Loss: 1.324, Validation Accuracy: 52.80%
# Epoch [3/10], Training Loss: 1.305, Validation Accuracy: 52.91%
# Epoch [4/10], Training Loss: 1.296, Validation Accuracy: 53.02%
# Epoch [5/10], Training Loss: 1.292, Validation Accuracy: 52.84%
# Epoch [6/10], Training Loss: 1.283, Validation Accuracy: 53.20%
# Epoch [7/10], Training Loss: 1.271, Validation Accuracy: 52.85%
# Epoch [8/10], Training Loss: 1.260, Validation Accuracy: 52.87%
# Epoch [9/10], Training Loss: 1.254, Validation Accuracy: 53.16%
# Epoch [10/10], Training Loss: 1.248, Validation Accuracy: 52.90%
# Epoch [1/10], Training Loss: 1.305, Validation Accuracy: 53.75%
# Epoch [2/10], Training Loss: 1.283, Validation Accuracy: 53.31%
# Epoch [3/10], Training Loss: 1.278, Validation Accuracy: 52.54%
# Epoch [4/10], Training Loss: 1.261, Validation Accuracy: 53.65%
# Epoch [5/10], Training Loss: 1.242, Validation Accuracy: 53.86%
# Epoch [6/10], Training Loss: 1.237, Validation Accuracy: 54.22%
# Epoch [7/10], Training Loss: 1.230, Validation Accuracy: 53.40%
# Epoch [8/10], Training Loss: 1.219, Validation Accuracy: 54.15%
# Epoch [9/10], Training Loss: 1.203, Validation Accuracy: 54.18%
# Epoch [10/10], Training Loss: 1.194, Validation Accuracy: 53.29%
# Epoch [1/10], Training Loss: 1.268, Validation Accuracy: 54.07%
# Epoch [2/10], Training Loss: 1.247, Validation Accuracy: 53.87%
# Epoch [3/10], Training Loss: 1.228, Validation Accuracy: 54.44%
# Epoch [4/10], Training Loss: 1.221, Validation Accuracy: 53.92%
# Epoch [5/10], Training Loss: 1.204, Validation Accuracy: 54.09%
# Epoch [6/10], Training Loss: 1.191, Validation Accuracy: 54.00%
# Epoch [7/10], Training Loss: 1.188, Validation Accuracy: 54.77%
# Epoch [8/10], Training Loss: 1.177, Validation Accuracy: 54.56%
# Epoch [9/10], Training Loss: 1.179, Validation Accuracy: 54.27%
# Epoch [10/10], Training Loss: 1.155, Validation Accuracy: 53.78%
# Epoch [1/10], Training Loss: 1.249, Validation Accuracy: 55.17%
# Epoch [2/10], Training Loss: 1.216, Validation Accuracy: 54.86%
# Epoch [3/10], Training Loss: 1.201, Validation Accuracy: 55.08%
# Epoch [4/10], Training Loss: 1.187, Validation Accuracy: 55.37%
# Epoch [5/10], Training Loss: 1.172, Validation Accuracy: 55.24%
# Epoch [6/10], Training Loss: 1.163, Validation Accuracy: 54.88%
# Epoch [7/10], Training Loss: 1.155, Validation Accuracy: 55.35%
# Epoch [8/10], Training Loss: 1.150, Validation Accuracy: 55.53%
# Epoch [9/10], Training Loss: 1.134, Validation Accuracy: 55.12%
# Epoch [10/10], Training Loss: 1.126, Validation Accuracy: 54.64%
# Epoch [1/10], Training Loss: 1.260, Validation Accuracy: 54.91%
# Epoch [2/10], Training Loss: 1.236, Validation Accuracy: 55.44%
# Epoch [3/10], Training Loss: 1.214, Validation Accuracy: 55.76%
# Epoch [4/10], Training Loss: 1.194, Validation Accuracy: 55.75%
# Epoch [5/10], Training Loss: 1.189, Validation Accuracy: 54.89%
# Epoch [6/10], Training Loss: 1.178, Validation Accuracy: 55.95%
# Epoch [7/10], Training Loss: 1.162, Validation Accuracy: 56.46%
# Epoch [8/10], Training Loss: 1.160, Validation Accuracy: 55.72%
# Epoch [9/10], Training Loss: 1.145, Validation Accuracy: 55.85%
# Epoch [10/10], Training Loss: 1.136, Validation Accuracy: 55.77%
# Epoch [1/10], Training Loss: 1.212, Validation Accuracy: 55.30%
# Epoch [2/10], Training Loss: 1.199, Validation Accuracy: 55.95%
# Epoch [3/10], Training Loss: 1.181, Validation Accuracy: 56.40%
# Epoch [4/10], Training Loss: 1.157, Validation Accuracy: 56.02%
# Epoch [5/10], Training Loss: 1.142, Validation Accuracy: 56.53%
# Epoch [6/10], Training Loss: 1.138, Validation Accuracy: 56.37%
# Epoch [7/10], Training Loss: 1.129, Validation Accuracy: 56.71%
# Epoch [8/10], Training Loss: 1.119, Validation Accuracy: 56.99%
# Epoch [9/10], Training Loss: 1.107, Validation Accuracy: 57.13%
# Epoch [10/10], Training Loss: 1.105, Validation Accuracy: 56.25%
# Epoch [1/10], Training Loss: 1.187, Validation Accuracy: 56.73%
# Epoch [2/10], Training Loss: 1.151, Validation Accuracy: 56.41%
# Epoch [3/10], Training Loss: 1.133, Validation Accuracy: 55.71%
# Epoch [4/10], Training Loss: 1.117, Validation Accuracy: 56.55%
# Epoch [5/10], Training Loss: 1.098, Validation Accuracy: 57.42%
# Epoch [6/10], Training Loss: 1.095, Validation Accuracy: 56.00%
# Epoch [7/10], Training Loss: 1.086, Validation Accuracy: 56.77%
# Epoch [8/10], Training Loss: 1.065, Validation Accuracy: 57.15%
# Epoch [9/10], Training Loss: 1.055, Validation Accuracy: 56.97%
# Epoch [10/10], Training Loss: 1.047, Validation Accuracy: 56.56%
# Epoch [1/10], Training Loss: 1.153, Validation Accuracy: 57.29%
# Epoch [2/10], Training Loss: 1.132, Validation Accuracy: 55.83%
# Epoch [3/10], Training Loss: 1.107, Validation Accuracy: 57.21%
# Epoch [4/10], Training Loss: 1.091, Validation Accuracy: 56.99%
# Epoch [5/10], Training Loss: 1.070, Validation Accuracy: 57.06%
# Epoch [6/10], Training Loss: 1.066, Validation Accuracy: 57.24%
# Epoch [7/10], Training Loss: 1.045, Validation Accuracy: 57.65%
# Epoch [8/10], Training Loss: 1.038, Validation Accuracy: 57.39%
# Epoch [9/10], Training Loss: 1.030, Validation Accuracy: 57.08%
# Epoch [10/10], Training Loss: 1.021, Validation Accuracy: 57.05%
# Epoch [1/10], Training Loss: 1.152, Validation Accuracy: 57.76%
# Epoch [2/10], Training Loss: 1.104, Validation Accuracy: 56.41%
# Epoch [3/10], Training Loss: 1.088, Validation Accuracy: 57.72%
# Epoch [4/10], Training Loss: 1.069, Validation Accuracy: 57.83%
# Epoch [5/10], Training Loss: 1.061, Validation Accuracy: 57.04%
# Epoch [6/10], Training Loss: 1.041, Validation Accuracy: 57.87%
# Epoch [7/10], Training Loss: 1.038, Validation Accuracy: 56.33%
# Epoch [8/10], Training Loss: 1.032, Validation Accuracy: 56.31%
# Epoch [9/10], Training Loss: 1.028, Validation Accuracy: 57.32%
# Epoch [10/10], Training Loss: 1.006, Validation Accuracy: 57.02%
# Epoch [1/10], Training Loss: 1.171, Validation Accuracy: 57.39%
# Epoch [2/10], Training Loss: 1.142, Validation Accuracy: 57.36%
# Epoch [3/10], Training Loss: 1.106, Validation Accuracy: 57.77%
# Epoch [4/10], Training Loss: 1.088, Validation Accuracy: 57.85%
# Epoch [5/10], Training Loss: 1.074, Validation Accuracy: 56.86%
# Epoch [6/10], Training Loss: 1.067, Validation Accuracy: 56.83%
# Epoch [7/10], Training Loss: 1.059, Validation Accuracy: 57.97%
# Epoch [8/10], Training Loss: 1.034, Validation Accuracy: 57.73%
# Epoch [9/10], Training Loss: 1.035, Validation Accuracy: 57.95%
# Epoch [10/10], Training Loss: 1.013, Validation Accuracy: 57.60%
# Epoch [1/10], Training Loss: 1.133, Validation Accuracy: 58.24%
# Epoch [2/10], Training Loss: 1.095, Validation Accuracy: 57.45%
# Epoch [3/10], Training Loss: 1.069, Validation Accuracy: 58.39%
# Epoch [4/10], Training Loss: 1.052, Validation Accuracy: 57.47%
# Epoch [5/10], Training Loss: 1.041, Validation Accuracy: 58.61%
# Epoch [6/10], Training Loss: 1.021, Validation Accuracy: 57.96%
# Epoch [7/10], Training Loss: 1.009, Validation Accuracy: 58.66%
# Epoch [8/10], Training Loss: 0.999, Validation Accuracy: 58.66%
# Epoch [9/10], Training Loss: 0.982, Validation Accuracy: 58.67%
# Epoch [10/10], Training Loss: 0.976, Validation Accuracy: 58.32%
# Epoch [1/10], Training Loss: 1.103, Validation Accuracy: 57.77%
# Epoch [2/10], Training Loss: 1.060, Validation Accuracy: 57.22%
# Epoch [3/10], Training Loss: 1.041, Validation Accuracy: 57.65%
# Epoch [4/10], Training Loss: 1.017, Validation Accuracy: 58.20%
# Epoch [5/10], Training Loss: 1.004, Validation Accuracy: 58.58%
# Epoch [6/10], Training Loss: 0.991, Validation Accuracy: 58.31%
# Epoch [7/10], Training Loss: 0.972, Validation Accuracy: 57.88%
# Epoch [8/10], Training Loss: 0.957, Validation Accuracy: 57.76%
# Epoch [9/10], Training Loss: 0.947, Validation Accuracy: 58.13%
# Epoch [10/10], Training Loss: 0.937, Validation Accuracy: 58.02%
# Epoch [1/10], Training Loss: 1.083, Validation Accuracy: 58.14%
# Epoch [2/10], Training Loss: 1.036, Validation Accuracy: 58.65%
# Epoch [3/10], Training Loss: 1.003, Validation Accuracy: 58.92%
# Epoch [4/10], Training Loss: 0.986, Validation Accuracy: 58.72%
# Epoch [5/10], Training Loss: 0.969, Validation Accuracy: 58.87%
# Epoch [6/10], Training Loss: 0.952, Validation Accuracy: 58.40%
# Epoch [7/10], Training Loss: 0.947, Validation Accuracy: 58.89%
# Epoch [8/10], Training Loss: 0.930, Validation Accuracy: 58.85%
# Epoch [9/10], Training Loss: 0.920, Validation Accuracy: 58.56%
# Epoch [10/10], Training Loss: 0.902, Validation Accuracy: 58.32%
# Epoch [1/10], Training Loss: 1.072, Validation Accuracy: 58.21%
# Epoch [2/10], Training Loss: 1.025, Validation Accuracy: 57.95%
# Epoch [3/10], Training Loss: 1.003, Validation Accuracy: 58.95%
# Epoch [4/10], Training Loss: 0.978, Validation Accuracy: 59.10%
# Epoch [5/10], Training Loss: 0.955, Validation Accuracy: 58.59%
# Epoch [6/10], Training Loss: 0.937, Validation Accuracy: 59.06%
# Epoch [7/10], Training Loss: 0.931, Validation Accuracy: 58.44%
# Epoch [8/10], Training Loss: 0.917, Validation Accuracy: 58.72%
# Epoch [9/10], Training Loss: 0.902, Validation Accuracy: 58.64%
# Epoch [10/10], Training Loss: 0.887, Validation Accuracy: 58.63%
# Epoch [1/10], Training Loss: 1.098, Validation Accuracy: 58.89%
# Epoch [2/10], Training Loss: 1.050, Validation Accuracy: 58.58%
# Epoch [3/10], Training Loss: 1.024, Validation Accuracy: 58.43%
# Epoch [4/10], Training Loss: 0.992, Validation Accuracy: 59.07%
# Epoch [5/10], Training Loss: 0.984, Validation Accuracy: 58.56%
# Epoch [6/10], Training Loss: 0.961, Validation Accuracy: 57.67%
# Epoch [7/10], Training Loss: 0.945, Validation Accuracy: 59.01%
# Epoch [8/10], Training Loss: 0.923, Validation Accuracy: 58.13%
# Epoch [9/10], Training Loss: 0.917, Validation Accuracy: 59.00%
# Epoch [10/10], Training Loss: 0.899, Validation Accuracy: 58.77%
# Epoch [1/10], Training Loss: 1.064, Validation Accuracy: 59.22%
# Epoch [2/10], Training Loss: 1.009, Validation Accuracy: 59.14%
# Epoch [3/10], Training Loss: 0.981, Validation Accuracy: 58.75%
# Epoch [4/10], Training Loss: 0.963, Validation Accuracy: 58.93%
# Epoch [5/10], Training Loss: 0.934, Validation Accuracy: 59.39%
# Epoch [6/10], Training Loss: 0.920, Validation Accuracy: 58.91%
# Epoch [7/10], Training Loss: 0.904, Validation Accuracy: 59.02%
# Epoch [8/10], Training Loss: 0.891, Validation Accuracy: 59.14%
# Epoch [9/10], Training Loss: 0.882, Validation Accuracy: 59.45%
# Epoch [10/10], Training Loss: 0.864, Validation Accuracy: 58.89%
# Epoch [1/10], Training Loss: 1.040, Validation Accuracy: 58.48%
# Epoch [2/10], Training Loss: 0.990, Validation Accuracy: 59.86%
# Epoch [3/10], Training Loss: 0.957, Validation Accuracy: 58.57%
# Epoch [4/10], Training Loss: 0.940, Validation Accuracy: 59.03%
# Epoch [5/10], Training Loss: 0.911, Validation Accuracy: 59.06%
# Epoch [6/10], Training Loss: 0.895, Validation Accuracy: 59.16%
# Epoch [7/10], Training Loss: 0.882, Validation Accuracy: 58.65%
# Epoch [8/10], Training Loss: 0.859, Validation Accuracy: 59.55%
# Epoch [9/10], Training Loss: 0.853, Validation Accuracy: 57.75%
# Epoch [10/10], Training Loss: 0.832, Validation Accuracy: 58.97%
# Epoch [1/10], Training Loss: 1.028, Validation Accuracy: 57.72%
# Epoch [2/10], Training Loss: 0.968, Validation Accuracy: 59.62%
# Epoch [3/10], Training Loss: 0.931, Validation Accuracy: 59.35%
# Epoch [4/10], Training Loss: 0.900, Validation Accuracy: 58.99%
# Epoch [5/10], Training Loss: 0.872, Validation Accuracy: 59.48%
# Epoch [6/10], Training Loss: 0.859, Validation Accuracy: 58.58%
# Epoch [7/10], Training Loss: 0.848, Validation Accuracy: 59.94%
# Epoch [8/10], Training Loss: 0.826, Validation Accuracy: 59.61%
# Epoch [9/10], Training Loss: 0.817, Validation Accuracy: 59.33%
# Epoch [10/10], Training Loss: 0.797, Validation Accuracy: 59.66%
# Epoch [1/10], Training Loss: 1.008, Validation Accuracy: 58.76%
# Epoch [2/10], Training Loss: 0.948, Validation Accuracy: 58.86%
# Epoch [3/10], Training Loss: 0.928, Validation Accuracy: 59.44%
# Epoch [4/10], Training Loss: 0.896, Validation Accuracy: 58.60%
# Epoch [5/10], Training Loss: 0.872, Validation Accuracy: 58.87%
# Epoch [6/10], Training Loss: 0.843, Validation Accuracy: 58.41%
# Epoch [7/10], Training Loss: 0.832, Validation Accuracy: 59.27%
# Epoch [8/10], Training Loss: 0.815, Validation Accuracy: 59.38%
# Epoch [9/10], Training Loss: 0.797, Validation Accuracy: 59.28%
# Epoch [10/10], Training Loss: 0.790, Validation Accuracy: 59.17%
# Epoch [1/10], Training Loss: 1.038, Validation Accuracy: 59.12%
# Epoch [2/10], Training Loss: 0.981, Validation Accuracy: 58.57%
# Epoch [3/10], Training Loss: 0.941, Validation Accuracy: 58.62%
# Epoch [4/10], Training Loss: 0.911, Validation Accuracy: 59.66%
# Epoch [5/10], Training Loss: 0.885, Validation Accuracy: 59.48%
# Epoch [6/10], Training Loss: 0.857, Validation Accuracy: 59.33%
# Epoch [7/10], Training Loss: 0.850, Validation Accuracy: 58.82%
# Epoch [8/10], Training Loss: 0.825, Validation Accuracy: 59.20%
# Epoch [9/10], Training Loss: 0.822, Validation Accuracy: 58.47%
# Epoch [10/10], Training Loss: 0.790, Validation Accuracy: 59.07%
# Epoch [1/10], Training Loss: 1.007, Validation Accuracy: 59.09%
# Epoch [2/10], Training Loss: 0.945, Validation Accuracy: 59.40%
# Epoch [3/10], Training Loss: 0.898, Validation Accuracy: 59.93%
# Epoch [4/10], Training Loss: 0.876, Validation Accuracy: 59.42%
# Epoch [5/10], Training Loss: 0.845, Validation Accuracy: 59.84%
# Epoch [6/10], Training Loss: 0.827, Validation Accuracy: 59.41%
# Epoch [7/10], Training Loss: 0.816, Validation Accuracy: 58.89%
# Epoch [8/10], Training Loss: 0.794, Validation Accuracy: 59.65%
# Epoch [9/10], Training Loss: 0.774, Validation Accuracy: 59.57%
# Epoch [10/10], Training Loss: 0.754, Validation Accuracy: 59.11%
# Epoch [1/10], Training Loss: 0.994, Validation Accuracy: 58.58%
# Epoch [2/10], Training Loss: 0.930, Validation Accuracy: 59.82%
# Epoch [3/10], Training Loss: 0.876, Validation Accuracy: 59.15%
# Epoch [4/10], Training Loss: 0.855, Validation Accuracy: 60.03%
# Epoch [5/10], Training Loss: 0.829, Validation Accuracy: 59.84%
# Epoch [6/10], Training Loss: 0.805, Validation Accuracy: 59.85%
# Epoch [7/10], Training Loss: 0.784, Validation Accuracy: 59.44%
# Epoch [8/10], Training Loss: 0.766, Validation Accuracy: 58.89%
# Epoch [9/10], Training Loss: 0.747, Validation Accuracy: 59.61%
# Epoch [10/10], Training Loss: 0.733, Validation Accuracy: 59.51%
# Epoch [1/10], Training Loss: 0.974, Validation Accuracy: 59.42%
# Epoch [2/10], Training Loss: 0.893, Validation Accuracy: 59.28%
# Epoch [3/10], Training Loss: 0.860, Validation Accuracy: 59.11%
# Epoch [4/10], Training Loss: 0.826, Validation Accuracy: 59.75%
# Epoch [5/10], Training Loss: 0.799, Validation Accuracy: 59.08%
# Epoch [6/10], Training Loss: 0.769, Validation Accuracy: 59.12%
# Epoch [7/10], Training Loss: 0.749, Validation Accuracy: 59.96%
# Epoch [8/10], Training Loss: 0.740, Validation Accuracy: 59.73%
# Epoch [9/10], Training Loss: 0.713, Validation Accuracy: 59.40%
# Epoch [10/10], Training Loss: 0.698, Validation Accuracy: 59.29%
# Epoch [1/10], Training Loss: 0.972, Validation Accuracy: 58.40%
# Epoch [2/10], Training Loss: 0.888, Validation Accuracy: 59.09%
# Epoch [3/10], Training Loss: 0.835, Validation Accuracy: 59.66%
# Epoch [4/10], Training Loss: 0.812, Validation Accuracy: 58.79%
# Epoch [5/10], Training Loss: 0.786, Validation Accuracy: 58.93%
# Epoch [6/10], Training Loss: 0.766, Validation Accuracy: 59.65%
# Epoch [7/10], Training Loss: 0.746, Validation Accuracy: 58.93%
# Epoch [8/10], Training Loss: 0.724, Validation Accuracy: 58.91%
# Epoch [9/10], Training Loss: 0.702, Validation Accuracy: 59.37%
# Epoch [10/10], Training Loss: 0.685, Validation Accuracy: 59.14%
# Epoch [1/10], Training Loss: 0.989, Validation Accuracy: 59.94%
# Epoch [2/10], Training Loss: 0.903, Validation Accuracy: 60.23%
# Epoch [3/10], Training Loss: 0.860, Validation Accuracy: 59.71%
# Epoch [4/10], Training Loss: 0.826, Validation Accuracy: 59.05%
# Epoch [5/10], Training Loss: 0.803, Validation Accuracy: 59.24%
# Epoch [6/10], Training Loss: 0.768, Validation Accuracy: 58.96%
# Epoch [7/10], Training Loss: 0.747, Validation Accuracy: 59.49%
# Epoch [8/10], Training Loss: 0.724, Validation Accuracy: 59.44%
# Epoch [9/10], Training Loss: 0.703, Validation Accuracy: 59.14%
# Epoch [10/10], Training Loss: 0.692, Validation Accuracy: 59.11%
# Epoch [1/10], Training Loss: 0.961, Validation Accuracy: 59.58%
# Epoch [2/10], Training Loss: 0.874, Validation Accuracy: 60.35%
# Epoch [3/10], Training Loss: 0.828, Validation Accuracy: 59.63%
# Epoch [4/10], Training Loss: 0.783, Validation Accuracy: 59.00%
# Epoch [5/10], Training Loss: 0.768, Validation Accuracy: 60.12%
# Epoch [6/10], Training Loss: 0.740, Validation Accuracy: 59.79%
# Epoch [7/10], Training Loss: 0.719, Validation Accuracy: 59.60%
# Epoch [8/10], Training Loss: 0.703, Validation Accuracy: 59.22%
# Epoch [9/10], Training Loss: 0.687, Validation Accuracy: 59.49%
# Epoch [10/10], Training Loss: 0.664, Validation Accuracy: 59.32%
# Epoch [1/10], Training Loss: 0.942, Validation Accuracy: 59.47%
# Epoch [2/10], Training Loss: 0.873, Validation Accuracy: 59.50%
# Epoch [3/10], Training Loss: 0.809, Validation Accuracy: 59.58%
# Epoch [4/10], Training Loss: 0.775, Validation Accuracy: 59.63%
# Epoch [5/10], Training Loss: 0.744, Validation Accuracy: 59.78%
# Epoch [6/10], Training Loss: 0.730, Validation Accuracy: 59.10%
# Epoch [7/10], Training Loss: 0.690, Validation Accuracy: 58.98%
# Epoch [8/10], Training Loss: 0.684, Validation Accuracy: 59.62%
# Epoch [9/10], Training Loss: 0.659, Validation Accuracy: 58.76%
# Epoch [10/10], Training Loss: 0.640, Validation Accuracy: 59.64%
# Epoch [1/10], Training Loss: 0.934, Validation Accuracy: 59.34%
# Epoch [2/10], Training Loss: 0.835, Validation Accuracy: 59.62%
# Epoch [3/10], Training Loss: 0.781, Validation Accuracy: 58.93%
# Epoch [4/10], Training Loss: 0.754, Validation Accuracy: 59.92%
# Epoch [5/10], Training Loss: 0.718, Validation Accuracy: 59.58%
# Epoch [6/10], Training Loss: 0.686, Validation Accuracy: 59.22%
# Epoch [7/10], Training Loss: 0.655, Validation Accuracy: 59.31%
# Epoch [8/10], Training Loss: 0.641, Validation Accuracy: 59.73%
# Epoch [9/10], Training Loss: 0.620, Validation Accuracy: 58.79%
# Epoch [10/10], Training Loss: 0.600, Validation Accuracy: 59.58%
# Epoch [1/10], Training Loss: 0.924, Validation Accuracy: 59.20%
# Epoch [2/10], Training Loss: 0.825, Validation Accuracy: 59.28%
# Epoch [3/10], Training Loss: 0.768, Validation Accuracy: 59.72%
# Epoch [4/10], Training Loss: 0.729, Validation Accuracy: 59.62%
# Epoch [5/10], Training Loss: 0.707, Validation Accuracy: 58.87%
# Epoch [6/10], Training Loss: 0.684, Validation Accuracy: 59.60%
# Epoch [7/10], Training Loss: 0.655, Validation Accuracy: 59.53%
# Epoch [8/10], Training Loss: 0.637, Validation Accuracy: 59.28%
# Epoch [9/10], Training Loss: 0.602, Validation Accuracy: 58.76%
# Epoch [10/10], Training Loss: 0.598, Validation Accuracy: 59.09%
# Epoch [1/10], Training Loss: 0.951, Validation Accuracy: 59.00%
# Epoch [2/10], Training Loss: 0.837, Validation Accuracy: 59.48%
# Epoch [3/10], Training Loss: 0.780, Validation Accuracy: 59.78%
# Epoch [4/10], Training Loss: 0.743, Validation Accuracy: 59.42%
# Epoch [5/10], Training Loss: 0.706, Validation Accuracy: 59.57%
# Epoch [6/10], Training Loss: 0.685, Validation Accuracy: 59.15%
# Epoch [7/10], Training Loss: 0.653, Validation Accuracy: 58.47%
# Epoch [8/10], Training Loss: 0.648, Validation Accuracy: 59.40%
# Epoch [9/10], Training Loss: 0.607, Validation Accuracy: 59.08%
# Epoch [10/10], Training Loss: 0.587, Validation Accuracy: 58.67%
# Epoch [1/10], Training Loss: 0.922, Validation Accuracy: 59.62%
# Epoch [2/10], Training Loss: 0.813, Validation Accuracy: 59.02%
# Epoch [3/10], Training Loss: 0.754, Validation Accuracy: 59.23%
# Epoch [4/10], Training Loss: 0.723, Validation Accuracy: 59.64%
# Epoch [5/10], Training Loss: 0.704, Validation Accuracy: 59.25%
# Epoch [6/10], Training Loss: 0.664, Validation Accuracy: 59.02%
# Epoch [7/10], Training Loss: 0.634, Validation Accuracy: 59.16%
# Epoch [8/10], Training Loss: 0.610, Validation Accuracy: 59.08%
# Epoch [9/10], Training Loss: 0.581, Validation Accuracy: 59.11%
# Epoch [10/10], Training Loss: 0.562, Validation Accuracy: 58.71%
# Epoch [1/10], Training Loss: 0.917, Validation Accuracy: 58.74%
# Epoch [2/10], Training Loss: 0.802, Validation Accuracy: 60.28%
# Epoch [3/10], Training Loss: 0.734, Validation Accuracy: 59.21%
# Epoch [4/10], Training Loss: 0.700, Validation Accuracy: 59.97%
# Epoch [5/10], Training Loss: 0.673, Validation Accuracy: 59.09%
# Epoch [6/10], Training Loss: 0.644, Validation Accuracy: 58.89%
# Epoch [7/10], Training Loss: 0.616, Validation Accuracy: 59.39%
# Epoch [8/10], Training Loss: 0.584, Validation Accuracy: 59.19%
# Epoch [9/10], Training Loss: 0.567, Validation Accuracy: 58.25%
# Epoch [10/10], Training Loss: 0.554, Validation Accuracy: 58.20%
# Epoch [1/10], Training Loss: 0.895, Validation Accuracy: 57.76%
# Epoch [2/10], Training Loss: 0.779, Validation Accuracy: 59.39%
# Epoch [3/10], Training Loss: 0.721, Validation Accuracy: 59.19%
# Epoch [4/10], Training Loss: 0.675, Validation Accuracy: 59.72%
# Epoch [5/10], Training Loss: 0.634, Validation Accuracy: 59.31%
# Epoch [6/10], Training Loss: 0.604, Validation Accuracy: 59.28%
# Epoch [7/10], Training Loss: 0.583, Validation Accuracy: 59.12%
# Epoch [8/10], Training Loss: 0.551, Validation Accuracy: 59.71%
# Epoch [9/10], Training Loss: 0.530, Validation Accuracy: 58.56%
# Epoch [10/10], Training Loss: 0.517, Validation Accuracy: 58.71%
# Epoch [1/10], Training Loss: 0.878, Validation Accuracy: 59.28%
# Epoch [2/10], Training Loss: 0.757, Validation Accuracy: 58.92%
# Epoch [3/10], Training Loss: 0.708, Validation Accuracy: 59.16%
# Epoch [4/10], Training Loss: 0.656, Validation Accuracy: 59.08%
# Epoch [5/10], Training Loss: 0.618, Validation Accuracy: 58.64%
# Epoch [6/10], Training Loss: 0.590, Validation Accuracy: 59.49%
# Epoch [7/10], Training Loss: 0.560, Validation Accuracy: 59.13%
# Epoch [8/10], Training Loss: 0.543, Validation Accuracy: 58.89%
# Epoch [9/10], Training Loss: 0.524, Validation Accuracy: 59.15%
# Epoch [10/10], Training Loss: 0.508, Validation Accuracy: 58.79%
# Epoch [1/10], Training Loss: 0.912, Validation Accuracy: 58.97%
# Epoch [2/10], Training Loss: 0.775, Validation Accuracy: 58.51%
# Epoch [3/10], Training Loss: 0.704, Validation Accuracy: 58.70%
# Epoch [4/10], Training Loss: 0.663, Validation Accuracy: 59.19%
# Epoch [5/10], Training Loss: 0.624, Validation Accuracy: 59.16%
# Epoch [6/10], Training Loss: 0.591, Validation Accuracy: 58.35%
# Epoch [7/10], Training Loss: 0.572, Validation Accuracy: 59.58%
# Epoch [8/10], Training Loss: 0.535, Validation Accuracy: 59.12%
# Epoch [9/10], Training Loss: 0.508, Validation Accuracy: 58.83%
# Epoch [10/10], Training Loss: 0.499, Validation Accuracy: 58.62%
# Epoch [1/10], Training Loss: 0.882, Validation Accuracy: 58.80%
# Epoch [2/10], Training Loss: 0.755, Validation Accuracy: 58.95%
# Epoch [3/10], Training Loss: 0.697, Validation Accuracy: 59.09%
# Epoch [4/10], Training Loss: 0.647, Validation Accuracy: 58.38%
# Epoch [5/10], Training Loss: 0.604, Validation Accuracy: 59.02%
# Epoch [6/10], Training Loss: 0.575, Validation Accuracy: 59.33%
# Epoch [7/10], Training Loss: 0.547, Validation Accuracy: 58.11%
# Epoch [8/10], Training Loss: 0.522, Validation Accuracy: 58.67%
# Epoch [9/10], Training Loss: 0.501, Validation Accuracy: 58.86%
# Epoch [10/10], Training Loss: 0.482, Validation Accuracy: 58.09%
# Epoch [1/10], Training Loss: 0.875, Validation Accuracy: 58.50%
# Epoch [2/10], Training Loss: 0.755, Validation Accuracy: 58.48%
# Epoch [3/10], Training Loss: 0.670, Validation Accuracy: 58.93%
# Epoch [4/10], Training Loss: 0.629, Validation Accuracy: 58.55%
# Epoch [5/10], Training Loss: 0.592, Validation Accuracy: 58.15%
# Epoch [6/10], Training Loss: 0.577, Validation Accuracy: 58.71%
# Epoch [7/10], Training Loss: 0.539, Validation Accuracy: 57.83%
# Epoch [8/10], Training Loss: 0.515, Validation Accuracy: 58.55%
# Epoch [9/10], Training Loss: 0.482, Validation Accuracy: 58.59%
# Epoch [10/10], Training Loss: 0.459, Validation Accuracy: 57.58%
# Epoch [1/10], Training Loss: 0.857, Validation Accuracy: 58.35%
# Epoch [2/10], Training Loss: 0.721, Validation Accuracy: 58.96%
# Epoch [3/10], Training Loss: 0.650, Validation Accuracy: 59.23%
# Epoch [4/10], Training Loss: 0.595, Validation Accuracy: 58.72%
# Epoch [5/10], Training Loss: 0.564, Validation Accuracy: 58.29%
# Epoch [6/10], Training Loss: 0.526, Validation Accuracy: 59.24%
# Epoch [7/10], Training Loss: 0.493, Validation Accuracy: 58.60%
# Epoch [8/10], Training Loss: 0.467, Validation Accuracy: 58.43%
# Epoch [9/10], Training Loss: 0.454, Validation Accuracy: 58.16%
# Epoch [10/10], Training Loss: 0.436, Validation Accuracy: 58.68%
# Confusion Matrix:
# [[696  44  48  19  32   6  24  10  76  45]
#  [ 51 727  16   9   6  10  14   5  42 120]
#  [ 94  23 458  71 109  85  87  38  20  15]
#  [ 29  20  69 349  73 257 116  35  23  29]
#  [ 41  13  96  51 487  94 104  82  17  15]
#  [ 23  12  59 152  45 587  49  56   7  10]
#  [ 15  16  53  78  52  55 701  11  10   9]
#  [ 31  23  40  63  79 113  16 591   6  38]
#  [100  71  28  13  20   9   7   5 694  53]
#  [ 60 196  25  24   9  19  21  22  37 587]]
# Test Accuracy: 58.77%
# True Positives (TP): [696 727 458 349 487 587 701 591 694 587]
# False Positives (FP): [444 418 434 480 425 648 438 264 238 334]
# True Negatives (TN): [8556 8582 8566 8520 8575 8352 8562 8736 8762 8666]
# False Negatives (FN): [304 273 542 651 513 413 299 409 306 413]
# : [10000 10000 10000 10000 10000 10000 10000 10000 10000 10000]
# Precision: [0.61052632 0.6349345  0.51345291 0.42098914 0.53399123 0.47530364
#  0.61545215 0.69122807 0.74463519 0.63735071]
# Recall: [0.696 0.727 0.458 0.349 0.487 0.587 0.701 0.591 0.694 0.587]
# F1 Score: [0.65046729 0.67785548 0.48414376 0.38162931 0.50941423 0.52527964
#  0.65544647 0.63719677 0.7184265  0.61114003]
