# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahad31/Different-VAE-for-KL-FedDis/blob/main/Beta_Uni_Trunc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Beta=.1

# %%
import numpy as np
from scipy.stats import truncnorm
import torch
import torchvision
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import Subset, DataLoader
from torchvision.datasets import CIFAR10
from typing import Dict, Tuple
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import random

# Define VAE model
class VAE(nn.Module):
    def __init__(self, x_dim, h_dim, z_dim):
        super(VAE, self).__init__()
        self.x_dim = x_dim
        self.h_dim = h_dim
        self.z_dim = z_dim

        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 32, 4, stride=2, padding=1),  # 16x16
            nn.ReLU(),
            nn.Conv2d(32, 64, 4, stride=2, padding=1),  # 8x8
            nn.ReLU(),
            nn.Conv2d(64, 128, 4, stride=2, padding=1),  # 4x4
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(2048, 256),
            nn.ReLU(),
            nn.Linear(256, 2*z_dim)
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(z_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 2048),
            nn.ReLU(),
            nn.Unflatten(1, (128, 4, 4)),
            nn.ConvTranspose2d(128, 64, 4, stride=2, padding=1),  # 8x8
            nn.ReLU(),
            nn.ConvTranspose2d(64, 32, 4, stride=2, padding=1),  # 16x16
            nn.ReLU(),
            nn.ConvTranspose2d(32, 3, 4, stride=2, padding=1),  # 32x32
            nn.Sigmoid()
        )

    def encode(self, x):
        h = self.encoder(x)
        mu, logvar = h[:, :self.z_dim], h[:, self.z_dim:]
        return mu, logvar

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z):
        return self.decoder(z)

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar


# Define VAE training procedure
def vae_train(vae: VAE, trainloader: DataLoader, epochs: int, beta: float =0.1):
    optimizer = torch.optim.Adam(vae.parameters(), lr=1e-3)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)

    for epoch in range(epochs):
        vae.train()
        for i, data in enumerate(trainloader, 0):
            inputs, _ = data
            optimizer.zero_grad()
            recon_x, mu, logvar = vae(inputs)
            loss = vae_loss(recon_x, inputs, mu, logvar , beta=beta)
            loss.backward()
            optimizer.step()

        scheduler.step()



# Define classification model
class Net(nn.Module):
    def __init__(self) -> None:
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.pool(nn.functional.relu(self.conv1(x)))
        x = self.pool(nn.functional.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = nn.functional.relu(self.fc1(x))
        x = nn.functional.relu(self.fc2(x))
        x = self.fc3(x)
        return x


# Load CIFAR10 dataset
transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]
)

full_dataset = CIFAR10(root="./data", train=True, download=True, transform=transform)
test_set = CIFAR10(root="./data", train=False, download=True, transform=transform)

# Separate dataset by class
class_indices = {i: [] for i in range(10)}  # CIFAR-10 has 10 classes
for idx, (_, label) in enumerate(full_dataset):
    class_indices[label].append(idx)

# Define target count per class, summing to 60,000 with random distribution
class_counts = np.random.multinomial(60000, [0.1] * 10)  # Adjust probabilities if you want specific class biases
print("Random Images per Class:", class_counts)

# Sample indices based on the specified class counts
indices = []
for class_id, count in enumerate(class_counts):
    # Ensure count does not exceed available images
    count = min(count, len(class_indices[class_id]))
    selected_indices = random.sample(class_indices[class_id], count)
    indices.extend(selected_indices)

# Create a custom CIFAR-10 dataset with the sampled indices
custom_dataset = Subset(full_dataset, indices)
# Split dataset into training and validation sets
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_set, val_set = torch.utils.data.random_split(full_dataset, [train_size, val_size])

# Create training and validation loaders
trainloader = DataLoader(train_set, batch_size=128, shuffle=True, num_workers=2)
valloader = DataLoader(val_set, batch_size=128, shuffle=False, num_workers=2)
testloader = DataLoader(test_set, batch_size=128, shuffle=False, num_workers=2)




# Define VAE loss function
def vae_loss(recon_x, x, mu, logvar, beta=0.1):
    BCE = nn.functional.mse_loss(recon_x, x, reduction='sum')
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return BCE + beta * KLD


# Define training procedure for classification model
def train(net: nn.Module, trainloader: DataLoader, valloader: DataLoader, epochs: int) -> None:
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)

    best_acc = 0.0

    for epoch in range(epochs):
        # Training loop
        net.train()
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            inputs, labels = data
            optimizer.zero_grad()
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        scheduler.step()

        # Validation loop
        net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data in valloader:
                images, labels = data
                outputs = net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_acc = 100 * correct / total
        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(net.state_dict(), 'best_model.pth')

        print(f"Epoch [{epoch+1}/{epochs}], Training Loss: {running_loss / (i+1):.3f}, Validation Accuracy: {val_acc:.2f}%")

# Define evaluation procedure
def evaluate(net: nn.Module, testloader: DataLoader) -> Tuple[float, np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
    net.eval()
    correct = 0
    total = 0
    all_labels = []
    all_predictions = []
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    accuracy = 100 * correct / total

    # Calculate confusion matrix
    cm = confusion_matrix(all_labels, all_predictions)
    print(f"Confusion Matrix:\n{cm}")

    # Calculate TP, FP, TN, FN for each class
    tp = np.diag(cm)
    fp = cm.sum(axis=0) - tp
    fn = cm.sum(axis=1) - tp
    tn = cm.sum() - (fp + fn + tp)

    # Calculate precision, recall, and F1 score for each class
    precision = precision_score(all_labels, all_predictions, average=None)
    recall = recall_score(all_labels, all_predictions, average=None)
    f1 = f1_score(all_labels, all_predictions, average=None)

    return accuracy, tp, fp, tn, fn, precision, recall, f1

# Initialize clients
def initialize_clients(trainset, transform, batch_size, num_clients):
    clients = {}
    for i in range(num_clients):
        client_trainset = torch.utils.data.Subset(trainset, range(i * len(trainset) // num_clients, (i + 1) * len(trainset) // num_clients))
        client_trainloader = torch.utils.data.DataLoader(client_trainset, batch_size=batch_size, shuffle=True)
        clients[f"client_{i}"] = client_trainloader
    return clients

def get_distribution_info(vae: VAE) -> Dict:
    # Implement the logic to extract distribution information from the VAE
    # This can involve computing statistics, parameters, or any other relevant information
    # that can be used to generate augmented data

    # Example implementation:
    distribution_info = {
        "uniform": {
            "mean": vae.encoder[-1].bias.data.cpu().numpy(),
            "std": torch.exp(0.5 * vae.encoder[-1].weight.data).cpu().numpy()
        },
        "normal": {
            "mean": vae.encoder[-1].bias.data.cpu().numpy(),
            "std": torch.exp(0.5 * vae.encoder[-1].weight.data).cpu().numpy()
        }
    }

    return distribution_info

def send_distribution_info(distribution_info: Dict) -> None:
    # Implement the logic to send the distribution information to the global server
    # This can involve using a network protocol, a message queue, or any other communication mechanism
    # to send the information

    # Example implementation:
    # Send the distribution information to the global server using a network protocol
    # For example, you can use the `socket` module to send the information over a network
    # or use a message queue like `RabbitMQ` to send the information
    pass

def generate_augmented_data(vae: VAE, distribution_info_uniform: Dict, distribution_info_normal: Dict) -> torch.Tensor:
    # Generate augmented data using both uniform and truncated uniform distributions

    mean = distribution_info_uniform["mean"].mean().item()  # Convert numpy array to float
    std = distribution_info_uniform["std"].mean().item()  # Convert numpy array to float


    mean_normal = distribution_info_normal["mean"]
    std_normal = distribution_info_normal["std"]

    augmented_data_normal = torch.randn(64, vae.z_dim) * std_normal + mean_normal

     # Generate augmented data using Uniform distribution
    augmented_data_uniform = torch.FloatTensor(64, vae.z_dim).uniform_(mean - std, mean + std)


    # Calculate the average of augmented data from both distributions
    augmented_data_average = (augmented_data_uniform + augmented_data_normal ) / 2

    return augmented_data_average

def federated_train(net: nn.Module, vae: VAE, trainloaders: Dict[str, DataLoader], trainloader: DataLoader, valloader: DataLoader, epochs: int) -> None:
    for epoch in range(epochs):
        for client_id, client_trainloader in trainloaders.items():
            # Train VAE on client data
            vae_train(vae, client_trainloader, epochs=10, beta=0.1)

            # Share distribution information with global server
            distribution_info = get_distribution_info(vae)
            send_distribution_info(distribution_info)

            # Receive distribution information from other clients
            other_distribution_info = receive_distribution_info()

            # Generate augmented data using received distribution information
            augmented_data = generate_augmented_data(vae, other_distribution_info["uniform"], other_distribution_info["normal"])

            # Train classification model using local, augmented, and validation data
            train(net, client_trainloader, valloader, epochs=10)

            # Send model updates to global server
            send_model_update(client_id, net.state_dict())

# Define logic to receive distribution information from global server
def receive_distribution_info() -> Dict:
    # Receive distribution information logic
    distribution_info = {
        "uniform": {
            "mean": np.zeros(20),  # Adjust the size based on your latent space dimension
            "std": np.ones(20)
        },
        "normal": {
            "mean": np.zeros(20),  # Adjust the size based on your latent space dimension
            "std": np.ones(20)
        }
    }
    return distribution_info

def send_model_update(client_id: str, model_update: Dict) -> None:
    # Implement the logic to send the model update to the global server
    # This can involve using a network protocol, a message queue, or any other communication mechanism
    # to send the model update

    # Example implementation:
    # Send the model update to the global server using a network protocol
    # For example, you can use the `socket` module to send the information over a network
    # or use a message queue like `RabbitMQ` to send the information
    pass

# Define global server procedure
def global_server() -> None:
    net = Net()
    x_dim = 3 * 32 * 32  # CIFAR-10 input size
    h_dim = 400
    z_dim = 20
    vae = VAE(x_dim, h_dim, z_dim)  # Initialize VAE object with required arguments

    # Initialize clients
    num_clients = 5  # Define the number of clients
    clients = initialize_clients(train_set, transform, batch_size=128, num_clients=num_clients)

    # Train model using FedDIS
    federated_train(net, vae, clients, trainloader, valloader, epochs=10)

    # Evaluate final model
    test_accuracy, tp, fp, tn, fn, precision, recall, f1 = evaluate(net, testloader)
    print(f"Test Accuracy: {test_accuracy:.2f}%")

    print("True Positives (TP):", tp)
    print("False Positives (FP):", fp)
    print("True Negatives (TN):", tn)
    print("False Negatives (FN):", fn)
    print(":", fn+tn+tp+fp)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)

if __name__ == "__main__":
    global_server()
# Out:
# 100%|██████████| 170M/170M [00:02<00:00, 69.1MB/s]
# Random Images per Class: [5893 6152 6063 5953 6013 6066 5914 6053 5926 5967]
# /tmp/ipython-input-1-2672262166.py:283: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   augmented_data_normal = torch.randn(64, vae.z_dim) * std_normal + mean_normal
# Epoch [1/10], Training Loss: 2.304, Validation Accuracy: 10.54%
# Epoch [2/10], Training Loss: 2.302, Validation Accuracy: 10.68%
# Epoch [3/10], Training Loss: 2.300, Validation Accuracy: 12.05%
# Epoch [4/10], Training Loss: 2.299, Validation Accuracy: 13.80%
# Epoch [5/10], Training Loss: 2.296, Validation Accuracy: 14.89%
# Epoch [6/10], Training Loss: 2.293, Validation Accuracy: 15.71%
# Epoch [7/10], Training Loss: 2.289, Validation Accuracy: 16.57%
# Epoch [8/10], Training Loss: 2.284, Validation Accuracy: 18.38%
# Epoch [9/10], Training Loss: 2.276, Validation Accuracy: 18.15%
# Epoch [10/10], Training Loss: 2.264, Validation Accuracy: 17.43%
# Epoch [1/10], Training Loss: 2.249, Validation Accuracy: 17.42%
# Epoch [2/10], Training Loss: 2.225, Validation Accuracy: 17.12%
# Epoch [3/10], Training Loss: 2.195, Validation Accuracy: 18.14%
# Epoch [4/10], Training Loss: 2.163, Validation Accuracy: 21.13%
# Epoch [5/10], Training Loss: 2.136, Validation Accuracy: 23.99%
# Epoch [6/10], Training Loss: 2.115, Validation Accuracy: 25.31%
# Epoch [7/10], Training Loss: 2.097, Validation Accuracy: 26.04%
# Epoch [8/10], Training Loss: 2.077, Validation Accuracy: 27.31%
# Epoch [9/10], Training Loss: 2.053, Validation Accuracy: 28.21%
# Epoch [10/10], Training Loss: 2.031, Validation Accuracy: 28.72%
# Epoch [1/10], Training Loss: 2.028, Validation Accuracy: 29.68%
# Epoch [2/10], Training Loss: 2.007, Validation Accuracy: 30.03%
# Epoch [3/10], Training Loss: 1.986, Validation Accuracy: 30.15%
# Epoch [4/10], Training Loss: 1.967, Validation Accuracy: 30.54%
# Epoch [5/10], Training Loss: 1.945, Validation Accuracy: 30.73%
# Epoch [6/10], Training Loss: 1.923, Validation Accuracy: 30.05%
# Epoch [7/10], Training Loss: 1.907, Validation Accuracy: 32.28%
# Epoch [8/10], Training Loss: 1.883, Validation Accuracy: 32.29%
# Epoch [9/10], Training Loss: 1.870, Validation Accuracy: 32.60%
# Epoch [10/10], Training Loss: 1.848, Validation Accuracy: 33.10%
# Epoch [1/10], Training Loss: 1.850, Validation Accuracy: 34.06%
# Epoch [2/10], Training Loss: 1.825, Validation Accuracy: 34.22%
# Epoch [3/10], Training Loss: 1.809, Validation Accuracy: 35.57%
# Epoch [4/10], Training Loss: 1.793, Validation Accuracy: 35.93%
# Epoch [5/10], Training Loss: 1.781, Validation Accuracy: 35.31%
# Epoch [6/10], Training Loss: 1.768, Validation Accuracy: 36.15%
# Epoch [7/10], Training Loss: 1.757, Validation Accuracy: 37.19%
# Epoch [8/10], Training Loss: 1.743, Validation Accuracy: 36.78%
# Epoch [9/10], Training Loss: 1.735, Validation Accuracy: 36.86%
# Epoch [10/10], Training Loss: 1.726, Validation Accuracy: 36.78%
# Epoch [1/10], Training Loss: 1.731, Validation Accuracy: 37.06%
# Epoch [2/10], Training Loss: 1.722, Validation Accuracy: 37.24%
# Epoch [3/10], Training Loss: 1.707, Validation Accuracy: 38.97%
# Epoch [4/10], Training Loss: 1.700, Validation Accuracy: 36.44%
# Epoch [5/10], Training Loss: 1.691, Validation Accuracy: 38.86%
# Epoch [6/10], Training Loss: 1.681, Validation Accuracy: 38.61%
# Epoch [7/10], Training Loss: 1.681, Validation Accuracy: 38.99%
# Epoch [8/10], Training Loss: 1.663, Validation Accuracy: 39.29%
# Epoch [9/10], Training Loss: 1.653, Validation Accuracy: 38.35%
# Epoch [10/10], Training Loss: 1.644, Validation Accuracy: 39.31%
# Epoch [1/10], Training Loss: 1.664, Validation Accuracy: 40.24%
# Epoch [2/10], Training Loss: 1.650, Validation Accuracy: 40.51%
# Epoch [3/10], Training Loss: 1.635, Validation Accuracy: 38.08%
# Epoch [4/10], Training Loss: 1.634, Validation Accuracy: 40.66%
# Epoch [5/10], Training Loss: 1.615, Validation Accuracy: 40.79%
# Epoch [6/10], Training Loss: 1.611, Validation Accuracy: 41.15%
# Epoch [7/10], Training Loss: 1.595, Validation Accuracy: 40.99%
# Epoch [8/10], Training Loss: 1.593, Validation Accuracy: 41.12%
# Epoch [9/10], Training Loss: 1.583, Validation Accuracy: 40.85%
# Epoch [10/10], Training Loss: 1.569, Validation Accuracy: 42.35%
# Epoch [1/10], Training Loss: 1.591, Validation Accuracy: 42.51%
# Epoch [2/10], Training Loss: 1.571, Validation Accuracy: 43.00%
# Epoch [3/10], Training Loss: 1.561, Validation Accuracy: 41.41%
# Epoch [4/10], Training Loss: 1.557, Validation Accuracy: 42.98%
# Epoch [5/10], Training Loss: 1.541, Validation Accuracy: 43.18%
# Epoch [6/10], Training Loss: 1.531, Validation Accuracy: 43.38%
# Epoch [7/10], Training Loss: 1.526, Validation Accuracy: 42.54%
# Epoch [8/10], Training Loss: 1.512, Validation Accuracy: 43.73%
# Epoch [9/10], Training Loss: 1.505, Validation Accuracy: 44.31%
# Epoch [10/10], Training Loss: 1.494, Validation Accuracy: 44.52%
# Epoch [1/10], Training Loss: 1.528, Validation Accuracy: 44.69%
# Epoch [2/10], Training Loss: 1.513, Validation Accuracy: 45.28%
# Epoch [3/10], Training Loss: 1.498, Validation Accuracy: 45.02%
# Epoch [4/10], Training Loss: 1.488, Validation Accuracy: 45.25%
# Epoch [5/10], Training Loss: 1.480, Validation Accuracy: 45.75%
# Epoch [6/10], Training Loss: 1.468, Validation Accuracy: 46.18%
# Epoch [7/10], Training Loss: 1.465, Validation Accuracy: 44.50%
# Epoch [8/10], Training Loss: 1.459, Validation Accuracy: 45.84%
# Epoch [9/10], Training Loss: 1.442, Validation Accuracy: 46.31%
# Epoch [10/10], Training Loss: 1.431, Validation Accuracy: 46.75%
# Epoch [1/10], Training Loss: 1.466, Validation Accuracy: 47.12%
# Epoch [2/10], Training Loss: 1.449, Validation Accuracy: 46.76%
# Epoch [3/10], Training Loss: 1.439, Validation Accuracy: 47.88%
# Epoch [4/10], Training Loss: 1.434, Validation Accuracy: 47.68%
# Epoch [5/10], Training Loss: 1.419, Validation Accuracy: 47.42%
# Epoch [6/10], Training Loss: 1.413, Validation Accuracy: 48.03%
# Epoch [7/10], Training Loss: 1.408, Validation Accuracy: 47.42%
# Epoch [8/10], Training Loss: 1.394, Validation Accuracy: 47.34%
# Epoch [9/10], Training Loss: 1.384, Validation Accuracy: 47.32%
# Epoch [10/10], Training Loss: 1.377, Validation Accuracy: 48.26%
# Epoch [1/10], Training Loss: 1.407, Validation Accuracy: 49.13%
# Epoch [2/10], Training Loss: 1.392, Validation Accuracy: 48.55%
# Epoch [3/10], Training Loss: 1.379, Validation Accuracy: 49.36%
# Epoch [4/10], Training Loss: 1.369, Validation Accuracy: 48.96%
# Epoch [5/10], Training Loss: 1.362, Validation Accuracy: 49.45%
# Epoch [6/10], Training Loss: 1.349, Validation Accuracy: 49.22%
# Epoch [7/10], Training Loss: 1.344, Validation Accuracy: 49.54%
# Epoch [8/10], Training Loss: 1.331, Validation Accuracy: 49.87%
# Epoch [9/10], Training Loss: 1.322, Validation Accuracy: 49.52%
# Epoch [10/10], Training Loss: 1.322, Validation Accuracy: 50.10%
# Epoch [1/10], Training Loss: 1.381, Validation Accuracy: 49.96%
# Epoch [2/10], Training Loss: 1.362, Validation Accuracy: 49.96%
# Epoch [3/10], Training Loss: 1.353, Validation Accuracy: 50.37%
# Epoch [4/10], Training Loss: 1.329, Validation Accuracy: 50.52%
# Epoch [5/10], Training Loss: 1.326, Validation Accuracy: 50.39%
# Epoch [6/10], Training Loss: 1.309, Validation Accuracy: 50.66%
# Epoch [7/10], Training Loss: 1.302, Validation Accuracy: 50.12%
# Epoch [8/10], Training Loss: 1.302, Validation Accuracy: 50.87%
# Epoch [9/10], Training Loss: 1.291, Validation Accuracy: 51.31%
# Epoch [10/10], Training Loss: 1.284, Validation Accuracy: 50.53%
# Epoch [1/10], Training Loss: 1.334, Validation Accuracy: 51.29%
# Epoch [2/10], Training Loss: 1.316, Validation Accuracy: 51.83%
# Epoch [3/10], Training Loss: 1.307, Validation Accuracy: 51.85%
# Epoch [4/10], Training Loss: 1.292, Validation Accuracy: 52.28%
# Epoch [5/10], Training Loss: 1.285, Validation Accuracy: 52.03%
# Epoch [6/10], Training Loss: 1.273, Validation Accuracy: 51.71%
# Epoch [7/10], Training Loss: 1.268, Validation Accuracy: 52.24%
# Epoch [8/10], Training Loss: 1.257, Validation Accuracy: 51.43%
# Epoch [9/10], Training Loss: 1.249, Validation Accuracy: 52.59%
# Epoch [10/10], Training Loss: 1.251, Validation Accuracy: 52.14%
# Epoch [1/10], Training Loss: 1.304, Validation Accuracy: 52.80%
# Epoch [2/10], Training Loss: 1.286, Validation Accuracy: 53.36%
# Epoch [3/10], Training Loss: 1.274, Validation Accuracy: 52.49%
# Epoch [4/10], Training Loss: 1.266, Validation Accuracy: 53.44%
# Epoch [5/10], Training Loss: 1.248, Validation Accuracy: 53.11%
# Epoch [6/10], Training Loss: 1.243, Validation Accuracy: 52.92%
# Epoch [7/10], Training Loss: 1.238, Validation Accuracy: 53.62%
# Epoch [8/10], Training Loss: 1.230, Validation Accuracy: 53.14%
# Epoch [9/10], Training Loss: 1.226, Validation Accuracy: 53.34%
# Epoch [10/10], Training Loss: 1.214, Validation Accuracy: 53.72%
# Epoch [1/10], Training Loss: 1.275, Validation Accuracy: 53.79%
# Epoch [2/10], Training Loss: 1.259, Validation Accuracy: 53.22%
# Epoch [3/10], Training Loss: 1.250, Validation Accuracy: 53.44%
# Epoch [4/10], Training Loss: 1.244, Validation Accuracy: 54.07%
# Epoch [5/10], Training Loss: 1.220, Validation Accuracy: 54.12%
# Epoch [6/10], Training Loss: 1.218, Validation Accuracy: 53.61%
# Epoch [7/10], Training Loss: 1.219, Validation Accuracy: 53.71%
# Epoch [8/10], Training Loss: 1.204, Validation Accuracy: 54.44%
# Epoch [9/10], Training Loss: 1.196, Validation Accuracy: 52.19%
# Epoch [10/10], Training Loss: 1.184, Validation Accuracy: 54.04%
# Epoch [1/10], Training Loss: 1.248, Validation Accuracy: 54.07%
# Epoch [2/10], Training Loss: 1.222, Validation Accuracy: 54.46%
# Epoch [3/10], Training Loss: 1.199, Validation Accuracy: 54.59%
# Epoch [4/10], Training Loss: 1.183, Validation Accuracy: 53.55%
# Epoch [5/10], Training Loss: 1.182, Validation Accuracy: 54.65%
# Epoch [6/10], Training Loss: 1.170, Validation Accuracy: 55.06%
# Epoch [7/10], Training Loss: 1.163, Validation Accuracy: 54.08%
# Epoch [8/10], Training Loss: 1.161, Validation Accuracy: 54.24%
# Epoch [9/10], Training Loss: 1.141, Validation Accuracy: 54.82%
# Epoch [10/10], Training Loss: 1.131, Validation Accuracy: 54.49%
# Epoch [1/10], Training Loss: 1.229, Validation Accuracy: 55.22%
# Epoch [2/10], Training Loss: 1.203, Validation Accuracy: 55.12%
# Epoch [3/10], Training Loss: 1.184, Validation Accuracy: 53.14%
# Epoch [4/10], Training Loss: 1.174, Validation Accuracy: 55.37%
# Epoch [5/10], Training Loss: 1.172, Validation Accuracy: 55.88%
# Epoch [6/10], Training Loss: 1.148, Validation Accuracy: 56.00%
# Epoch [7/10], Training Loss: 1.147, Validation Accuracy: 55.04%
# Epoch [8/10], Training Loss: 1.140, Validation Accuracy: 55.23%
# Epoch [9/10], Training Loss: 1.126, Validation Accuracy: 55.92%
# Epoch [10/10], Training Loss: 1.122, Validation Accuracy: 55.39%
# Epoch [1/10], Training Loss: 1.206, Validation Accuracy: 55.74%
# Epoch [2/10], Training Loss: 1.174, Validation Accuracy: 55.21%
# Epoch [3/10], Training Loss: 1.170, Validation Accuracy: 56.02%
# Epoch [4/10], Training Loss: 1.148, Validation Accuracy: 55.99%
# Epoch [5/10], Training Loss: 1.133, Validation Accuracy: 55.15%
# Epoch [6/10], Training Loss: 1.137, Validation Accuracy: 55.48%
# Epoch [7/10], Training Loss: 1.118, Validation Accuracy: 55.65%
# Epoch [8/10], Training Loss: 1.108, Validation Accuracy: 56.40%
# Epoch [9/10], Training Loss: 1.101, Validation Accuracy: 55.36%
# Epoch [10/10], Training Loss: 1.089, Validation Accuracy: 55.91%
# Epoch [1/10], Training Loss: 1.186, Validation Accuracy: 56.38%
# Epoch [2/10], Training Loss: 1.163, Validation Accuracy: 56.93%
# Epoch [3/10], Training Loss: 1.148, Validation Accuracy: 56.38%
# Epoch [4/10], Training Loss: 1.137, Validation Accuracy: 56.93%
# Epoch [5/10], Training Loss: 1.121, Validation Accuracy: 57.02%
# Epoch [6/10], Training Loss: 1.108, Validation Accuracy: 57.38%
# Epoch [7/10], Training Loss: 1.100, Validation Accuracy: 56.52%
# Epoch [8/10], Training Loss: 1.088, Validation Accuracy: 56.95%
# Epoch [9/10], Training Loss: 1.085, Validation Accuracy: 57.59%
# Epoch [10/10], Training Loss: 1.074, Validation Accuracy: 57.04%
# Epoch [1/10], Training Loss: 1.166, Validation Accuracy: 57.93%
# Epoch [2/10], Training Loss: 1.141, Validation Accuracy: 56.79%
# Epoch [3/10], Training Loss: 1.128, Validation Accuracy: 57.68%
# Epoch [4/10], Training Loss: 1.108, Validation Accuracy: 57.20%
# Epoch [5/10], Training Loss: 1.102, Validation Accuracy: 57.76%
# Epoch [6/10], Training Loss: 1.080, Validation Accuracy: 57.32%
# Epoch [7/10], Training Loss: 1.078, Validation Accuracy: 55.87%
# Epoch [8/10], Training Loss: 1.067, Validation Accuracy: 56.94%
# Epoch [9/10], Training Loss: 1.061, Validation Accuracy: 57.19%
# Epoch [10/10], Training Loss: 1.067, Validation Accuracy: 57.32%
# Epoch [1/10], Training Loss: 1.133, Validation Accuracy: 58.07%
# Epoch [2/10], Training Loss: 1.104, Validation Accuracy: 57.57%
# Epoch [3/10], Training Loss: 1.087, Validation Accuracy: 57.63%
# Epoch [4/10], Training Loss: 1.074, Validation Accuracy: 56.08%
# Epoch [5/10], Training Loss: 1.064, Validation Accuracy: 57.72%
# Epoch [6/10], Training Loss: 1.052, Validation Accuracy: 57.86%
# Epoch [7/10], Training Loss: 1.036, Validation Accuracy: 58.25%
# Epoch [8/10], Training Loss: 1.023, Validation Accuracy: 57.62%
# Epoch [9/10], Training Loss: 1.017, Validation Accuracy: 58.15%
# Epoch [10/10], Training Loss: 1.009, Validation Accuracy: 57.20%
# Epoch [1/10], Training Loss: 1.142, Validation Accuracy: 57.64%
# Epoch [2/10], Training Loss: 1.102, Validation Accuracy: 58.58%
# Epoch [3/10], Training Loss: 1.075, Validation Accuracy: 58.31%
# Epoch [4/10], Training Loss: 1.063, Validation Accuracy: 58.49%
# Epoch [5/10], Training Loss: 1.052, Validation Accuracy: 58.69%
# Epoch [6/10], Training Loss: 1.034, Validation Accuracy: 58.62%
# Epoch [7/10], Training Loss: 1.023, Validation Accuracy: 58.24%
# Epoch [8/10], Training Loss: 1.012, Validation Accuracy: 56.67%
# Epoch [9/10], Training Loss: 1.002, Validation Accuracy: 58.37%
# Epoch [10/10], Training Loss: 1.003, Validation Accuracy: 58.10%
# Epoch [1/10], Training Loss: 1.110, Validation Accuracy: 59.11%
# Epoch [2/10], Training Loss: 1.081, Validation Accuracy: 59.42%
# Epoch [3/10], Training Loss: 1.056, Validation Accuracy: 58.84%
# Epoch [4/10], Training Loss: 1.040, Validation Accuracy: 59.08%
# Epoch [5/10], Training Loss: 1.028, Validation Accuracy: 58.21%
# Epoch [6/10], Training Loss: 1.020, Validation Accuracy: 59.37%
# Epoch [7/10], Training Loss: 1.000, Validation Accuracy: 58.99%
# Epoch [8/10], Training Loss: 0.996, Validation Accuracy: 59.17%
# Epoch [9/10], Training Loss: 0.981, Validation Accuracy: 58.37%
# Epoch [10/10], Training Loss: 0.973, Validation Accuracy: 58.98%
# Epoch [1/10], Training Loss: 1.108, Validation Accuracy: 59.17%
# Epoch [2/10], Training Loss: 1.068, Validation Accuracy: 58.71%
# Epoch [3/10], Training Loss: 1.049, Validation Accuracy: 58.32%
# Epoch [4/10], Training Loss: 1.039, Validation Accuracy: 59.48%
# Epoch [5/10], Training Loss: 1.017, Validation Accuracy: 58.96%
# Epoch [6/10], Training Loss: 1.010, Validation Accuracy: 58.71%
# Epoch [7/10], Training Loss: 0.994, Validation Accuracy: 59.43%
# Epoch [8/10], Training Loss: 0.982, Validation Accuracy: 58.77%
# Epoch [9/10], Training Loss: 0.967, Validation Accuracy: 59.43%
# Epoch [10/10], Training Loss: 0.959, Validation Accuracy: 59.32%
# Epoch [1/10], Training Loss: 1.093, Validation Accuracy: 60.17%
# Epoch [2/10], Training Loss: 1.059, Validation Accuracy: 59.83%
# Epoch [3/10], Training Loss: 1.033, Validation Accuracy: 59.83%
# Epoch [4/10], Training Loss: 1.028, Validation Accuracy: 59.07%
# Epoch [5/10], Training Loss: 1.008, Validation Accuracy: 59.84%
# Epoch [6/10], Training Loss: 0.984, Validation Accuracy: 59.51%
# Epoch [7/10], Training Loss: 0.977, Validation Accuracy: 59.04%
# Epoch [8/10], Training Loss: 0.963, Validation Accuracy: 59.33%
# Epoch [9/10], Training Loss: 0.948, Validation Accuracy: 59.13%
# Epoch [10/10], Training Loss: 0.936, Validation Accuracy: 59.37%
# Epoch [1/10], Training Loss: 1.058, Validation Accuracy: 58.72%
# Epoch [2/10], Training Loss: 1.031, Validation Accuracy: 58.39%
# Epoch [3/10], Training Loss: 0.994, Validation Accuracy: 58.55%
# Epoch [4/10], Training Loss: 0.983, Validation Accuracy: 58.99%
# Epoch [5/10], Training Loss: 0.962, Validation Accuracy: 59.78%
# Epoch [6/10], Training Loss: 0.943, Validation Accuracy: 60.33%
# Epoch [7/10], Training Loss: 0.930, Validation Accuracy: 59.63%
# Epoch [8/10], Training Loss: 0.924, Validation Accuracy: 59.15%
# Epoch [9/10], Training Loss: 0.900, Validation Accuracy: 59.65%
# Epoch [10/10], Training Loss: 0.897, Validation Accuracy: 59.05%
# Epoch [1/10], Training Loss: 1.060, Validation Accuracy: 59.48%
# Epoch [2/10], Training Loss: 1.013, Validation Accuracy: 60.05%
# Epoch [3/10], Training Loss: 0.986, Validation Accuracy: 59.99%
# Epoch [4/10], Training Loss: 0.979, Validation Accuracy: 59.91%
# Epoch [5/10], Training Loss: 0.947, Validation Accuracy: 59.06%
# Epoch [6/10], Training Loss: 0.933, Validation Accuracy: 60.03%
# Epoch [7/10], Training Loss: 0.918, Validation Accuracy: 59.91%
# Epoch [8/10], Training Loss: 0.902, Validation Accuracy: 59.65%
# Epoch [9/10], Training Loss: 0.897, Validation Accuracy: 59.71%
# Epoch [10/10], Training Loss: 0.893, Validation Accuracy: 59.64%
# Epoch [1/10], Training Loss: 1.048, Validation Accuracy: 60.14%
# Epoch [2/10], Training Loss: 1.010, Validation Accuracy: 60.59%
# Epoch [3/10], Training Loss: 0.988, Validation Accuracy: 59.60%
# Epoch [4/10], Training Loss: 0.964, Validation Accuracy: 60.49%
# Epoch [5/10], Training Loss: 0.936, Validation Accuracy: 59.93%
# Epoch [6/10], Training Loss: 0.932, Validation Accuracy: 60.42%
# Epoch [7/10], Training Loss: 0.913, Validation Accuracy: 59.64%
# Epoch [8/10], Training Loss: 0.899, Validation Accuracy: 60.36%
# Epoch [9/10], Training Loss: 0.885, Validation Accuracy: 60.12%
# Epoch [10/10], Training Loss: 0.880, Validation Accuracy: 60.02%
# Epoch [1/10], Training Loss: 1.037, Validation Accuracy: 60.05%
# Epoch [2/10], Training Loss: 0.995, Validation Accuracy: 60.27%
# Epoch [3/10], Training Loss: 0.963, Validation Accuracy: 60.43%
# Epoch [4/10], Training Loss: 0.945, Validation Accuracy: 59.65%
# Epoch [5/10], Training Loss: 0.919, Validation Accuracy: 60.31%
# Epoch [6/10], Training Loss: 0.906, Validation Accuracy: 60.52%
# Epoch [7/10], Training Loss: 0.893, Validation Accuracy: 60.37%
# Epoch [8/10], Training Loss: 0.885, Validation Accuracy: 60.53%
# Epoch [9/10], Training Loss: 0.871, Validation Accuracy: 60.10%
# Epoch [10/10], Training Loss: 0.865, Validation Accuracy: 58.55%
# Epoch [1/10], Training Loss: 1.029, Validation Accuracy: 60.58%
# Epoch [2/10], Training Loss: 0.979, Validation Accuracy: 60.23%
# Epoch [3/10], Training Loss: 0.943, Validation Accuracy: 60.85%
# Epoch [4/10], Training Loss: 0.920, Validation Accuracy: 60.49%
# Epoch [5/10], Training Loss: 0.899, Validation Accuracy: 60.26%
# Epoch [6/10], Training Loss: 0.882, Validation Accuracy: 60.82%
# Epoch [7/10], Training Loss: 0.866, Validation Accuracy: 61.06%
# Epoch [8/10], Training Loss: 0.846, Validation Accuracy: 60.17%
# Epoch [9/10], Training Loss: 0.840, Validation Accuracy: 60.64%
# Epoch [10/10], Training Loss: 0.823, Validation Accuracy: 60.18%
# Epoch [1/10], Training Loss: 1.003, Validation Accuracy: 60.21%
# Epoch [2/10], Training Loss: 0.940, Validation Accuracy: 60.87%
# Epoch [3/10], Training Loss: 0.915, Validation Accuracy: 60.46%
# Epoch [4/10], Training Loss: 0.892, Validation Accuracy: 60.76%
# Epoch [5/10], Training Loss: 0.869, Validation Accuracy: 59.74%
# Epoch [6/10], Training Loss: 0.858, Validation Accuracy: 59.85%
# Epoch [7/10], Training Loss: 0.837, Validation Accuracy: 61.19%
# Epoch [8/10], Training Loss: 0.818, Validation Accuracy: 60.98%
# Epoch [9/10], Training Loss: 0.803, Validation Accuracy: 59.59%
# Epoch [10/10], Training Loss: 0.794, Validation Accuracy: 60.04%
# Epoch [1/10], Training Loss: 0.998, Validation Accuracy: 60.93%
# Epoch [2/10], Training Loss: 0.944, Validation Accuracy: 60.93%
# Epoch [3/10], Training Loss: 0.910, Validation Accuracy: 60.34%
# Epoch [4/10], Training Loss: 0.891, Validation Accuracy: 60.75%
# Epoch [5/10], Training Loss: 0.858, Validation Accuracy: 60.31%
# Epoch [6/10], Training Loss: 0.847, Validation Accuracy: 60.92%
# Epoch [7/10], Training Loss: 0.823, Validation Accuracy: 60.49%
# Epoch [8/10], Training Loss: 0.807, Validation Accuracy: 60.68%
# Epoch [9/10], Training Loss: 0.793, Validation Accuracy: 60.32%
# Epoch [10/10], Training Loss: 0.786, Validation Accuracy: 60.50%
# Epoch [1/10], Training Loss: 0.988, Validation Accuracy: 60.43%
# Epoch [2/10], Training Loss: 0.932, Validation Accuracy: 61.51%
# Epoch [3/10], Training Loss: 0.900, Validation Accuracy: 60.86%
# Epoch [4/10], Training Loss: 0.869, Validation Accuracy: 61.10%
# Epoch [5/10], Training Loss: 0.847, Validation Accuracy: 61.35%
# Epoch [6/10], Training Loss: 0.821, Validation Accuracy: 60.65%
# Epoch [7/10], Training Loss: 0.813, Validation Accuracy: 61.08%
# Epoch [8/10], Training Loss: 0.792, Validation Accuracy: 60.63%
# Epoch [9/10], Training Loss: 0.779, Validation Accuracy: 60.53%
# Epoch [10/10], Training Loss: 0.774, Validation Accuracy: 60.46%
# Epoch [1/10], Training Loss: 0.975, Validation Accuracy: 60.63%
# Epoch [2/10], Training Loss: 0.921, Validation Accuracy: 60.52%
# Epoch [3/10], Training Loss: 0.893, Validation Accuracy: 60.65%
# Epoch [4/10], Training Loss: 0.857, Validation Accuracy: 60.85%
# Epoch [5/10], Training Loss: 0.843, Validation Accuracy: 60.29%
# Epoch [6/10], Training Loss: 0.817, Validation Accuracy: 60.53%
# Epoch [7/10], Training Loss: 0.807, Validation Accuracy: 60.04%
# Epoch [8/10], Training Loss: 0.788, Validation Accuracy: 60.52%
# Epoch [9/10], Training Loss: 0.769, Validation Accuracy: 59.97%
# Epoch [10/10], Training Loss: 0.761, Validation Accuracy: 60.82%
# Epoch [1/10], Training Loss: 0.968, Validation Accuracy: 61.12%
# Epoch [2/10], Training Loss: 0.898, Validation Accuracy: 60.57%
# Epoch [3/10], Training Loss: 0.855, Validation Accuracy: 61.08%
# Epoch [4/10], Training Loss: 0.829, Validation Accuracy: 60.82%
# Epoch [5/10], Training Loss: 0.808, Validation Accuracy: 60.70%
# Epoch [6/10], Training Loss: 0.788, Validation Accuracy: 60.64%
# Epoch [7/10], Training Loss: 0.763, Validation Accuracy: 61.08%
# Epoch [8/10], Training Loss: 0.759, Validation Accuracy: 60.81%
# Epoch [9/10], Training Loss: 0.725, Validation Accuracy: 60.46%
# Epoch [10/10], Training Loss: 0.723, Validation Accuracy: 60.35%
# Epoch [1/10], Training Loss: 0.941, Validation Accuracy: 60.29%
# Epoch [2/10], Training Loss: 0.888, Validation Accuracy: 60.57%
# Epoch [3/10], Training Loss: 0.855, Validation Accuracy: 60.66%
# Epoch [4/10], Training Loss: 0.815, Validation Accuracy: 61.35%
# Epoch [5/10], Training Loss: 0.787, Validation Accuracy: 60.77%
# Epoch [6/10], Training Loss: 0.761, Validation Accuracy: 61.36%
# Epoch [7/10], Training Loss: 0.752, Validation Accuracy: 61.10%
# Epoch [8/10], Training Loss: 0.735, Validation Accuracy: 61.01%
# Epoch [9/10], Training Loss: 0.718, Validation Accuracy: 60.86%
# Epoch [10/10], Training Loss: 0.696, Validation Accuracy: 60.81%
# Epoch [1/10], Training Loss: 0.946, Validation Accuracy: 61.68%
# Epoch [2/10], Training Loss: 0.873, Validation Accuracy: 59.95%
# Epoch [3/10], Training Loss: 0.825, Validation Accuracy: 61.64%
# Epoch [4/10], Training Loss: 0.795, Validation Accuracy: 60.72%
# Epoch [5/10], Training Loss: 0.772, Validation Accuracy: 60.98%
# Epoch [6/10], Training Loss: 0.765, Validation Accuracy: 60.71%
# Epoch [7/10], Training Loss: 0.733, Validation Accuracy: 61.17%
# Epoch [8/10], Training Loss: 0.712, Validation Accuracy: 61.17%
# Epoch [9/10], Training Loss: 0.692, Validation Accuracy: 60.93%
# Epoch [10/10], Training Loss: 0.684, Validation Accuracy: 60.64%
# Epoch [1/10], Training Loss: 0.944, Validation Accuracy: 61.07%
# Epoch [2/10], Training Loss: 0.853, Validation Accuracy: 60.50%
# Epoch [3/10], Training Loss: 0.818, Validation Accuracy: 61.42%
# Epoch [4/10], Training Loss: 0.779, Validation Accuracy: 61.60%
# Epoch [5/10], Training Loss: 0.763, Validation Accuracy: 61.24%
# Epoch [6/10], Training Loss: 0.741, Validation Accuracy: 60.17%
# Epoch [7/10], Training Loss: 0.716, Validation Accuracy: 61.41%
# Epoch [8/10], Training Loss: 0.699, Validation Accuracy: 60.60%
# Epoch [9/10], Training Loss: 0.683, Validation Accuracy: 60.92%
# Epoch [10/10], Training Loss: 0.667, Validation Accuracy: 60.55%
# Epoch [1/10], Training Loss: 0.925, Validation Accuracy: 60.83%
# Epoch [2/10], Training Loss: 0.855, Validation Accuracy: 61.14%
# Epoch [3/10], Training Loss: 0.809, Validation Accuracy: 60.70%
# Epoch [4/10], Training Loss: 0.773, Validation Accuracy: 61.07%
# Epoch [5/10], Training Loss: 0.748, Validation Accuracy: 61.26%
# Epoch [6/10], Training Loss: 0.729, Validation Accuracy: 61.02%
# Epoch [7/10], Training Loss: 0.715, Validation Accuracy: 60.42%
# Epoch [8/10], Training Loss: 0.687, Validation Accuracy: 61.12%
# Epoch [9/10], Training Loss: 0.666, Validation Accuracy: 61.08%
# Epoch [10/10], Training Loss: 0.657, Validation Accuracy: 61.02%
# Epoch [1/10], Training Loss: 0.928, Validation Accuracy: 60.83%
# Epoch [2/10], Training Loss: 0.829, Validation Accuracy: 60.80%
# Epoch [3/10], Training Loss: 0.782, Validation Accuracy: 60.95%
# Epoch [4/10], Training Loss: 0.745, Validation Accuracy: 61.22%
# Epoch [5/10], Training Loss: 0.720, Validation Accuracy: 60.93%
# Epoch [6/10], Training Loss: 0.708, Validation Accuracy: 60.76%
# Epoch [7/10], Training Loss: 0.676, Validation Accuracy: 60.89%
# Epoch [8/10], Training Loss: 0.660, Validation Accuracy: 61.07%
# Epoch [9/10], Training Loss: 0.637, Validation Accuracy: 60.11%
# Epoch [10/10], Training Loss: 0.621, Validation Accuracy: 60.77%
# Epoch [1/10], Training Loss: 0.903, Validation Accuracy: 60.70%
# Epoch [2/10], Training Loss: 0.815, Validation Accuracy: 61.45%
# Epoch [3/10], Training Loss: 0.767, Validation Accuracy: 60.44%
# Epoch [4/10], Training Loss: 0.733, Validation Accuracy: 60.61%
# Epoch [5/10], Training Loss: 0.714, Validation Accuracy: 60.87%
# Epoch [6/10], Training Loss: 0.677, Validation Accuracy: 61.16%
# Epoch [7/10], Training Loss: 0.661, Validation Accuracy: 61.73%
# Epoch [8/10], Training Loss: 0.646, Validation Accuracy: 61.25%
# Epoch [9/10], Training Loss: 0.626, Validation Accuracy: 61.20%
# Epoch [10/10], Training Loss: 0.601, Validation Accuracy: 61.39%
# Epoch [1/10], Training Loss: 0.891, Validation Accuracy: 61.67%
# Epoch [2/10], Training Loss: 0.796, Validation Accuracy: 61.26%
# Epoch [3/10], Training Loss: 0.746, Validation Accuracy: 61.61%
# Epoch [4/10], Training Loss: 0.707, Validation Accuracy: 61.10%
# Epoch [5/10], Training Loss: 0.685, Validation Accuracy: 61.19%
# Epoch [6/10], Training Loss: 0.662, Validation Accuracy: 60.70%
# Epoch [7/10], Training Loss: 0.638, Validation Accuracy: 60.15%
# Epoch [8/10], Training Loss: 0.614, Validation Accuracy: 61.16%
# Epoch [9/10], Training Loss: 0.590, Validation Accuracy: 60.78%
# Epoch [10/10], Training Loss: 0.570, Validation Accuracy: 61.05%
# Epoch [1/10], Training Loss: 0.892, Validation Accuracy: 60.26%
# Epoch [2/10], Training Loss: 0.803, Validation Accuracy: 61.39%
# Epoch [3/10], Training Loss: 0.744, Validation Accuracy: 61.13%
# Epoch [4/10], Training Loss: 0.700, Validation Accuracy: 60.94%
# Epoch [5/10], Training Loss: 0.669, Validation Accuracy: 60.67%
# Epoch [6/10], Training Loss: 0.643, Validation Accuracy: 60.91%
# Epoch [7/10], Training Loss: 0.614, Validation Accuracy: 60.77%
# Epoch [8/10], Training Loss: 0.598, Validation Accuracy: 60.32%
# Epoch [9/10], Training Loss: 0.570, Validation Accuracy: 61.03%
# Epoch [10/10], Training Loss: 0.556, Validation Accuracy: 61.05%
# Epoch [1/10], Training Loss: 0.887, Validation Accuracy: 60.59%
# Epoch [2/10], Training Loss: 0.788, Validation Accuracy: 60.66%
# Epoch [3/10], Training Loss: 0.750, Validation Accuracy: 61.40%
# Epoch [4/10], Training Loss: 0.717, Validation Accuracy: 60.47%
# Epoch [5/10], Training Loss: 0.670, Validation Accuracy: 60.97%
# Epoch [6/10], Training Loss: 0.636, Validation Accuracy: 61.34%
# Epoch [7/10], Training Loss: 0.621, Validation Accuracy: 60.49%
# Epoch [8/10], Training Loss: 0.601, Validation Accuracy: 61.19%
# Epoch [9/10], Training Loss: 0.578, Validation Accuracy: 60.92%
# Epoch [10/10], Training Loss: 0.560, Validation Accuracy: 60.80%
# Epoch [1/10], Training Loss: 0.869, Validation Accuracy: 59.55%
# Epoch [2/10], Training Loss: 0.773, Validation Accuracy: 61.21%
# Epoch [3/10], Training Loss: 0.716, Validation Accuracy: 60.71%
# Epoch [4/10], Training Loss: 0.684, Validation Accuracy: 60.92%
# Epoch [5/10], Training Loss: 0.640, Validation Accuracy: 60.52%
# Epoch [6/10], Training Loss: 0.617, Validation Accuracy: 60.05%
# Epoch [7/10], Training Loss: 0.601, Validation Accuracy: 60.67%
# Epoch [8/10], Training Loss: 0.556, Validation Accuracy: 61.09%
# Epoch [9/10], Training Loss: 0.542, Validation Accuracy: 60.88%
# Epoch [10/10], Training Loss: 0.515, Validation Accuracy: 60.69%
# Epoch [1/10], Training Loss: 0.857, Validation Accuracy: 60.27%
# Epoch [2/10], Training Loss: 0.756, Validation Accuracy: 59.81%
# Epoch [3/10], Training Loss: 0.706, Validation Accuracy: 60.85%
# Epoch [4/10], Training Loss: 0.666, Validation Accuracy: 61.67%
# Epoch [5/10], Training Loss: 0.621, Validation Accuracy: 60.79%
# Epoch [6/10], Training Loss: 0.598, Validation Accuracy: 60.46%
# Epoch [7/10], Training Loss: 0.567, Validation Accuracy: 60.67%
# Epoch [8/10], Training Loss: 0.555, Validation Accuracy: 61.39%
# Epoch [9/10], Training Loss: 0.531, Validation Accuracy: 61.34%
# Epoch [10/10], Training Loss: 0.512, Validation Accuracy: 60.82%
# Epoch [1/10], Training Loss: 0.849, Validation Accuracy: 60.94%
# Epoch [2/10], Training Loss: 0.733, Validation Accuracy: 60.55%
# Epoch [3/10], Training Loss: 0.679, Validation Accuracy: 61.41%
# Epoch [4/10], Training Loss: 0.645, Validation Accuracy: 60.97%
# Epoch [5/10], Training Loss: 0.609, Validation Accuracy: 61.23%
# Epoch [6/10], Training Loss: 0.577, Validation Accuracy: 60.64%
# Epoch [7/10], Training Loss: 0.545, Validation Accuracy: 61.49%
# Epoch [8/10], Training Loss: 0.518, Validation Accuracy: 59.98%
# Epoch [9/10], Training Loss: 0.499, Validation Accuracy: 60.72%
# Epoch [10/10], Training Loss: 0.486, Validation Accuracy: 60.33%
# Epoch [1/10], Training Loss: 0.855, Validation Accuracy: 60.69%
# Epoch [2/10], Training Loss: 0.728, Validation Accuracy: 60.02%
# Epoch [3/10], Training Loss: 0.676, Validation Accuracy: 61.06%
# Epoch [4/10], Training Loss: 0.625, Validation Accuracy: 61.16%
# Epoch [5/10], Training Loss: 0.582, Validation Accuracy: 61.09%
# Epoch [6/10], Training Loss: 0.545, Validation Accuracy: 60.59%
# Epoch [7/10], Training Loss: 0.526, Validation Accuracy: 61.05%
# Epoch [8/10], Training Loss: 0.503, Validation Accuracy: 60.60%
# Epoch [9/10], Training Loss: 0.483, Validation Accuracy: 60.94%
# Epoch [10/10], Training Loss: 0.461, Validation Accuracy: 60.78%
# Epoch [1/10], Training Loss: 0.852, Validation Accuracy: 60.51%
# Epoch [2/10], Training Loss: 0.737, Validation Accuracy: 60.32%
# Epoch [3/10], Training Loss: 0.668, Validation Accuracy: 60.96%
# Epoch [4/10], Training Loss: 0.622, Validation Accuracy: 60.75%
# Epoch [5/10], Training Loss: 0.586, Validation Accuracy: 59.97%
# Epoch [6/10], Training Loss: 0.560, Validation Accuracy: 60.41%
# Epoch [7/10], Training Loss: 0.546, Validation Accuracy: 59.90%
# Epoch [8/10], Training Loss: 0.514, Validation Accuracy: 60.16%
# Epoch [9/10], Training Loss: 0.489, Validation Accuracy: 60.47%
# Epoch [10/10], Training Loss: 0.470, Validation Accuracy: 59.95%
# Epoch [1/10], Training Loss: 0.858, Validation Accuracy: 59.85%
# Epoch [2/10], Training Loss: 0.718, Validation Accuracy: 60.68%
# Epoch [3/10], Training Loss: 0.638, Validation Accuracy: 60.70%
# Epoch [4/10], Training Loss: 0.595, Validation Accuracy: 60.57%
# Epoch [5/10], Training Loss: 0.552, Validation Accuracy: 60.05%
# Epoch [6/10], Training Loss: 0.526, Validation Accuracy: 59.89%
# Epoch [7/10], Training Loss: 0.515, Validation Accuracy: 60.74%
# Epoch [8/10], Training Loss: 0.475, Validation Accuracy: 60.75%
# Epoch [9/10], Training Loss: 0.455, Validation Accuracy: 60.63%
# Epoch [10/10], Training Loss: 0.436, Validation Accuracy: 60.56%
# Epoch [1/10], Training Loss: 0.832, Validation Accuracy: 59.99%
# Epoch [2/10], Training Loss: 0.700, Validation Accuracy: 60.88%
# Epoch [3/10], Training Loss: 0.642, Validation Accuracy: 61.30%
# Epoch [4/10], Training Loss: 0.591, Validation Accuracy: 60.52%
# Epoch [5/10], Training Loss: 0.555, Validation Accuracy: 61.05%
# Epoch [6/10], Training Loss: 0.526, Validation Accuracy: 59.38%
# Epoch [7/10], Training Loss: 0.508, Validation Accuracy: 60.70%
# Epoch [8/10], Training Loss: 0.468, Validation Accuracy: 60.53%
# Epoch [9/10], Training Loss: 0.449, Validation Accuracy: 60.60%
# Epoch [10/10], Training Loss: 0.428, Validation Accuracy: 60.96%
# Confusion Matrix:
# [[622  32  47  18  30  25  23  32 115  56]
#  [ 29 671  10  14  13  11  15  15  61 161]
#  [ 71  12 440  73 147  75  75  70  26  11]
#  [ 16  16  64 398  89 179  96  80  37  25]
#  [ 20   4  58  60 549  71  80 131  19   8]
#  [ 10   4  65 192  67 480  39 111  14  18]
#  [  8   8  44  70  59  32 739  23   6  11]
#  [  9  10  25  43  85  76  15 711   6  20]
#  [ 84  32  15  14  11   8   7  18 763  48]
#  [ 32 111  13  14  13  11  20  55  60 671]]
# Test Accuracy: 60.44%
# True Positives (TP): [622 671 440 398 549 480 739 711 763 671]
# False Positives (FP): [279 229 341 498 514 488 370 535 344 358]
# True Negatives (TN): [8721 8771 8659 8502 8486 8512 8630 8465 8656 8642]
# False Negatives (FN): [378 329 560 602 451 520 261 289 237 329]
# : [10000 10000 10000 10000 10000 10000 10000 10000 10000 10000]
# Precision: [0.69034406 0.74555556 0.56338028 0.44419643 0.51646284 0.49586777
#  0.6663661  0.570626   0.68925023 0.65208941]
# Recall: [0.622 0.671 0.44  0.398 0.549 0.48  0.739 0.711 0.763 0.671]
# F1 Score: [0.65439243 0.70631579 0.49410444 0.41983122 0.53223461 0.48780488
#  0.70080607 0.63312556 0.72425249 0.66140956]

# %% [markdown]
# Beta=0.5

# %%
import numpy as np
from scipy.stats import truncnorm
import torch
import torchvision
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import Subset, DataLoader
from torchvision.datasets import CIFAR10
from typing import Dict, Tuple
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import random

# Define VAE model
class VAE(nn.Module):
    def __init__(self, x_dim, h_dim, z_dim):
        super(VAE, self).__init__()
        self.x_dim = x_dim
        self.h_dim = h_dim
        self.z_dim = z_dim

        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 32, 4, stride=2, padding=1),  # 16x16
            nn.ReLU(),
            nn.Conv2d(32, 64, 4, stride=2, padding=1),  # 8x8
            nn.ReLU(),
            nn.Conv2d(64, 128, 4, stride=2, padding=1),  # 4x4
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(2048, 256),
            nn.ReLU(),
            nn.Linear(256, 2*z_dim)
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(z_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 2048),
            nn.ReLU(),
            nn.Unflatten(1, (128, 4, 4)),
            nn.ConvTranspose2d(128, 64, 4, stride=2, padding=1),  # 8x8
            nn.ReLU(),
            nn.ConvTranspose2d(64, 32, 4, stride=2, padding=1),  # 16x16
            nn.ReLU(),
            nn.ConvTranspose2d(32, 3, 4, stride=2, padding=1),  # 32x32
            nn.Sigmoid()
        )

    def encode(self, x):
        h = self.encoder(x)
        mu, logvar = h[:, :self.z_dim], h[:, self.z_dim:]
        return mu, logvar

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z):
        return self.decoder(z)

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar


# Define VAE training procedure
def vae_train(vae: VAE, trainloader: DataLoader, epochs: int, beta: float =0.5):
    optimizer = torch.optim.Adam(vae.parameters(), lr=1e-3)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)

    for epoch in range(epochs):
        vae.train()
        for i, data in enumerate(trainloader, 0):
            inputs, _ = data
            optimizer.zero_grad()
            recon_x, mu, logvar = vae(inputs)
            loss = vae_loss(recon_x, inputs, mu, logvar , beta=beta)
            loss.backward()
            optimizer.step()

        scheduler.step()



# Define classification model
class Net(nn.Module):
    def __init__(self) -> None:
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.pool(nn.functional.relu(self.conv1(x)))
        x = self.pool(nn.functional.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = nn.functional.relu(self.fc1(x))
        x = nn.functional.relu(self.fc2(x))
        x = self.fc3(x)
        return x


# Load CIFAR10 dataset
transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]
)

full_dataset = CIFAR10(root="./data", train=True, download=True, transform=transform)
test_set = CIFAR10(root="./data", train=False, download=True, transform=transform)

# Separate dataset by class
class_indices = {i: [] for i in range(10)}  # CIFAR-10 has 10 classes
for idx, (_, label) in enumerate(full_dataset):
    class_indices[label].append(idx)

# Define target count per class, summing to 60,000 with random distribution
class_counts = np.random.multinomial(60000, [0.1] * 10)  # Adjust probabilities if you want specific class biases
print("Random Images per Class:", class_counts)

# Sample indices based on the specified class counts
indices = []
for class_id, count in enumerate(class_counts):
    # Ensure count does not exceed available images
    count = min(count, len(class_indices[class_id]))
    selected_indices = random.sample(class_indices[class_id], count)
    indices.extend(selected_indices)

# Create a custom CIFAR-10 dataset with the sampled indices
custom_dataset = Subset(full_dataset, indices)
# Split dataset into training and validation sets
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_set, val_set = torch.utils.data.random_split(full_dataset, [train_size, val_size])

# Create training and validation loaders
trainloader = DataLoader(train_set, batch_size=128, shuffle=True, num_workers=2)
valloader = DataLoader(val_set, batch_size=128, shuffle=False, num_workers=2)
testloader = DataLoader(test_set, batch_size=128, shuffle=False, num_workers=2)




# Define VAE loss function
def vae_loss(recon_x, x, mu, logvar, beta=0.5):
    BCE = nn.functional.mse_loss(recon_x, x, reduction='sum')
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return BCE + beta * KLD


# Define training procedure for classification model
def train(net: nn.Module, trainloader: DataLoader, valloader: DataLoader, epochs: int) -> None:
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)

    best_acc = 0.0

    for epoch in range(epochs):
        # Training loop
        net.train()
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            inputs, labels = data
            optimizer.zero_grad()
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        scheduler.step()

        # Validation loop
        net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data in valloader:
                images, labels = data
                outputs = net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_acc = 100 * correct / total
        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(net.state_dict(), 'best_model.pth')

        print(f"Epoch [{epoch+1}/{epochs}], Training Loss: {running_loss / (i+1):.3f}, Validation Accuracy: {val_acc:.2f}%")

# Define evaluation procedure
def evaluate(net: nn.Module, testloader: DataLoader) -> Tuple[float, np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
    net.eval()
    correct = 0
    total = 0
    all_labels = []
    all_predictions = []
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    accuracy = 100 * correct / total

    # Calculate confusion matrix
    cm = confusion_matrix(all_labels, all_predictions)
    print(f"Confusion Matrix:\n{cm}")

    # Calculate TP, FP, TN, FN for each class
    tp = np.diag(cm)
    fp = cm.sum(axis=0) - tp
    fn = cm.sum(axis=1) - tp
    tn = cm.sum() - (fp + fn + tp)

    # Calculate precision, recall, and F1 score for each class
    precision = precision_score(all_labels, all_predictions, average=None)
    recall = recall_score(all_labels, all_predictions, average=None)
    f1 = f1_score(all_labels, all_predictions, average=None)

    return accuracy, tp, fp, tn, fn, precision, recall, f1

# Initialize clients
def initialize_clients(trainset, transform, batch_size, num_clients):
    clients = {}
    for i in range(num_clients):
        client_trainset = torch.utils.data.Subset(trainset, range(i * len(trainset) // num_clients, (i + 1) * len(trainset) // num_clients))
        client_trainloader = torch.utils.data.DataLoader(client_trainset, batch_size=batch_size, shuffle=True)
        clients[f"client_{i}"] = client_trainloader
    return clients

def get_distribution_info(vae: VAE) -> Dict:
    # Implement the logic to extract distribution information from the VAE
    # This can involve computing statistics, parameters, or any other relevant information
    # that can be used to generate augmented data

    # Example implementation:
    distribution_info = {
        "uniform": {
            "mean": vae.encoder[-1].bias.data.cpu().numpy(),
            "std": torch.exp(0.5 * vae.encoder[-1].weight.data).cpu().numpy()
        },
        "normal": {
            "mean": vae.encoder[-1].bias.data.cpu().numpy(),
            "std": torch.exp(0.5 * vae.encoder[-1].weight.data).cpu().numpy()
        }
    }

    return distribution_info

def send_distribution_info(distribution_info: Dict) -> None:
    # Implement the logic to send the distribution information to the global server
    # This can involve using a network protocol, a message queue, or any other communication mechanism
    # to send the information

    # Example implementation:
    # Send the distribution information to the global server using a network protocol
    # For example, you can use the `socket` module to send the information over a network
    # or use a message queue like `RabbitMQ` to send the information
    pass

def generate_augmented_data(vae: VAE, distribution_info_uniform: Dict, distribution_info_normal: Dict) -> torch.Tensor:
    # Generate augmented data using both uniform and truncated uniform distributions

    mean = distribution_info_uniform["mean"].mean().item()  # Convert numpy array to float
    std = distribution_info_uniform["std"].mean().item()  # Convert numpy array to float


    mean_normal = distribution_info_normal["mean"]
    std_normal = distribution_info_normal["std"]

    augmented_data_normal = torch.randn(64, vae.z_dim) * std_normal + mean_normal

     # Generate augmented data using Uniform distribution
    augmented_data_uniform = torch.FloatTensor(64, vae.z_dim).uniform_(mean - std, mean + std)


    # Calculate the average of augmented data from both distributions
    augmented_data_average = (augmented_data_uniform + augmented_data_normal ) / 2

    return augmented_data_average

def federated_train(net: nn.Module, vae: VAE, trainloaders: Dict[str, DataLoader], trainloader: DataLoader, valloader: DataLoader, epochs: int) -> None:
    for epoch in range(epochs):
        for client_id, client_trainloader in trainloaders.items():
            # Train VAE on client data
            vae_train(vae, client_trainloader, epochs=10, beta=0.5)

            # Share distribution information with global server
            distribution_info = get_distribution_info(vae)
            send_distribution_info(distribution_info)

            # Receive distribution information from other clients
            other_distribution_info = receive_distribution_info()

            # Generate augmented data using received distribution information
            augmented_data = generate_augmented_data(vae, other_distribution_info["uniform"], other_distribution_info["normal"])

            # Train classification model using local, augmented, and validation data
            train(net, client_trainloader, valloader, epochs=10)

            # Send model updates to global server
            send_model_update(client_id, net.state_dict())

# Define logic to receive distribution information from global server
def receive_distribution_info() -> Dict:
    # Receive distribution information logic
    distribution_info = {
        "uniform": {
            "mean": np.zeros(20),  # Adjust the size based on your latent space dimension
            "std": np.ones(20)
        },
        "normal": {
            "mean": np.zeros(20),  # Adjust the size based on your latent space dimension
            "std": np.ones(20)
        }
    }
    return distribution_info

def send_model_update(client_id: str, model_update: Dict) -> None:
    # Implement the logic to send the model update to the global server
    # This can involve using a network protocol, a message queue, or any other communication mechanism
    # to send the model update

    # Example implementation:
    # Send the model update to the global server using a network protocol
    # For example, you can use the `socket` module to send the information over a network
    # or use a message queue like `RabbitMQ` to send the information
    pass

# Define global server procedure
def global_server() -> None:
    net = Net()
    x_dim = 3 * 32 * 32  # CIFAR-10 input size
    h_dim = 400
    z_dim = 20
    vae = VAE(x_dim, h_dim, z_dim)  # Initialize VAE object with required arguments

    # Initialize clients
    num_clients = 5  # Define the number of clients
    clients = initialize_clients(train_set, transform, batch_size=128, num_clients=num_clients)

    # Train model using FedDIS
    federated_train(net, vae, clients, trainloader, valloader, epochs=10)

    # Evaluate final model
    test_accuracy, tp, fp, tn, fn, precision, recall, f1 = evaluate(net, testloader)
    print(f"Test Accuracy: {test_accuracy:.2f}%")

    print("True Positives (TP):", tp)
    print("False Positives (FP):", fp)
    print("True Negatives (TN):", tn)
    print("False Negatives (FN):", fn)
    print(":", fn+tn+tp+fp)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)

if __name__ == "__main__":
    global_server()
# Out:
# 100%|██████████| 170M/170M [00:01<00:00, 98.8MB/s]
# Random Images per Class: [6024 5975 6030 5992 5894 6008 5978 5917 6166 6016]
# /tmp/ipython-input-1-3401303563.py:283: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   augmented_data_normal = torch.randn(64, vae.z_dim) * std_normal + mean_normal
# Epoch [1/10], Training Loss: 2.305, Validation Accuracy: 12.49%
# Epoch [2/10], Training Loss: 2.304, Validation Accuracy: 10.42%
# Epoch [3/10], Training Loss: 2.303, Validation Accuracy: 10.12%
# Epoch [4/10], Training Loss: 2.303, Validation Accuracy: 10.11%
# Epoch [5/10], Training Loss: 2.302, Validation Accuracy: 10.11%
# Epoch [6/10], Training Loss: 2.302, Validation Accuracy: 10.11%
# Epoch [7/10], Training Loss: 2.301, Validation Accuracy: 10.12%
# Epoch [8/10], Training Loss: 2.300, Validation Accuracy: 10.18%
# Epoch [9/10], Training Loss: 2.299, Validation Accuracy: 10.32%
# Epoch [10/10], Training Loss: 2.299, Validation Accuracy: 11.37%
# Epoch [1/10], Training Loss: 2.299, Validation Accuracy: 11.90%
# Epoch [2/10], Training Loss: 2.298, Validation Accuracy: 13.02%
# Epoch [3/10], Training Loss: 2.296, Validation Accuracy: 14.02%
# Epoch [4/10], Training Loss: 2.295, Validation Accuracy: 15.70%
# Epoch [5/10], Training Loss: 2.293, Validation Accuracy: 16.82%
# Epoch [6/10], Training Loss: 2.290, Validation Accuracy: 17.96%
# Epoch [7/10], Training Loss: 2.287, Validation Accuracy: 18.60%
# Epoch [8/10], Training Loss: 2.283, Validation Accuracy: 18.88%
# Epoch [9/10], Training Loss: 2.278, Validation Accuracy: 19.12%
# Epoch [10/10], Training Loss: 2.269, Validation Accuracy: 18.78%
# Epoch [1/10], Training Loss: 2.259, Validation Accuracy: 18.61%
# Epoch [2/10], Training Loss: 2.241, Validation Accuracy: 19.40%
# Epoch [3/10], Training Loss: 2.213, Validation Accuracy: 21.10%
# Epoch [4/10], Training Loss: 2.173, Validation Accuracy: 21.10%
# Epoch [5/10], Training Loss: 2.116, Validation Accuracy: 21.60%
# Epoch [6/10], Training Loss: 2.064, Validation Accuracy: 23.45%
# Epoch [7/10], Training Loss: 2.030, Validation Accuracy: 24.62%
# Epoch [8/10], Training Loss: 2.005, Validation Accuracy: 24.71%
# Epoch [9/10], Training Loss: 1.981, Validation Accuracy: 26.31%
# Epoch [10/10], Training Loss: 1.960, Validation Accuracy: 27.69%
# Epoch [1/10], Training Loss: 1.957, Validation Accuracy: 28.96%
# Epoch [2/10], Training Loss: 1.933, Validation Accuracy: 30.14%
# Epoch [3/10], Training Loss: 1.911, Validation Accuracy: 28.68%
# Epoch [4/10], Training Loss: 1.892, Validation Accuracy: 31.85%
# Epoch [5/10], Training Loss: 1.872, Validation Accuracy: 32.53%
# Epoch [6/10], Training Loss: 1.856, Validation Accuracy: 33.04%
# Epoch [7/10], Training Loss: 1.839, Validation Accuracy: 33.64%
# Epoch [8/10], Training Loss: 1.823, Validation Accuracy: 34.34%
# Epoch [9/10], Training Loss: 1.806, Validation Accuracy: 34.81%
# Epoch [10/10], Training Loss: 1.791, Validation Accuracy: 34.63%
# Epoch [1/10], Training Loss: 1.792, Validation Accuracy: 34.62%
# Epoch [2/10], Training Loss: 1.770, Validation Accuracy: 35.71%
# Epoch [3/10], Training Loss: 1.755, Validation Accuracy: 36.09%
# Epoch [4/10], Training Loss: 1.740, Validation Accuracy: 36.39%
# Epoch [5/10], Training Loss: 1.723, Validation Accuracy: 37.01%
# Epoch [6/10], Training Loss: 1.704, Validation Accuracy: 37.85%
# Epoch [7/10], Training Loss: 1.691, Validation Accuracy: 38.35%
# Epoch [8/10], Training Loss: 1.680, Validation Accuracy: 37.45%
# Epoch [9/10], Training Loss: 1.664, Validation Accuracy: 38.95%
# Epoch [10/10], Training Loss: 1.651, Validation Accuracy: 38.00%
# Epoch [1/10], Training Loss: 1.671, Validation Accuracy: 39.16%
# Epoch [2/10], Training Loss: 1.660, Validation Accuracy: 40.24%
# Epoch [3/10], Training Loss: 1.646, Validation Accuracy: 40.06%
# Epoch [4/10], Training Loss: 1.641, Validation Accuracy: 40.26%
# Epoch [5/10], Training Loss: 1.629, Validation Accuracy: 40.71%
# Epoch [6/10], Training Loss: 1.619, Validation Accuracy: 40.76%
# Epoch [7/10], Training Loss: 1.609, Validation Accuracy: 40.77%
# Epoch [8/10], Training Loss: 1.605, Validation Accuracy: 40.70%
# Epoch [9/10], Training Loss: 1.594, Validation Accuracy: 41.50%
# Epoch [10/10], Training Loss: 1.591, Validation Accuracy: 41.45%
# Epoch [1/10], Training Loss: 1.600, Validation Accuracy: 41.60%
# Epoch [2/10], Training Loss: 1.598, Validation Accuracy: 42.63%
# Epoch [3/10], Training Loss: 1.584, Validation Accuracy: 42.57%
# Epoch [4/10], Training Loss: 1.569, Validation Accuracy: 43.22%
# Epoch [5/10], Training Loss: 1.565, Validation Accuracy: 42.65%
# Epoch [6/10], Training Loss: 1.555, Validation Accuracy: 43.38%
# Epoch [7/10], Training Loss: 1.542, Validation Accuracy: 43.14%
# Epoch [8/10], Training Loss: 1.539, Validation Accuracy: 43.05%
# Epoch [9/10], Training Loss: 1.526, Validation Accuracy: 43.60%
# Epoch [10/10], Training Loss: 1.529, Validation Accuracy: 42.94%
# Epoch [1/10], Training Loss: 1.549, Validation Accuracy: 43.63%
# Epoch [2/10], Training Loss: 1.539, Validation Accuracy: 44.43%
# Epoch [3/10], Training Loss: 1.527, Validation Accuracy: 44.61%
# Epoch [4/10], Training Loss: 1.512, Validation Accuracy: 43.92%
# Epoch [5/10], Training Loss: 1.505, Validation Accuracy: 44.68%
# Epoch [6/10], Training Loss: 1.498, Validation Accuracy: 45.52%
# Epoch [7/10], Training Loss: 1.492, Validation Accuracy: 45.97%
# Epoch [8/10], Training Loss: 1.480, Validation Accuracy: 46.17%
# Epoch [9/10], Training Loss: 1.472, Validation Accuracy: 46.25%
# Epoch [10/10], Training Loss: 1.470, Validation Accuracy: 46.12%
# Epoch [1/10], Training Loss: 1.484, Validation Accuracy: 46.68%
# Epoch [2/10], Training Loss: 1.471, Validation Accuracy: 46.41%
# Epoch [3/10], Training Loss: 1.472, Validation Accuracy: 46.73%
# Epoch [4/10], Training Loss: 1.451, Validation Accuracy: 47.42%
# Epoch [5/10], Training Loss: 1.442, Validation Accuracy: 47.42%
# Epoch [6/10], Training Loss: 1.440, Validation Accuracy: 46.72%
# Epoch [7/10], Training Loss: 1.432, Validation Accuracy: 47.55%
# Epoch [8/10], Training Loss: 1.423, Validation Accuracy: 47.87%
# Epoch [9/10], Training Loss: 1.422, Validation Accuracy: 47.96%
# Epoch [10/10], Training Loss: 1.414, Validation Accuracy: 47.36%
# Epoch [1/10], Training Loss: 1.439, Validation Accuracy: 48.27%
# Epoch [2/10], Training Loss: 1.429, Validation Accuracy: 48.25%
# Epoch [3/10], Training Loss: 1.415, Validation Accuracy: 49.26%
# Epoch [4/10], Training Loss: 1.403, Validation Accuracy: 48.97%
# Epoch [5/10], Training Loss: 1.392, Validation Accuracy: 49.10%
# Epoch [6/10], Training Loss: 1.391, Validation Accuracy: 48.00%
# Epoch [7/10], Training Loss: 1.383, Validation Accuracy: 48.53%
# Epoch [8/10], Training Loss: 1.375, Validation Accuracy: 48.84%
# Epoch [9/10], Training Loss: 1.361, Validation Accuracy: 49.26%
# Epoch [10/10], Training Loss: 1.360, Validation Accuracy: 49.46%
# Epoch [1/10], Training Loss: 1.423, Validation Accuracy: 49.88%
# Epoch [2/10], Training Loss: 1.405, Validation Accuracy: 49.49%
# Epoch [3/10], Training Loss: 1.396, Validation Accuracy: 49.58%
# Epoch [4/10], Training Loss: 1.378, Validation Accuracy: 50.51%
# Epoch [5/10], Training Loss: 1.378, Validation Accuracy: 50.22%
# Epoch [6/10], Training Loss: 1.368, Validation Accuracy: 49.81%
# Epoch [7/10], Training Loss: 1.367, Validation Accuracy: 50.01%
# Epoch [8/10], Training Loss: 1.349, Validation Accuracy: 51.11%
# Epoch [9/10], Training Loss: 1.348, Validation Accuracy: 50.87%
# Epoch [10/10], Training Loss: 1.338, Validation Accuracy: 50.46%
# Epoch [1/10], Training Loss: 1.389, Validation Accuracy: 50.91%
# Epoch [2/10], Training Loss: 1.372, Validation Accuracy: 50.62%
# Epoch [3/10], Training Loss: 1.361, Validation Accuracy: 51.10%
# Epoch [4/10], Training Loss: 1.353, Validation Accuracy: 51.37%
# Epoch [5/10], Training Loss: 1.339, Validation Accuracy: 51.18%
# Epoch [6/10], Training Loss: 1.340, Validation Accuracy: 51.83%
# Epoch [7/10], Training Loss: 1.327, Validation Accuracy: 50.96%
# Epoch [8/10], Training Loss: 1.323, Validation Accuracy: 50.64%
# Epoch [9/10], Training Loss: 1.315, Validation Accuracy: 51.84%
# Epoch [10/10], Training Loss: 1.306, Validation Accuracy: 51.71%
# Epoch [1/10], Training Loss: 1.353, Validation Accuracy: 51.31%
# Epoch [2/10], Training Loss: 1.337, Validation Accuracy: 50.39%
# Epoch [3/10], Training Loss: 1.322, Validation Accuracy: 52.34%
# Epoch [4/10], Training Loss: 1.312, Validation Accuracy: 51.68%
# Epoch [5/10], Training Loss: 1.311, Validation Accuracy: 50.44%
# Epoch [6/10], Training Loss: 1.301, Validation Accuracy: 52.07%
# Epoch [7/10], Training Loss: 1.288, Validation Accuracy: 52.33%
# Epoch [8/10], Training Loss: 1.280, Validation Accuracy: 52.63%
# Epoch [9/10], Training Loss: 1.270, Validation Accuracy: 52.00%
# Epoch [10/10], Training Loss: 1.259, Validation Accuracy: 52.77%
# Epoch [1/10], Training Loss: 1.318, Validation Accuracy: 53.06%
# Epoch [2/10], Training Loss: 1.298, Validation Accuracy: 53.43%
# Epoch [3/10], Training Loss: 1.292, Validation Accuracy: 52.90%
# Epoch [4/10], Training Loss: 1.274, Validation Accuracy: 53.14%
# Epoch [5/10], Training Loss: 1.263, Validation Accuracy: 52.57%
# Epoch [6/10], Training Loss: 1.266, Validation Accuracy: 53.47%
# Epoch [7/10], Training Loss: 1.252, Validation Accuracy: 53.00%
# Epoch [8/10], Training Loss: 1.247, Validation Accuracy: 53.28%
# Epoch [9/10], Training Loss: 1.238, Validation Accuracy: 53.92%
# Epoch [10/10], Training Loss: 1.226, Validation Accuracy: 53.51%
# Epoch [1/10], Training Loss: 1.273, Validation Accuracy: 54.17%
# Epoch [2/10], Training Loss: 1.250, Validation Accuracy: 54.61%
# Epoch [3/10], Training Loss: 1.231, Validation Accuracy: 53.29%
# Epoch [4/10], Training Loss: 1.234, Validation Accuracy: 53.08%
# Epoch [5/10], Training Loss: 1.217, Validation Accuracy: 53.88%
# Epoch [6/10], Training Loss: 1.206, Validation Accuracy: 54.65%
# Epoch [7/10], Training Loss: 1.195, Validation Accuracy: 54.45%
# Epoch [8/10], Training Loss: 1.183, Validation Accuracy: 54.62%
# Epoch [9/10], Training Loss: 1.179, Validation Accuracy: 54.20%
# Epoch [10/10], Training Loss: 1.181, Validation Accuracy: 53.35%
# Epoch [1/10], Training Loss: 1.272, Validation Accuracy: 55.25%
# Epoch [2/10], Training Loss: 1.252, Validation Accuracy: 55.23%
# Epoch [3/10], Training Loss: 1.225, Validation Accuracy: 55.00%
# Epoch [4/10], Training Loss: 1.215, Validation Accuracy: 55.55%
# Epoch [5/10], Training Loss: 1.210, Validation Accuracy: 55.40%
# Epoch [6/10], Training Loss: 1.192, Validation Accuracy: 55.38%
# Epoch [7/10], Training Loss: 1.192, Validation Accuracy: 55.17%
# Epoch [8/10], Training Loss: 1.183, Validation Accuracy: 55.00%
# Epoch [9/10], Training Loss: 1.162, Validation Accuracy: 55.60%
# Epoch [10/10], Training Loss: 1.155, Validation Accuracy: 55.67%
# Epoch [1/10], Training Loss: 1.249, Validation Accuracy: 56.03%
# Epoch [2/10], Training Loss: 1.227, Validation Accuracy: 55.83%
# Epoch [3/10], Training Loss: 1.212, Validation Accuracy: 55.55%
# Epoch [4/10], Training Loss: 1.204, Validation Accuracy: 55.81%
# Epoch [5/10], Training Loss: 1.188, Validation Accuracy: 56.55%
# Epoch [6/10], Training Loss: 1.180, Validation Accuracy: 55.84%
# Epoch [7/10], Training Loss: 1.175, Validation Accuracy: 55.49%
# Epoch [8/10], Training Loss: 1.156, Validation Accuracy: 55.37%
# Epoch [9/10], Training Loss: 1.151, Validation Accuracy: 55.89%
# Epoch [10/10], Training Loss: 1.145, Validation Accuracy: 56.02%
# Epoch [1/10], Training Loss: 1.216, Validation Accuracy: 56.20%
# Epoch [2/10], Training Loss: 1.191, Validation Accuracy: 57.16%
# Epoch [3/10], Training Loss: 1.172, Validation Accuracy: 56.76%
# Epoch [4/10], Training Loss: 1.161, Validation Accuracy: 56.59%
# Epoch [5/10], Training Loss: 1.151, Validation Accuracy: 56.75%
# Epoch [6/10], Training Loss: 1.130, Validation Accuracy: 57.62%
# Epoch [7/10], Training Loss: 1.127, Validation Accuracy: 56.98%
# Epoch [8/10], Training Loss: 1.111, Validation Accuracy: 56.30%
# Epoch [9/10], Training Loss: 1.102, Validation Accuracy: 56.30%
# Epoch [10/10], Training Loss: 1.102, Validation Accuracy: 56.74%
# Epoch [1/10], Training Loss: 1.194, Validation Accuracy: 57.36%
# Epoch [2/10], Training Loss: 1.165, Validation Accuracy: 57.26%
# Epoch [3/10], Training Loss: 1.143, Validation Accuracy: 56.82%
# Epoch [4/10], Training Loss: 1.131, Validation Accuracy: 57.06%
# Epoch [5/10], Training Loss: 1.116, Validation Accuracy: 57.24%
# Epoch [6/10], Training Loss: 1.107, Validation Accuracy: 57.68%
# Epoch [7/10], Training Loss: 1.110, Validation Accuracy: 57.72%
# Epoch [8/10], Training Loss: 1.073, Validation Accuracy: 57.49%
# Epoch [9/10], Training Loss: 1.074, Validation Accuracy: 57.88%
# Epoch [10/10], Training Loss: 1.061, Validation Accuracy: 57.51%
# Epoch [1/10], Training Loss: 1.159, Validation Accuracy: 57.73%
# Epoch [2/10], Training Loss: 1.121, Validation Accuracy: 57.35%
# Epoch [3/10], Training Loss: 1.108, Validation Accuracy: 58.13%
# Epoch [4/10], Training Loss: 1.087, Validation Accuracy: 58.14%
# Epoch [5/10], Training Loss: 1.069, Validation Accuracy: 58.29%
# Epoch [6/10], Training Loss: 1.055, Validation Accuracy: 58.14%
# Epoch [7/10], Training Loss: 1.047, Validation Accuracy: 58.33%
# Epoch [8/10], Training Loss: 1.037, Validation Accuracy: 58.47%
# Epoch [9/10], Training Loss: 1.024, Validation Accuracy: 57.95%
# Epoch [10/10], Training Loss: 1.019, Validation Accuracy: 58.27%
# Epoch [1/10], Training Loss: 1.146, Validation Accuracy: 57.69%
# Epoch [2/10], Training Loss: 1.130, Validation Accuracy: 57.81%
# Epoch [3/10], Training Loss: 1.104, Validation Accuracy: 58.87%
# Epoch [4/10], Training Loss: 1.084, Validation Accuracy: 58.40%
# Epoch [5/10], Training Loss: 1.070, Validation Accuracy: 58.65%
# Epoch [6/10], Training Loss: 1.062, Validation Accuracy: 59.05%
# Epoch [7/10], Training Loss: 1.041, Validation Accuracy: 57.78%
# Epoch [8/10], Training Loss: 1.032, Validation Accuracy: 58.90%
# Epoch [9/10], Training Loss: 1.027, Validation Accuracy: 58.91%
# Epoch [10/10], Training Loss: 1.018, Validation Accuracy: 58.69%
# Epoch [1/10], Training Loss: 1.152, Validation Accuracy: 59.33%
# Epoch [2/10], Training Loss: 1.125, Validation Accuracy: 59.19%
# Epoch [3/10], Training Loss: 1.090, Validation Accuracy: 59.19%
# Epoch [4/10], Training Loss: 1.074, Validation Accuracy: 58.11%
# Epoch [5/10], Training Loss: 1.074, Validation Accuracy: 59.30%
# Epoch [6/10], Training Loss: 1.050, Validation Accuracy: 58.85%
# Epoch [7/10], Training Loss: 1.034, Validation Accuracy: 58.84%
# Epoch [8/10], Training Loss: 1.020, Validation Accuracy: 59.30%
# Epoch [9/10], Training Loss: 1.008, Validation Accuracy: 59.47%
# Epoch [10/10], Training Loss: 0.995, Validation Accuracy: 59.51%
# Epoch [1/10], Training Loss: 1.120, Validation Accuracy: 59.21%
# Epoch [2/10], Training Loss: 1.085, Validation Accuracy: 59.17%
# Epoch [3/10], Training Loss: 1.056, Validation Accuracy: 59.85%
# Epoch [4/10], Training Loss: 1.050, Validation Accuracy: 59.08%
# Epoch [5/10], Training Loss: 1.028, Validation Accuracy: 59.36%
# Epoch [6/10], Training Loss: 1.010, Validation Accuracy: 59.48%
# Epoch [7/10], Training Loss: 1.007, Validation Accuracy: 59.66%
# Epoch [8/10], Training Loss: 0.997, Validation Accuracy: 59.94%
# Epoch [9/10], Training Loss: 0.971, Validation Accuracy: 60.20%
# Epoch [10/10], Training Loss: 0.961, Validation Accuracy: 59.95%
# Epoch [1/10], Training Loss: 1.102, Validation Accuracy: 59.81%
# Epoch [2/10], Training Loss: 1.058, Validation Accuracy: 60.14%
# Epoch [3/10], Training Loss: 1.032, Validation Accuracy: 60.50%
# Epoch [4/10], Training Loss: 1.024, Validation Accuracy: 59.86%
# Epoch [5/10], Training Loss: 1.002, Validation Accuracy: 59.61%
# Epoch [6/10], Training Loss: 0.987, Validation Accuracy: 60.58%
# Epoch [7/10], Training Loss: 0.967, Validation Accuracy: 60.81%
# Epoch [8/10], Training Loss: 0.956, Validation Accuracy: 60.63%
# Epoch [9/10], Training Loss: 0.953, Validation Accuracy: 60.76%
# Epoch [10/10], Training Loss: 0.938, Validation Accuracy: 60.16%
# Epoch [1/10], Training Loss: 1.075, Validation Accuracy: 60.69%
# Epoch [2/10], Training Loss: 1.033, Validation Accuracy: 60.10%
# Epoch [3/10], Training Loss: 1.007, Validation Accuracy: 60.70%
# Epoch [4/10], Training Loss: 0.980, Validation Accuracy: 60.76%
# Epoch [5/10], Training Loss: 0.966, Validation Accuracy: 60.77%
# Epoch [6/10], Training Loss: 0.957, Validation Accuracy: 59.38%
# Epoch [7/10], Training Loss: 0.937, Validation Accuracy: 59.92%
# Epoch [8/10], Training Loss: 0.932, Validation Accuracy: 59.31%
# Epoch [9/10], Training Loss: 0.920, Validation Accuracy: 60.07%
# Epoch [10/10], Training Loss: 0.905, Validation Accuracy: 60.10%
# Epoch [1/10], Training Loss: 1.062, Validation Accuracy: 60.09%
# Epoch [2/10], Training Loss: 1.035, Validation Accuracy: 61.16%
# Epoch [3/10], Training Loss: 1.004, Validation Accuracy: 61.00%
# Epoch [4/10], Training Loss: 0.978, Validation Accuracy: 60.75%
# Epoch [5/10], Training Loss: 0.956, Validation Accuracy: 60.81%
# Epoch [6/10], Training Loss: 0.952, Validation Accuracy: 60.62%
# Epoch [7/10], Training Loss: 0.931, Validation Accuracy: 61.17%
# Epoch [8/10], Training Loss: 0.915, Validation Accuracy: 61.34%
# Epoch [9/10], Training Loss: 0.901, Validation Accuracy: 60.59%
# Epoch [10/10], Training Loss: 0.903, Validation Accuracy: 60.59%
# Epoch [1/10], Training Loss: 1.074, Validation Accuracy: 60.95%
# Epoch [2/10], Training Loss: 1.020, Validation Accuracy: 61.18%
# Epoch [3/10], Training Loss: 0.997, Validation Accuracy: 61.02%
# Epoch [4/10], Training Loss: 0.981, Validation Accuracy: 60.88%
# Epoch [5/10], Training Loss: 0.958, Validation Accuracy: 60.87%
# Epoch [6/10], Training Loss: 0.936, Validation Accuracy: 60.71%
# Epoch [7/10], Training Loss: 0.916, Validation Accuracy: 60.63%
# Epoch [8/10], Training Loss: 0.906, Validation Accuracy: 60.07%
# Epoch [9/10], Training Loss: 0.891, Validation Accuracy: 60.54%
# Epoch [10/10], Training Loss: 0.883, Validation Accuracy: 60.86%
# Epoch [1/10], Training Loss: 1.046, Validation Accuracy: 61.28%
# Epoch [2/10], Training Loss: 1.001, Validation Accuracy: 61.09%
# Epoch [3/10], Training Loss: 0.971, Validation Accuracy: 61.04%
# Epoch [4/10], Training Loss: 0.949, Validation Accuracy: 61.90%
# Epoch [5/10], Training Loss: 0.922, Validation Accuracy: 61.54%
# Epoch [6/10], Training Loss: 0.910, Validation Accuracy: 61.25%
# Epoch [7/10], Training Loss: 0.900, Validation Accuracy: 60.72%
# Epoch [8/10], Training Loss: 0.891, Validation Accuracy: 61.27%
# Epoch [9/10], Training Loss: 0.865, Validation Accuracy: 61.19%
# Epoch [10/10], Training Loss: 0.851, Validation Accuracy: 61.13%
# Epoch [1/10], Training Loss: 1.020, Validation Accuracy: 61.16%
# Epoch [2/10], Training Loss: 0.976, Validation Accuracy: 60.06%
# Epoch [3/10], Training Loss: 0.951, Validation Accuracy: 61.57%
# Epoch [4/10], Training Loss: 0.921, Validation Accuracy: 60.63%
# Epoch [5/10], Training Loss: 0.901, Validation Accuracy: 61.97%
# Epoch [6/10], Training Loss: 0.880, Validation Accuracy: 61.72%
# Epoch [7/10], Training Loss: 0.861, Validation Accuracy: 62.29%
# Epoch [8/10], Training Loss: 0.851, Validation Accuracy: 61.66%
# Epoch [9/10], Training Loss: 0.837, Validation Accuracy: 61.59%
# Epoch [10/10], Training Loss: 0.819, Validation Accuracy: 61.76%
# Epoch [1/10], Training Loss: 1.008, Validation Accuracy: 61.21%
# Epoch [2/10], Training Loss: 0.951, Validation Accuracy: 61.46%
# Epoch [3/10], Training Loss: 0.917, Validation Accuracy: 60.91%
# Epoch [4/10], Training Loss: 0.895, Validation Accuracy: 60.84%
# Epoch [5/10], Training Loss: 0.868, Validation Accuracy: 61.33%
# Epoch [6/10], Training Loss: 0.853, Validation Accuracy: 61.66%
# Epoch [7/10], Training Loss: 0.837, Validation Accuracy: 61.65%
# Epoch [8/10], Training Loss: 0.823, Validation Accuracy: 60.48%
# Epoch [9/10], Training Loss: 0.816, Validation Accuracy: 61.28%
# Epoch [10/10], Training Loss: 0.797, Validation Accuracy: 61.07%
# Epoch [1/10], Training Loss: 1.005, Validation Accuracy: 61.52%
# Epoch [2/10], Training Loss: 0.938, Validation Accuracy: 62.08%
# Epoch [3/10], Training Loss: 0.923, Validation Accuracy: 61.69%
# Epoch [4/10], Training Loss: 0.889, Validation Accuracy: 61.96%
# Epoch [5/10], Training Loss: 0.866, Validation Accuracy: 62.22%
# Epoch [6/10], Training Loss: 0.854, Validation Accuracy: 61.51%
# Epoch [7/10], Training Loss: 0.839, Validation Accuracy: 61.70%
# Epoch [8/10], Training Loss: 0.820, Validation Accuracy: 61.89%
# Epoch [9/10], Training Loss: 0.799, Validation Accuracy: 60.50%
# Epoch [10/10], Training Loss: 0.792, Validation Accuracy: 61.53%
# Epoch [1/10], Training Loss: 1.009, Validation Accuracy: 60.48%
# Epoch [2/10], Training Loss: 0.941, Validation Accuracy: 61.42%
# Epoch [3/10], Training Loss: 0.913, Validation Accuracy: 61.29%
# Epoch [4/10], Training Loss: 0.880, Validation Accuracy: 61.46%
# Epoch [5/10], Training Loss: 0.867, Validation Accuracy: 61.05%
# Epoch [6/10], Training Loss: 0.840, Validation Accuracy: 61.38%
# Epoch [7/10], Training Loss: 0.823, Validation Accuracy: 61.51%
# Epoch [8/10], Training Loss: 0.805, Validation Accuracy: 60.89%
# Epoch [9/10], Training Loss: 0.796, Validation Accuracy: 61.35%
# Epoch [10/10], Training Loss: 0.770, Validation Accuracy: 61.21%
# Epoch [1/10], Training Loss: 0.972, Validation Accuracy: 61.50%
# Epoch [2/10], Training Loss: 0.918, Validation Accuracy: 62.11%
# Epoch [3/10], Training Loss: 0.881, Validation Accuracy: 62.17%
# Epoch [4/10], Training Loss: 0.848, Validation Accuracy: 61.57%
# Epoch [5/10], Training Loss: 0.829, Validation Accuracy: 61.87%
# Epoch [6/10], Training Loss: 0.811, Validation Accuracy: 62.10%
# Epoch [7/10], Training Loss: 0.793, Validation Accuracy: 61.69%
# Epoch [8/10], Training Loss: 0.783, Validation Accuracy: 62.02%
# Epoch [9/10], Training Loss: 0.760, Validation Accuracy: 60.99%
# Epoch [10/10], Training Loss: 0.744, Validation Accuracy: 61.33%
# Epoch [1/10], Training Loss: 0.951, Validation Accuracy: 62.00%
# Epoch [2/10], Training Loss: 0.900, Validation Accuracy: 62.60%
# Epoch [3/10], Training Loss: 0.845, Validation Accuracy: 62.35%
# Epoch [4/10], Training Loss: 0.829, Validation Accuracy: 62.64%
# Epoch [5/10], Training Loss: 0.796, Validation Accuracy: 62.71%
# Epoch [6/10], Training Loss: 0.781, Validation Accuracy: 62.15%
# Epoch [7/10], Training Loss: 0.761, Validation Accuracy: 62.14%
# Epoch [8/10], Training Loss: 0.744, Validation Accuracy: 62.36%
# Epoch [9/10], Training Loss: 0.726, Validation Accuracy: 61.66%
# Epoch [10/10], Training Loss: 0.710, Validation Accuracy: 62.31%
# Epoch [1/10], Training Loss: 0.949, Validation Accuracy: 62.38%
# Epoch [2/10], Training Loss: 0.877, Validation Accuracy: 62.46%
# Epoch [3/10], Training Loss: 0.844, Validation Accuracy: 62.74%
# Epoch [4/10], Training Loss: 0.812, Validation Accuracy: 61.72%
# Epoch [5/10], Training Loss: 0.785, Validation Accuracy: 61.76%
# Epoch [6/10], Training Loss: 0.756, Validation Accuracy: 61.84%
# Epoch [7/10], Training Loss: 0.742, Validation Accuracy: 62.22%
# Epoch [8/10], Training Loss: 0.730, Validation Accuracy: 61.71%
# Epoch [9/10], Training Loss: 0.707, Validation Accuracy: 61.96%
# Epoch [10/10], Training Loss: 0.691, Validation Accuracy: 62.41%
# Epoch [1/10], Training Loss: 0.948, Validation Accuracy: 61.74%
# Epoch [2/10], Training Loss: 0.880, Validation Accuracy: 62.05%
# Epoch [3/10], Training Loss: 0.835, Validation Accuracy: 61.68%
# Epoch [4/10], Training Loss: 0.803, Validation Accuracy: 62.14%
# Epoch [5/10], Training Loss: 0.785, Validation Accuracy: 62.38%
# Epoch [6/10], Training Loss: 0.755, Validation Accuracy: 62.18%
# Epoch [7/10], Training Loss: 0.725, Validation Accuracy: 62.68%
# Epoch [8/10], Training Loss: 0.714, Validation Accuracy: 62.28%
# Epoch [9/10], Training Loss: 0.702, Validation Accuracy: 61.01%
# Epoch [10/10], Training Loss: 0.683, Validation Accuracy: 61.71%
# Epoch [1/10], Training Loss: 0.942, Validation Accuracy: 61.18%
# Epoch [2/10], Training Loss: 0.868, Validation Accuracy: 62.15%
# Epoch [3/10], Training Loss: 0.830, Validation Accuracy: 61.50%
# Epoch [4/10], Training Loss: 0.793, Validation Accuracy: 62.00%
# Epoch [5/10], Training Loss: 0.764, Validation Accuracy: 61.94%
# Epoch [6/10], Training Loss: 0.749, Validation Accuracy: 61.91%
# Epoch [7/10], Training Loss: 0.724, Validation Accuracy: 62.11%
# Epoch [8/10], Training Loss: 0.710, Validation Accuracy: 60.79%
# Epoch [9/10], Training Loss: 0.698, Validation Accuracy: 61.46%
# Epoch [10/10], Training Loss: 0.678, Validation Accuracy: 60.85%
# Epoch [1/10], Training Loss: 0.921, Validation Accuracy: 62.16%
# Epoch [2/10], Training Loss: 0.848, Validation Accuracy: 60.92%
# Epoch [3/10], Training Loss: 0.799, Validation Accuracy: 62.33%
# Epoch [4/10], Training Loss: 0.767, Validation Accuracy: 61.62%
# Epoch [5/10], Training Loss: 0.743, Validation Accuracy: 61.47%
# Epoch [6/10], Training Loss: 0.727, Validation Accuracy: 62.02%
# Epoch [7/10], Training Loss: 0.695, Validation Accuracy: 61.68%
# Epoch [8/10], Training Loss: 0.685, Validation Accuracy: 62.27%
# Epoch [9/10], Training Loss: 0.659, Validation Accuracy: 61.98%
# Epoch [10/10], Training Loss: 0.641, Validation Accuracy: 61.38%
# Epoch [1/10], Training Loss: 0.898, Validation Accuracy: 62.70%
# Epoch [2/10], Training Loss: 0.819, Validation Accuracy: 62.92%
# Epoch [3/10], Training Loss: 0.775, Validation Accuracy: 62.62%
# Epoch [4/10], Training Loss: 0.747, Validation Accuracy: 62.46%
# Epoch [5/10], Training Loss: 0.711, Validation Accuracy: 63.12%
# Epoch [6/10], Training Loss: 0.684, Validation Accuracy: 62.37%
# Epoch [7/10], Training Loss: 0.665, Validation Accuracy: 62.82%
# Epoch [8/10], Training Loss: 0.643, Validation Accuracy: 62.40%
# Epoch [9/10], Training Loss: 0.626, Validation Accuracy: 62.20%
# Epoch [10/10], Training Loss: 0.608, Validation Accuracy: 61.76%
# Epoch [1/10], Training Loss: 0.900, Validation Accuracy: 62.30%
# Epoch [2/10], Training Loss: 0.811, Validation Accuracy: 62.78%
# Epoch [3/10], Training Loss: 0.754, Validation Accuracy: 62.83%
# Epoch [4/10], Training Loss: 0.727, Validation Accuracy: 62.67%
# Epoch [5/10], Training Loss: 0.692, Validation Accuracy: 62.31%
# Epoch [6/10], Training Loss: 0.669, Validation Accuracy: 61.84%
# Epoch [7/10], Training Loss: 0.652, Validation Accuracy: 61.88%
# Epoch [8/10], Training Loss: 0.627, Validation Accuracy: 62.17%
# Epoch [9/10], Training Loss: 0.602, Validation Accuracy: 62.31%
# Epoch [10/10], Training Loss: 0.603, Validation Accuracy: 62.11%
# Epoch [1/10], Training Loss: 0.886, Validation Accuracy: 61.35%
# Epoch [2/10], Training Loss: 0.808, Validation Accuracy: 62.58%
# Epoch [3/10], Training Loss: 0.750, Validation Accuracy: 62.80%
# Epoch [4/10], Training Loss: 0.715, Validation Accuracy: 62.24%
# Epoch [5/10], Training Loss: 0.689, Validation Accuracy: 62.80%
# Epoch [6/10], Training Loss: 0.660, Validation Accuracy: 62.24%
# Epoch [7/10], Training Loss: 0.646, Validation Accuracy: 62.58%
# Epoch [8/10], Training Loss: 0.621, Validation Accuracy: 62.49%
# Epoch [9/10], Training Loss: 0.602, Validation Accuracy: 62.41%
# Epoch [10/10], Training Loss: 0.582, Validation Accuracy: 61.95%
# Epoch [1/10], Training Loss: 0.895, Validation Accuracy: 60.54%
# Epoch [2/10], Training Loss: 0.805, Validation Accuracy: 61.16%
# Epoch [3/10], Training Loss: 0.753, Validation Accuracy: 62.01%
# Epoch [4/10], Training Loss: 0.713, Validation Accuracy: 61.50%
# Epoch [5/10], Training Loss: 0.681, Validation Accuracy: 62.18%
# Epoch [6/10], Training Loss: 0.663, Validation Accuracy: 61.76%
# Epoch [7/10], Training Loss: 0.635, Validation Accuracy: 61.94%
# Epoch [8/10], Training Loss: 0.610, Validation Accuracy: 61.61%
# Epoch [9/10], Training Loss: 0.589, Validation Accuracy: 61.11%
# Epoch [10/10], Training Loss: 0.574, Validation Accuracy: 61.62%
# Epoch [1/10], Training Loss: 0.880, Validation Accuracy: 62.18%
# Epoch [2/10], Training Loss: 0.795, Validation Accuracy: 61.31%
# Epoch [3/10], Training Loss: 0.736, Validation Accuracy: 62.45%
# Epoch [4/10], Training Loss: 0.698, Validation Accuracy: 61.89%
# Epoch [5/10], Training Loss: 0.662, Validation Accuracy: 62.26%
# Epoch [6/10], Training Loss: 0.633, Validation Accuracy: 61.82%
# Epoch [7/10], Training Loss: 0.603, Validation Accuracy: 61.71%
# Epoch [8/10], Training Loss: 0.582, Validation Accuracy: 62.15%
# Epoch [9/10], Training Loss: 0.559, Validation Accuracy: 61.53%
# Epoch [10/10], Training Loss: 0.539, Validation Accuracy: 61.53%
# Epoch [1/10], Training Loss: 0.842, Validation Accuracy: 62.51%
# Epoch [2/10], Training Loss: 0.738, Validation Accuracy: 62.07%
# Epoch [3/10], Training Loss: 0.692, Validation Accuracy: 62.50%
# Epoch [4/10], Training Loss: 0.654, Validation Accuracy: 62.62%
# Epoch [5/10], Training Loss: 0.635, Validation Accuracy: 62.38%
# Epoch [6/10], Training Loss: 0.604, Validation Accuracy: 62.80%
# Epoch [7/10], Training Loss: 0.566, Validation Accuracy: 62.23%
# Epoch [8/10], Training Loss: 0.556, Validation Accuracy: 62.57%
# Epoch [9/10], Training Loss: 0.529, Validation Accuracy: 62.36%
# Epoch [10/10], Training Loss: 0.511, Validation Accuracy: 61.73%
# Epoch [1/10], Training Loss: 0.870, Validation Accuracy: 61.58%
# Epoch [2/10], Training Loss: 0.751, Validation Accuracy: 62.07%
# Epoch [3/10], Training Loss: 0.685, Validation Accuracy: 62.01%
# Epoch [4/10], Training Loss: 0.657, Validation Accuracy: 61.52%
# Epoch [5/10], Training Loss: 0.612, Validation Accuracy: 61.55%
# Epoch [6/10], Training Loss: 0.589, Validation Accuracy: 62.38%
# Epoch [7/10], Training Loss: 0.565, Validation Accuracy: 62.45%
# Epoch [8/10], Training Loss: 0.547, Validation Accuracy: 62.22%
# Epoch [9/10], Training Loss: 0.521, Validation Accuracy: 61.77%
# Epoch [10/10], Training Loss: 0.501, Validation Accuracy: 61.84%
# Epoch [1/10], Training Loss: 0.839, Validation Accuracy: 61.14%
# Epoch [2/10], Training Loss: 0.743, Validation Accuracy: 62.11%
# Epoch [3/10], Training Loss: 0.681, Validation Accuracy: 61.96%
# Epoch [4/10], Training Loss: 0.637, Validation Accuracy: 62.12%
# Epoch [5/10], Training Loss: 0.593, Validation Accuracy: 62.46%
# Epoch [6/10], Training Loss: 0.576, Validation Accuracy: 62.27%
# Epoch [7/10], Training Loss: 0.561, Validation Accuracy: 62.09%
# Epoch [8/10], Training Loss: 0.540, Validation Accuracy: 61.48%
# Epoch [9/10], Training Loss: 0.503, Validation Accuracy: 61.44%
# Epoch [10/10], Training Loss: 0.489, Validation Accuracy: 61.90%
# Epoch [1/10], Training Loss: 0.856, Validation Accuracy: 60.51%
# Epoch [2/10], Training Loss: 0.737, Validation Accuracy: 61.09%
# Epoch [3/10], Training Loss: 0.684, Validation Accuracy: 61.56%
# Epoch [4/10], Training Loss: 0.631, Validation Accuracy: 61.89%
# Epoch [5/10], Training Loss: 0.596, Validation Accuracy: 61.56%
# Epoch [6/10], Training Loss: 0.564, Validation Accuracy: 61.14%
# Epoch [7/10], Training Loss: 0.544, Validation Accuracy: 61.63%
# Epoch [8/10], Training Loss: 0.518, Validation Accuracy: 61.13%
# Epoch [9/10], Training Loss: 0.496, Validation Accuracy: 61.21%
# Epoch [10/10], Training Loss: 0.470, Validation Accuracy: 61.38%
# Epoch [1/10], Training Loss: 0.827, Validation Accuracy: 60.76%
# Epoch [2/10], Training Loss: 0.711, Validation Accuracy: 61.48%
# Epoch [3/10], Training Loss: 0.642, Validation Accuracy: 62.14%
# Epoch [4/10], Training Loss: 0.608, Validation Accuracy: 61.98%
# Epoch [5/10], Training Loss: 0.580, Validation Accuracy: 61.60%
# Epoch [6/10], Training Loss: 0.551, Validation Accuracy: 61.70%
# Epoch [7/10], Training Loss: 0.518, Validation Accuracy: 61.88%
# Epoch [8/10], Training Loss: 0.491, Validation Accuracy: 61.97%
# Epoch [9/10], Training Loss: 0.474, Validation Accuracy: 61.69%
# Epoch [10/10], Training Loss: 0.457, Validation Accuracy: 61.37%
# Epoch [1/10], Training Loss: 0.805, Validation Accuracy: 61.79%
# Epoch [2/10], Training Loss: 0.678, Validation Accuracy: 62.71%
# Epoch [3/10], Training Loss: 0.612, Validation Accuracy: 62.51%
# Epoch [4/10], Training Loss: 0.576, Validation Accuracy: 62.14%
# Epoch [5/10], Training Loss: 0.538, Validation Accuracy: 62.67%
# Epoch [6/10], Training Loss: 0.504, Validation Accuracy: 62.05%
# Epoch [7/10], Training Loss: 0.490, Validation Accuracy: 62.25%
# Epoch [8/10], Training Loss: 0.459, Validation Accuracy: 61.87%
# Epoch [9/10], Training Loss: 0.442, Validation Accuracy: 61.96%
# Epoch [10/10], Training Loss: 0.421, Validation Accuracy: 61.94%
# Epoch [1/10], Training Loss: 0.814, Validation Accuracy: 61.42%
# Epoch [2/10], Training Loss: 0.694, Validation Accuracy: 61.80%
# Epoch [3/10], Training Loss: 0.619, Validation Accuracy: 61.86%
# Epoch [4/10], Training Loss: 0.575, Validation Accuracy: 61.27%
# Epoch [5/10], Training Loss: 0.536, Validation Accuracy: 61.33%
# Epoch [6/10], Training Loss: 0.512, Validation Accuracy: 62.05%
# Epoch [7/10], Training Loss: 0.478, Validation Accuracy: 61.82%
# Epoch [8/10], Training Loss: 0.449, Validation Accuracy: 62.00%
# Epoch [9/10], Training Loss: 0.430, Validation Accuracy: 61.29%
# Epoch [10/10], Training Loss: 0.417, Validation Accuracy: 61.53%
# Confusion Matrix:
# [[705  27  63  17  24  13  13  15  67  56]
#  [ 38 708  16  16   7   7  11   9  37 151]
#  [ 69   8 471  67 117 120  49  52  26  21]
#  [ 19  16  73 401  78 242  64  54   8  45]
#  [ 29  10  93  56 521  87  52 118  17  17]
#  [ 18   7  80 158  53 546  26  82  12  18]
#  [ 17  13  71  72  62  64 654  18  14  15]
#  [ 23   8  28  45  62 124  14 655   3  38]
#  [110  56  33  14  14  10   3  12 698  50]
#  [ 53  89  14  18   5  21  13  35  27 725]]
# Test Accuracy: 60.84%
# True Positives (TP): [705 708 471 401 521 546 654 655 698 725]
# False Positives (FP): [376 234 471 463 422 688 245 395 211 411]
# True Negatives (TN): [8624 8766 8529 8537 8578 8312 8755 8605 8789 8589]
# False Negatives (FN): [295 292 529 599 479 454 346 345 302 275]
# : [10000 10000 10000 10000 10000 10000 10000 10000 10000 10000]
# Precision: [0.65217391 0.75159236 0.5        0.46412037 0.55249205 0.44246353
#  0.72747497 0.62380952 0.76787679 0.63820423]
# Recall: [0.705 0.708 0.471 0.401 0.521 0.546 0.654 0.655 0.698 0.725]
# F1 Score: [0.67755887 0.72914521 0.48506694 0.43025751 0.5362841  0.48880931
#  0.68878357 0.63902439 0.73127292 0.67883895]
